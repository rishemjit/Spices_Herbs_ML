# %%
import networkx as nx
import json
from networkx.algorithms import bipartite
from itertools import chain
import re
from collections import defaultdict
from Graph_Helpers import *
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ### Spice - Indication Network OR Spice - Phytochemical Network ###

# %%
FILE_IDX = 0
files = ["Derived_Data/Spice2Phytochemical2Disease/spice2indic_phytononzero.json", 
         "Derived_Data/Spice2Phytochemical2Disease/spice2phyto_nonzero.json"]
file_combine = files[FILE_IDX]

'''
MODE = 3

if MODE == 1: # herb
    with open(file_herb) as dict_file:
        dict_data = json.loads(dict_file.read())
    dict_data['Fig herb'] = dict_data.pop('Fig')  # herb
    dict_data['Poison  Ivy herb'] = dict_data.pop('Poison  Ivy')   #herb

if MODE == 2: # spice
    with open(file_spice) as dict_file:
        dict_data = json.loads(dict_file.read())

if MODE == 3: # combine
    with open(file_spice) as dict_file: # read from spice
        dict_spice = json.loads(dict_file.read())
    dict_data = dict_spice.copy()
    with open(file_herb) as dict_file: # read from herb
        dict_herb = json.loads(dict_file.read())
    dict_data1 = dict_herb.copy()

    duplicates = []
    for s in dict_spice.keys():
        for h in dict_herb.keys():
            if re.split('[^a-zA-Z]*', s) == re.split('[^a-zA-Z]*', h):
                dict_data[s] = list(set(dict_herb[h]).union(set(dict_spice[s])))
                dict_data1.pop(h)
                duplicates.append(s)
    dict_data.update(dict_data1)
    dict_data['Fig herb'] = dict_data.pop('Fig')  # herb
    dict_data['Poison Ivy herb'] = dict_data.pop('Poison Ivy')   #herb

dict2json(dict_data, 'spiceherb_indication_dict.json')
'''
dict_data = json2dict(file_combine) # spice2indic
Bi_graph = nx.Graph()
indications = set(list(chain.from_iterable(dict_data.values())))
items = list(dict_data.keys())  # items

Spice_Indication_df = pd.DataFrame(0, index=dict_data.keys(), columns= indications) # by rishem , create a data frame


Bi_graph.add_nodes_from(indications,bipartite = 1) # set 1: indications
Bi_graph.add_nodes_from(items,bipartite = 0) # set 0: items (spices)
for key in items:
    for v in dict_data[key]:
        Bi_graph.add_edges_from([(key,v)])
        Spice_Indication_df.loc[key, v]+=1  # by rishem
        #Spice_Indication_df.set_value(key, v, Spice_Indication_df.get_value(key, v)+1)

print('Edge count of bipartite:', len(Bi_graph.edges))
        
top_nodes = {n for n, d in Bi_graph.nodes(data=True) if d['bipartite']==0}
bottom_nodes = set(Bi_graph) - top_nodes   # indications

top_projection = bipartite.weighted_projected_graph(Bi_graph, top_nodes) # spice/herbs items
bot_projection = bipartite.weighted_projected_graph(Bi_graph, bottom_nodes) # indications

print('# of top nodes (spices): ',len(top_projection.nodes()), len(top_nodes))   # 746
print('# of bot nodes: ',len(bot_projection.nodes()), len(bottom_nodes))  # 1331
# Out:
# Edge count of bipartite: 34113
# # of top nodes (spices):  742 742
# # of bot nodes:  1327 1327

# %%
print('# edges top projection:', list(top_projection.edges)[0])
# Out:
# # edges top projection: ('Mate', 'Chaff-flower')

# %%
Spice_Indication_df.head()
# Out:
#                 Toxoplasmosis  Palsy  Cancer,stomach  Cancer,pudenda  \
# Acacia                      0      0               0               0
# Adam's needles              0      0               0               0
# African caper               0      0               0               0
# Agrimony                    0      0               1               0
# Air plant                   0      0               0               0
#
#                 Dermatosis  Hepatoma  Hematosis  Cancer,skin  Scar  Pulpitis  \
# Acacia                   0         0          0            0     0         0
# Adam's needles           1         0          0            0     0         0
# African caper            0         0          0            0     0         0
# Agrimony                 1         0          0            0     0         0
# Air plant                1         0          0            0     0         0
#
#                 ...  Screw worm  Cancer,leg  Rinderpest  Hipache  \
# ...

# %%
'''
from scipy.spatial.distance import cdist
from sklearn.decomposition import PCA
import seaborn as sns
from adjustText import adjust_text

import mpld3
#mpld3.enable_notebook()

#plotvar = region2spiceingre_df_combined.T

plotvar = Spice_Indication_df
n_components=3
pca = PCA(n_components=n_components)
principalComponents = pca.fit_transform(plotvar)

def myplot(score,coeff,label_sample, labels=None):
    from scipy.spatial.distance import cdist
    pc_ob=[0,1]
    print('score shape', score.shape)
    xs = score[:,pc_ob[0]]
    ys = score[:,pc_ob[1]]
    n = coeff.shape[0]
    #scalex = 1.0/(xs.max() - xs.min())
    #scaley = 1.0/(ys.max() - ys.min())
    #plt.scatter(xs * scalex,ys * scaley)
    plt.scatter(xs ,ys )
    dist = cdist(coeff[:,pc_ob], [(0,0)], 'euclidean')
    distcomp= np.sort(dist, axis=0)[::-1][30]# plot top 30 loadings
    textall=[]

    for i in range(n):
        if dist[i]> distcomp:
            plt.arrow(0, 0, coeff[i,0], coeff[i,1],color = [0.1, 0.2, 0.3],alpha = 0.5)
            if labels is None:
                plt.text(coeff[i,0]* 1.0, coeff[i,1] * 1.0, "Var"+str(i+1), color = 'g', ha = 'center', va = 'center')
            else:
                textall.append(plt.text(coeff[i,pc_ob[0]]* 1.0, coeff[i,pc_ob[1]] * 1.0, labels[i], color = 'g', ha = 'center', va = 'center', 
                         fontsize=12))
    #adjust_text(textall)
    
    textall=[]

    for i in range( len(label_sample)):
        textall.append(plt.text(xs[i]*1, ys[i]*1, label_sample[i], fontsize=14))
    #adjust_text(textall)
    #plt.xlim(-1,1)
    #plt.ylim(-1,1)
    plt.xlabel("PC{}".format(pc_ob[0]+1), fontsize= 14)
    plt.ylabel("PC{}".format(pc_ob[1]+1), fontsize=14)
    plt.grid()
    #plt.savefig('PCA_cuisine_spices_combined.jpg')

#Call the function. Use only the 2 PCs.
plt.figure(figsize=(20, 10))
myplot(principalComponents[:,0:n_components],np.transpose(pca.components_[0:n_components, :]), plotvar.index, plotvar.columns)
plt.show()
'''
# Out:
# '\nfrom scipy.spatial.distance import cdist\nfrom sklearn.decomposition import PCA\nimport seaborn as sns\nfrom adjustText import adjust_text\n\nimport mpld3\n#mpld3.enable_notebook()\n\n#plotvar = region2spiceingre_df_combined.T\n\nplotvar = Spice_Indication_df\nn_components=3\npca = PCA(n_components=n_components)\nprincipalComponents = pca.fit_transform(plotvar)\n\ndef myplot(score,coeff,label_sample, labels=None):\n    from scipy.spatial.distance import cdist\n    pc_ob=[0,1]\n    print(\'score shape\', score.shape)\n    xs = score[:,pc_ob[0]]\n    ys = score[:,pc_ob[1]]\n    n = coeff.shape[0]\n    #scalex = 1.0/(xs.max() - xs.min())\n    #scaley = 1.0/(ys.max() - ys.min())\n    #plt.scatter(xs * scalex,ys * scaley)\n    plt.scatter(xs ,ys )\n    dist = cdist(coeff[:,pc_ob], [(0,0)], \'euclidean\')\n    distcomp= np.sort(dist, axis=0)[::-1][30]# plot top 30 loadings\n    textall=[]\n\n    for i in range(n):\n        if dist[i]> distcomp:\n            plt.arrow(0, 0, coeff[i,0], c
# ...

# %% [markdown]
# ### Save adjacency mtx of the original projection graphs ###

# %%
adjmtx_pd_spice = nx.to_pandas_adjacency(top_projection)
adjmtx_pd_indic = nx.to_pandas_adjacency(bot_projection)

# %%
if not FILE_IDX:
    adjmtx_pd_spice.to_excel('NODEXL_ADJMTX_NEW/adjmtx_projgraph_spice_2indic.xlsx')
    adjmtx_pd_indic.to_excel('NODEXL_ADJMTX_NEW/adjmtx_projgraph_indic.xlsx')
else:
    adjmtx_pd_spice.to_excel('NODEXL_ADJMTX_NEW/adjmtx_projgraph_spice_2phyto.xlsx')
    adjmtx_pd_indic.to_excel('NODEXL_ADJMTX_NEW/adjmtx_projgraph_phyto.xlsx')

# %% [markdown]
# ### Backbone Extraction ###

# %%
# extract backbone network
import os.path
from os import path
import os
if not FILE_IDX:  
    PROJ_MODE = ['projgraph_spice_2indic', 'projgraph_indic']
else:
    PROJ_MODE = ['projgraph_spice_2phyto', 'projgraph_phyto']
print(PROJ_MODE)
IDX = 0

if IDX == 0:  # spice graph
    if FILE_IDX == 0:
        ALPHA = 0.04 # spice_2indic
    else:
        ALPHA = 0.008  # spice_2phyto
    # bot_projection: spice/herb
    # top_projection: indication

    top_backbone_nx = extract_backbone(top_projection, ALPHA)

    print('Edge Count:', top_backbone_nx.number_of_edges())
    print('Node Count:', len(top_backbone_nx.nodes()))

    # Save adjcency matrix of backboned projection graph
    adjmtx_pd = nx.to_pandas_adjacency(top_backbone_nx)
    adjmtx_pd.to_excel('NODEXL_ADJMTX_NEW/adjmtx_' + PROJ_MODE[IDX] + '_'+ str(ALPHA) + '.xlsx')
else:  # indic/phyto graph
    ALPHA = 0.0002
    ALPHA = 0.00001
    # bot_projection: spice/herb
    # top_projection: indication

    bot_backbone_nx = extract_backbone(bot_projection, ALPHA)

    print('Edge Count:', bot_backbone_nx.number_of_edges())
    print('Node Count:', len(bot_backbone_nx.nodes()))

    # Save adjcency matrix of backboned projection graph
    adjmtx_pd = nx.to_pandas_adjacency(bot_backbone_nx)
    adjmtx_pd.to_excel('NODEXL_ADJMTX_NEW/adjmtx_' + PROJ_MODE[IDX] + '_'+ str(ALPHA) + '.xlsx')
# Out:
# ['projgraph_spice_2indic', 'projgraph_indic']
# Edge Count: 114
# Node Count: 93

# %%
print(len(dict_data['Poke root']))
print(len(top_projection['Poke root']))
print(len(dict_data['Kale']))
# Out:
# 102
# 735
# 16

# %% [markdown]
# ### Generate clustering for backboned projection graph ###
# Note: First generate clustering on entire projection graph, then generate assign the backbone nodes to their corresponding clusters

# %% [markdown]
# ### Clustering 1: Wakita-Tusurumi Clustering ###

# %%
# Generate clustering for backbone, based on the whole graph clustering
import pandas as pd

# read {node: group number} from clustering on entire projection graph
cluster_pd = pd.read_excel('NODEXL_PLOT_NEW/'+ PROJ_MODE[0] + '/' + PROJ_MODE[IDX] + '_cluster2node_wakita.xlsx')
node2cluster_orig = dict(zip(list(cluster_pd['Vertex']), list(cluster_pd['Group'])))

# find group number (cluster) for backbone nodes
if IDX == 0:
    backbone_nodes = top_backbone_nx.nodes()
else:
    backbone_nodes = bot_backbone_nx.nodes()
cluster2node_backbone = {}
for node in backbone_nodes:
    cluster = node2cluster_orig[node]
    if not cluster in cluster2node_backbone:
        cluster2node_backbone[cluster] = [node]
    else:
        cluster2node_backbone[cluster].extend([node])
# generate clustering for backboned projection graph
cluster_list = []
for k,v in cluster2node_backbone.items():
    cluster_list.extend(len(v)*[k])
node_list = list(chain.from_iterable(cluster2node_backbone.values()))
cluster2node_backbone_df = pd.DataFrame({'Group': cluster_list, 'Vertex': node_list})
cluster2node_backbone_df.to_excel('NODEXL_PLOT_NEW/' + PROJ_MODE[0] + '/' + PROJ_MODE[IDX] + '_cluster2node_'+ str(ALPHA)+'_wakita.xlsx')

# %% [markdown]
# ## To analyze the clusters obtained

# %%
# add cluster column to Spice_Indication_df
def df_spice2indic_clustered(cluster_pd, Spice_Indication_df):
    print(len(cluster_pd.index))
    for i in range(len(cluster_pd.index)):
        spice = cluster_pd.loc[i, 'Vertex']
        cluster = cluster_pd.loc[i, 'Group']
        if 'G' not in cluster:
            print(spice)
        Spice_Indication_df.loc[spice, 'Cluster'] = cluster
    return Spice_Indication_df
spice2indic_clustered_wakita = df_spice2indic_clustered(cluster_pd, Spice_Indication_df)
spice2indic_clustered_wakita.head()
# Out:
# 742
#                 Toxoplasmosis  Palsy  Cancer,stomach  Cancer,pudenda  \
# Acacia                      0      0               0               0
# Adam's needles              0      0               0               0
# African caper               0      0               0               0
# Agrimony                    0      0               1               0
# Air plant                   0      0               0               0
#
#                 Dermatosis  Hepatoma  Hematosis  Cancer,skin  Scar  Pulpitis  \
# Acacia                   0         0          0            0     0         0
# Adam's needles           1         0          0            0     0         0
# African caper            0         0          0            0     0         0
# Agrimony                 1         0          0            0     0         0
# Air plant                1         0          0            0     0         0
#
#                 ...  Cancer,leg  Rinderpest  Hipache  \
# ...

# %% [markdown]
# ### delete clusters with less than 20 spices(can be experimented)

# %%
def df_cluster2count(Spice_Indication_df):
    temp = Spice_Indication_df['Cluster'].value_counts() # find no of spices in each cluster
    print(temp)
    # delete cluster with less than 20 enteries
    # for each cluster, each indication receive score calculated by # associated spices in cluster / # spices in cluster 
    group_ind_count =Spice_Indication_df.groupby('Cluster').apply(lambda x: x.sum()/len(x))
    keepClust = temp.loc[temp>5].index
    delClust = set(temp.index ) - set(keepClust)
    group_ind_count.drop(delClust, inplace=True)
    return group_ind_count
cluster2count_wakita = df_cluster2count(spice2indic_clustered_wakita)
cluster2count_wakita
# Out:
# G1     201
# G2     127
# G3     122
# G4      89
# G5      80
# G6      75
# G7      35
# G8       9
# G9       2
# G10      1
# G11      1
# Name: Cluster, dtype: int64
#          Toxoplasmosis     Palsy  Cancer,stomach  Cancer,pudenda  Dermatosis  \
# Cluster
# G1            0.004975  0.014925        0.059701        0.004975    0.393035
# G2            0.000000  0.023622        0.244094        0.000000    0.535433
# G3            0.000000  0.024590        0.073770        0.000000    0.491803
# G4            0.011236  0.022472        0.123596        0.000000    0.438202
# G5            0.000000  0.037500        0.225000        0.000000    0.637500
# G6            0.000000  0.026667        0.146667        0.000000    0.600000
# G7            0.000000  0.057143        0.114286        0.000000    0.571429
# G8            0.000000  0.000000        0.333333        0.000000    0.555556
#
#          Hepatoma  Hematosis  Cancer,skin      Scar  Pulpitis  ...  \
# ...

# %%
cluster2color = pd.read_excel('NODEXL_PLOT_NEW/' + PROJ_MODE[0] + '/'+ PROJ_MODE[0] + '_clustercolor.xlsx')
rgb_val = tuple([int(val) for val in cluster2color.loc[cluster2color['Group']=='G1','Vertex Color'].values[0].split(',')])
cluster2color
# Out:
#    Group Vertex Color Vertex Shape
# 0     G1    0, 12, 96         Disk
# 1     G2  0, 136, 227         Disk
# 2     G3   0, 100, 50         Disk
# 3     G4   0, 176, 22         Disk
# 4     G5    191, 0, 0         Disk
# 5     G6  230, 120, 0         Disk
# 6     G7  255, 191, 0         Disk
# 7     G8  150, 200, 0         Disk
# 8     G9  200, 0, 120         Disk
# 9    G10    77, 0, 96         Disk
# 10   G11   91, 0, 191         Disk

# %%
# find top diseses from each cluster
def plot_indic2count_bycluster(Spice_Indication_df,group_ind_count, save_path):
    fig = plt.figure(figsize= (20,10))
    fig.tight_layout()
    plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=0.8)
    plt.rc('xtick',labelsize=14)
    plt.rc('ytick',labelsize=14)

    for i, ind in enumerate(group_ind_count.index):
        t = group_ind_count.loc[ind].sort_values(ascending = False)[:10] # find top spices
        #t = t[t>0.5]
        rgb_val = tuple([int(val)/255 for val in cluster2color.loc[cluster2color['Group']==ind,'Vertex Color'].values[0].split(',')])
        print(rgb_val)
        ax = fig.add_subplot(2,4,i+1)
        t.plot.bar(ax=ax, color=rgb_val)
        temp = Spice_Indication_df.loc[Spice_Indication_df['Cluster']==ind].index
        #list (Spice_Indication_df.loc[temp].sum(axis=1).sort_values(ascending=False)[:10].index)
        top_nodes = list (Spice_Indication_df.loc[temp].sum(axis=1).sort_values(ascending=False)[:2].index)
        plt.title('Cluster %s \n(%s, %s)'%(ind[1:],top_nodes[0],top_nodes[1]),fontsize=15)
    plt.ylabel(r'\bf{phase field} $\phi$', {'color': 'C0', 'fontsize': 20})
    plt.tight_layout()
    plt.savefig(save_path)
save_path = 'NODEXL_PLOT_NEW/distribution_plot/cluster2' + PROJ_MODE[1].split('_')[1] + '_distribution_wakita.png'
plot_indic2count_bycluster(spice2indic_clustered_wakita, cluster2count_wakita, save_path)
# Out:
# (0.0, 0.047058823529411764, 0.3764705882352941)
# (0.0, 0.5333333333333333, 0.8901960784313725)
# (0.0, 0.39215686274509803, 0.19607843137254902)
# (0.0, 0.6901960784313725, 0.08627450980392157)
# (0.7490196078431373, 0.0, 0.0)
# (0.9019607843137255, 0.47058823529411764, 0.0)
# (1.0, 0.7490196078431373, 0.0)
# (0.5882352941176471, 0.7843137254901961, 0.0)

# %%
# # find top diseses from each cluster
# def plot_indic2count_bycluster(Spice_Indication_df,group_ind_count, save_path):
#     fig = plt.figure(figsize= (20,10))
#     fig.tight_layout()
#     plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=0.8)

#     for i, ind in enumerate(group_ind_count.index):
#         t = group_ind_count.loc[ind].sort_values(ascending = False)[:10] # find top spices
#         #t = t[t>0.5]
#         ax = fig.add_subplot(2,4,i+1)
#         t.plot.bar(ax=ax)
#         temp = Spice_Indication_df.loc[Spice_Indication_df['Cluster']==ind].index
#         #list (Spice_Indication_df.loc[temp].sum(axis=1).sort_values(ascending=False)[:10].index)
#         plt.title([ind]+ list (Spice_Indication_df.loc[temp].sum(axis=1).sort_values(ascending=False)[:2].index))
#     plt.savefig(save_path)
# save_path = 'NODEXL_PLOT_NEW/distribution_plot/cluster2' + PROJ_MODE[1].split('_')[1] + '_distribution_wakita.png'
# plot_indic2count_bycluster(spice2indic_clustered_wakita, cluster2count_wakita, save_path)

# %%
temp = spice2indic_clustered_wakita.loc[spice2indic_clustered_wakita['Cluster']=='G1'].index
spice2indic_clustered_wakita.loc[temp].sum(axis=1).sort_values(ascending=False)[:10]
# Out:
# Lobelia             116
# Bloodroot           115
# Ginseng             103
# Ginkgo               84
# Oregano              73
# Evening primrose     70
# Blue cohosh          69
# Wood betony          69
# Anise                66
# Cow parsnip          66
# dtype: int64

# %%
cluster2count_wakita
# Out:
#          Neutropenia  Vaginosis  Hemostasis     Blood    Strain      Scab  \
# Cluster
# G1             0.000   0.074627    0.000000  0.009950  0.004975  0.009950
# G2             0.000   0.078740    0.000000  0.015748  0.023622  0.007874
# G3             0.000   0.057377    0.000000  0.016393  0.008197  0.016393
# G4             0.000   0.101124    0.000000  0.000000  0.011236  0.000000
# G5             0.025   0.150000    0.000000  0.000000  0.025000  0.012500
# G6             0.000   0.186667    0.013333  0.013333  0.026667  0.000000
# G7             0.000   0.057143    0.000000  0.000000  0.028571  0.028571
# G8             0.000   0.111111    0.000000  0.000000  0.000000  0.000000
#
#            Emesis  Septicemia  Mucososis  Morbus behet  ...  Oligolactea  \
# Cluster                                                 ...
# G1       0.004975    0.000000   0.129353      0.000000  ...     0.000000
# G2       0.000000    0.000000   0.141732      0.007874  ...     0.023622
# ...

# %%
# rename index name
idx_repl = {}
for idx in cluster2count_wakita.index:
    idx_repl[idx] = 'C'+idx[1:]
cluster2count_wakita = pd.DataFrame.rename(cluster2count_wakita, index=idx_repl)

# %%
# find top diseses from each cluster
import seaborn as sns
def plot_cluster2indic_heatmap(group_ind_count, save_path): 
    top_ind_list = []
    for i, ind in enumerate(group_ind_count.index):
        t = group_ind_count.loc[ind].sort_values(ascending = False)[:10]
        top_ind_list.extend(list(t.index))
    cluster_ind_df = pd.DataFrame(index=group_ind_count.index,columns=list(set(top_ind_list)), dtype='float64')
    
    for i, ind in enumerate(group_ind_count.index):
        cluster_ind_df.loc[ind] = group_ind_count.loc[ind, cluster_ind_df.columns]
    #print(cluster_ind_df)

    #del cluster_ind_df.index.name

    fig = plt.figure(figsize= (14,8))
    plt.rc('xtick',labelsize=10)
    plt.rc('ytick',labelsize=10)
    sns.heatmap(cluster_ind_df)
    fig.savefig(save_path, bbox_inches="tight")
save_path = 'NODEXL_PLOT_NEW/heatmap/cluster2top' + PROJ_MODE[1].split('_')[1] + '_heatmap_wakita.png'
plot_cluster2indic_heatmap(cluster2count_wakita, save_path)

# %%
cluster2count_wakita.idxmax(axis=1)
# Out:
# Cluster
# C1       Fever
# C2      Cancer
# C3      Cancer
# C4       Fever
# C5        Pain
# C6       Fever
# C7       Cough
# C8    Diarrhea
# dtype: object

# %% [markdown]
# ### Clustering 2: Leidenalg Clustering ###

# %%
# generate adjacency matrix of nx projection graphs (pd format or np arr)

from pandas import ExcelWriter
import igraph as ig
import leidenalg
import os

# %%
if IDX == 0:
    adjmtx_np = nx.convert_matrix.to_numpy_matrix(top_projection)
    adjmtx_pd = nx.to_pandas_adjacency(top_projection)

    adjmtx_np_backbone = nx.convert_matrix.to_numpy_matrix(top_backbone_nx)
    adjmtx_pd_backbone = nx.to_pandas_adjacency(top_backbone_nx)
else:
    adjmtx_np = nx.convert_matrix.to_numpy_matrix(bot_projection)
    adjmtx_pd = nx.to_pandas_adjacency(bot_projection)

    adjmtx_np_backbone = nx.convert_matrix.to_numpy_matrix(bot_backbone_nx)
    adjmtx_pd_backbone = nx.to_pandas_adjacency(bot_backbone_nx)

node_names = list(adjmtx_pd.columns.values)

graph_pd = pd.DataFrame(adjmtx_np, index=node_names, columns=node_names)

# Get the values as np.array, it's more convenenient.
A = graph_pd.values

# Create graph, A.astype(bool).tolist() or (A / A).tolist() can also be used.
graph_ig = ig.Graph.Adjacency((A > 0).tolist())

# Add edge weights and node labels.
graph_ig.es['weight'] = A[A.nonzero()]
graph_ig.vs['label'] = node_names  # or a.index/a.columns

# %%
PART_IDX = 0
node2cluster_file = 'NODEXL_PLOT_NEW/' + PROJ_MODE[0] + '/'+ PROJ_MODE[IDX] + '_cluster2node'+'_leiden_' + str(PART_IDX) + '.xlsx'
if not os.path.isfile(node2cluster_file):
    # install igraph and leidenalg
    # search igraph graph from numpy or pandas adjacency matrix
    RESOLUTION = 0.1

    parts_modularity = leidenalg.find_partition(graph_ig, leidenalg.ModularityVertexPartition, n_iterations=-2) #0

    parts_significance = leidenalg.find_partition(graph_ig, leidenalg.SignificanceVertexPartition) #1

    parts_RB = leidenalg.find_partition(graph_ig, leidenalg.RBConfigurationVertexPartition, resolution_parameter = RESOLUTION) #2 

    parts_RBER = leidenalg.find_partition(graph_ig, leidenalg.RBERVertexPartition, resolution_parameter = RESOLUTION) #3 

    parts_surprise = leidenalg.find_partition(graph_ig, leidenalg.SurpriseVertexPartition) #4 

    parts_CPM = leidenalg.find_partition(graph_ig, leidenalg.CPMVertexPartition, resolution_parameter = RESOLUTION) #5

    parts_list = [parts_modularity, parts_significance, parts_RB, parts_RBER, parts_surprise, parts_CPM]

    # generate {node name: group id} dict for entire projection graph

    node2group = {}
    partition = parts_list[PART_IDX]
    for group_id in range(len(partition)):
        for i in partition[group_id]:
            node2group[node_names[i]] = 'G' + str(group_id + 1)
    cluster_pd_leiden = pd.DataFrame(node2group.items(), columns=['Vertex', 'Group'])
    print(cluster_pd_leiden)
    cluster_pd_leiden.to_excel(node2cluster_file)
    spice2indic_clustered_leiden = df_spice2indic_clustered(cluster_pd_leiden, Spice_Indication_df)
    spice2indic_clustered_leiden.head()
else:
    #print('READ---')
    cluster_pd_leiden = pd.read_excel(node2cluster_file)
    #print(cluster_pd_leiden
    spice2indic_clustered_leiden = df_spice2indic_clustered(cluster_pd_leiden, Spice_Indication_df)
spice2indic_clustered_leiden.head()
# Out:
# 742
#                 Neutropenia  Vaginosis  Hemostasis  Blood  Strain  Scab  \
# Acacia                    0          1           0      0       0     0
# Adam's needles            0          0           0      0       0     0
# African caper             0          0           0      0       0     0
# Agrimony                  0          0           0      0       0     0
# Air plant                 0          0           0      0       0     0
#
#                 Emesis  Septicemia  Mucososis  Morbus behet  ...  Gastrospasm  \
# Acacia               0           0          1             0  ...            0
# Adam's needles       0           0          0             0  ...            0
# African caper        0           0          0             0  ...            0
# Agrimony             0           0          1             0  ...            0
# Air plant            0           0          0             0  ...            0
#
# ...

# %%
if IDX == 0:
    save_path = 'NODEXL_PLOT_NEW/distribution_plot/cluster2' + PROJ_MODE[1].split('_')[1] + '_distribution_leiden.png'
    cluster2count_leiden = df_cluster2count(spice2indic_clustered_leiden)
    plot_indic2count_bycluster(spice2indic_clustered_leiden, cluster2count_leiden, save_path)
# Out:
# G1    311
# G2    264
# G3    167
# Name: Cluster, dtype: int64
# (0.0, 0.047058823529411764, 0.3764705882352941)
# (0.0, 0.5333333333333333, 0.8901960784313725)
# (0.0, 0.39215686274509803, 0.19607843137254902)

# %%
idx_repl = {}
for idx in cluster2count_leiden.index:
    idx_repl[idx] = 'C'+idx[1:]
cluster2count_leiden = pd.DataFrame.rename(cluster2count_leiden, index=idx_repl)
if IDX == 0:
    save_path = 'NODEXL_PLOT_NEW/heatmap/cluster2top' + PROJ_MODE[1].split('_')[1] + '_heatmap_leiden.png'
    plot_cluster2indic_heatmap(cluster2count_leiden, save_path)

# %%
# find group number (cluster) for backbone nodes
group2node_backbone = {}
for node in backbone_nodes:
    group = node2group[node]
    if not group in group2node_backbone:
        group2node_backbone[group] = [node]
    else:
        group2node_backbone[group].extend([node])
        
# generate clustering for backboned projection graph
group_list = []
for k,v in group2node_backbone.items():
    group_list.extend(len(v)*[k])
node_list = list(chain.from_iterable(group2node_backbone.values()))
group2node_backbone_df = pd.DataFrame({'Group': group_list, 'Vertex': node_list})
group2node_backbone_df.to_excel('NODEXL_PLOT_NEW/' + PROJ_MODE[0] + '/'+ PROJ_MODE[IDX] + '_cluster2node_'+ str(ALPHA)+'_leiden_' + str(PART_IDX) + '.xlsx')

# %% [markdown]
# ### Centrality Measures ###

# %%
# Centrality

from collections import OrderedDict
from operator import itemgetter    

if IDX == 0:
    g_distance_dict = {(e1, e2): 1 / weight for e1, e2, weight in top_projection.edges(data='weight')}
    nx.set_edge_attributes(top_projection, g_distance_dict, 'distance')
        
    centrality_eigen = nx.eigenvector_centrality(top_projection, weight='weight')

    #centrality_katz = nx.katz_centrality(GRAPHS[GRAPH_IDX])

    #centrality_harmonic = nx.harmonic_centrality(top_projection)

    centrality_closeness = nx.closeness_centrality(top_projection, distance='distance')

    #centrality_degree = nx.degree_centrality(top_projection)
    centrality_degree = top_projection.degree(weight='weight')
else:
    g_distance_dict = {(e1, e2): 1 / weight for e1, e2, weight in bot_projection.edges(data='weight')}
    nx.set_edge_attributes(bot_projection, g_distance_dict, 'distance')
    centrality_eigen = nx.eigenvector_centrality(bot_projection, weight='weight')

    #centrality_katz = nx.katz_centrality(GRAPHS[GRAPH_IDX])

    centrality_harmonic = nx.harmonic_centrality(bot_projection)

    centrality_closeness = nx.closeness_centrality(bot_projection)

    #centrality_degree = nx.degree_centrality(bot_projection)
    centrality_degree = bot_projection.degree(weight='weight')

# %%
centrality_eigen_ordered = list(OrderedDict(sorted(centrality_eigen.items(), key = itemgetter(1), reverse = True)))
print('eigen_centrality: ', centrality_eigen_ordered)

centrality_closeness_ordered = list(OrderedDict(sorted(centrality_closeness.items(), key = itemgetter(1), reverse = True)))
print('\ncloseness centrality: ',centrality_closeness_ordered)

centrality_degree_ordered = list(OrderedDict(sorted(centrality_degree, key = itemgetter(1), reverse = True)))
print('\ndegree centrality: ', centrality_degree_ordered)
# Out:
# eigen_centrality:  ['CALCIUM', 'IRON', 'POTASSIUM', 'PHOSPHORUS', 'SODIUM', 'FIBER', 'MAGNESIUM', 'ASCORBIC-ACID', 'MANGANESE', 'RIBOFLAVIN', 'ZINC', 'BETA-CAROTENE', 'NIACIN', 'THIAMIN', 'PALMITIC-ACID', 'OLEIC-ACID', 'BETA-SITOSTEROL', 'LINOLEIC-ACID', 'COPPER', 'STEARIC-ACID', 'CAFFEIC-ACID', 'QUERCETIN', 'VALINE', 'COBALT', 'CHROMIUM', 'LEUCINE', 'ARGININE', 'GLUTAMIC-ACID', 'THREONINE', 'SERINE', 'TYROSINE', 'LYSINE', 'STIGMASTEROL', 'ASPARTIC-ACID', 'ISOLEUCINE', 'PHENYLALANINE', 'GLYCINE', 'ALUMINUM', 'ALANINE', 'CAMPESTEROL', 'HISTIDINE', 'METHIONINE', 'SELENIUM', 'SILICON', 'MYRISTIC-ACID', 'P-COUMARIC-ACID', 'GLUCOSE', 'TRYPTOPHAN', 'BORON', 'PHYTOSTEROLS', 'FERULIC-ACID', 'KAEMPFEROL', 'CYSTINE', 'PANTOTHENIC-ACID', 'RUTIN', 'LIMONENE', 'TANNIN', 'OXALIC-ACID', 'CHLOROGENIC-ACID', 'SUCROSE', 'SULFUR', 'SALICYLATES', 'PALMITOLEIC-ACID', 'FRUCTOSE', 'CITRIC-ACID', 'PECTIN', 'ALPHA-PINENE', 'ALPHA-TOCOPHEROL', 'ALPHA-TERPINEOL', 'MALIC-ACID', 'ARSENIC', 'BETA-PINENE', 'NICKEL
# ...

# %%
# combine results and find top 20
TOP = 20
spice2rank = {}
for spice in centrality_closeness_ordered:
    rank_eigen = centrality_eigen_ordered.index(spice)
    rank_closeness = centrality_closeness_ordered.index(spice)
    rank_degree = centrality_degree_ordered.index(spice)
    rank_combined = rank_eigen + rank_closeness + rank_degree
    spice2rank.update({spice : rank_combined})
spice_ranked = list(OrderedDict(sorted(spice2rank.items(), key = itemgetter(1), reverse = False)))
', '.join(spice_ranked[:TOP])
# Out:
# 'CALCIUM, IRON, PHOSPHORUS, POTASSIUM, SODIUM, FIBER, ASCORBIC-ACID, MAGNESIUM, BETA-SITOSTEROL, MANGANESE, PALMITIC-ACID, BETA-CAROTENE, ZINC, RIBOFLAVIN, OLEIC-ACID, NIACIN, THIAMIN, LINOLEIC-ACID, STEARIC-ACID, COPPER'

# %%
df = pd.DataFrame.from_dict({'Eigen Centrality':centrality_eigen_ordered,'Closeness Centrality': centrality_closeness_ordered,
                             'Degree Centrality': centrality_degree_ordered, 'Combined rank': spice_ranked })
df.to_excel('NODEXL_PLOT_NEW/' + PROJ_MODE[0] + '/' + PROJ_MODE[IDX] +  '_centrality_summary.xlsx', header=True, index=False)

# %%
dictOfWords = dict.fromkeys(listOfStr , 1)
