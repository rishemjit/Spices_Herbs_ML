# %%
import json
import pandas as pd
from collections import Counter
from numpy import array, eye, hstack, ones, vstack, zeros
import cvxopt
from cvxopt.glpk import ilp
import time
from itertools import chain
from Graph_Helpers import *
from MinSetCover import Min_cover_set, Min_cover_set_greedy
import matplotlib.pyplot as plt
import math

# %%
#indic2spice_grouped['Mental disorders'].keys()

# %%
# Preprocessing of indic2group xlsx
label_file = '../Crawlers/Malacards/indic_all_categorized_malacards_LRV.xlsx'
result_folder = 'Derived_Data/MinSetCover/'
plot_folder = result_folder + 'minset_plots/'
spice2indic = json2dict('Derived_Data/Spice2Phytochemical2Disease/spice2indic_phytononzero.json')
indic2spice = reverse_dict(spice2indic)
label_df = pd.read_excel(label_file)
group2indic2spice = {}
for indic in indic2spice.keys():
    group = list(label_df[label_df.hnd_indic == indic]['ICD Category'])[0]
    #print(group)
    if str(group) == 'nan':
        group = 'General symptom'
    if group not in group2indic2spice:
        group2indic2spice[group] = {}
    group2indic2spice[group].update({indic: indic2spice[indic]})
    #break
dict2json(group2indic2spice, result_folder + 'group2indic2spice.json')

# %%
# check which category 'Thumb sucking' belongs to
group_list = []
for group, indic2spice in group2indic2spice.items():
    if indic2spice:
        group_list.append(group)
    for indic in indic2spice.keys():
        if indic == 'Thumb sucking':
            print(group)
# Out:
# General symptom

# %%
print(group_list)
# Out:
# ['infectious_disease', 'gastrointestinal_disease', 'General symptom', 'respiratory_disease', 'injury', 'cancer_disease', 'pregnancy_disease', 'cardiovascular_disease', 'eye_disease', 'endocrine_disease', 'nephrological_disease', 'metabolic_disease', 'skin_disease', 'mental_disease', 'reproductive_disease', 'musculoskeletal_disease ', 'ear_disease', 'neuronal_disease', 'poisoning', 'blood_disease', 'immune_disease', 'sleep_disease', 'nutritional_disease', 'general_disease', 'othercauses', 'oral_disease', 'genetic_disease', 'smell_taste_disease']

# %%
group2indic2spice.keys()
# infectious_disease, cardiovascular_disease, gastrointestinal_disease, respiratory_disease, cancer_disease
# Out:
# dict_keys(['infectious_disease', 'gastrointestinal_disease', 'General symptom', 'respiratory_disease', 'injury', 'cancer_disease', 'pregnancy_disease', 'cardiovascular_disease', 'eye_disease', 'endocrine_disease', 'nephrological_disease', 'metabolic_disease', 'skin_disease', 'mental_disease', 'reproductive_disease', 'musculoskeletal_disease ', 'ear_disease', 'neuronal_disease', 'poisoning', 'blood_disease', 'immune_disease', 'sleep_disease', 'nutritional_disease', 'general_disease', 'othercauses', 'oral_disease', 'genetic_disease', 'smell_taste_disease'])

# %%
# Generate Min Set Cover for each disease group

disease_groups = list(group2indic2spice.keys())
results_pd = pd.DataFrame(index = disease_groups, columns= ['#Spices', '#Indications', 'Min number of spices to cover indications', 'Min set'])

indic2spice_adjmtx = []
for group in disease_groups:
    set_name = ['Spices', 'Indications']
    spice2indic_onegroup = reverse_dict(group2indic2spice[group])
    bi_graph, spice_topset, indic_botset = Bipartite_graph(spice2indic_onegroup, set_name)
    # row: bottom nodes - dict.values; column: top nodes - dict.keys - indicationsbot
    # top_set: indic; bot_set: spices
    adjmtx = bipartite.biadjacency_matrix(bi_graph, row_order=indic_botset, column_order=spice_topset).toarray()
    print('\n\nGroup Name: ', group)
    print('Adjacency Matrix Shape (#indication x #spice): ', adjmtx.shape)
    indic2spice_adjmtx.append(adjmtx)
    min_coverset_greedy = Min_cover_set_greedy(spice2indic_onegroup, group2indic2spice[group])
    
    
    n2 = adjmtx.shape[1]
    c = np.hstack([np.ones(n2), [0]])
    
    min_coverset_optim = Min_cover_set(spice2indic_onegroup, spice_topset, indic_botset, adjmtx,c)
    print('Size of Min cover set matched: ', len(min_coverset_greedy) == len(min_coverset_optim))
    print('Set difference btw Greedy and Optimization approach: ', set(min_coverset_greedy) - set(min_coverset_optim))
    print('Symmetric difference difference btw Greedy and Optimization approach: ', set(min_coverset_greedy).symmetric_difference(set(min_coverset_optim)))# March 21,2020
    
    print('Min cover set by optimization:', len(min_coverset_optim), min_coverset_optim)
    print('\nMin cover set by greedy:', len(min_coverset_greedy), min_coverset_greedy)
    
    
    results_pd.loc[group, '#Spices'] = adjmtx.shape[1]
    results_pd.loc[group, '#Indications'] = adjmtx.shape[0]
    results_pd.loc[group, 'Min number of spices to cover indications'] = len(min_coverset_optim)
    results_pd.loc[group, 'Min set'] = min_coverset_optim
# Out:
# Total Spices(top):  695
# Total Indications(bot):  177
#
#
# Group Name:  infectious_disease
# Adjacency Matrix Shape (#indication x #spice):  (177, 695)
# status optimal
# All indications are covered:  True
# Size of Min cover set matched:  True
# Set difference btw Greedy and Optimization approach:  {'Akee apples', 'Cranesbill', 'Hot pepper', 'Ajowan', 'Horsetail', 'Cacao', 'Poke root'}
# Symmetric difference difference btw Greedy and Optimization approach:  {'Cranesbill', 'Hot pepper', 'Purging nut', 'Ajowan', 'Goldthread', 'Logwood', 'Jackass bitters', 'Cacao', 'Akee apples', 'Poke root', 'Roselle', 'Quassia', 'Scotch pine', 'Horsetail'}
# ...

# %%
# disregard indications in categories in drop_list
drop_list = ['General symptom','injury','othercauses','poisoning','general_disease']

for d in drop_list:
    try:
        disease_groups.remove(d)
    except:
        continue
disease_groups
# Out:
# ['infectious_disease',
#  'gastrointestinal_disease',
#  'respiratory_disease',
#  'cancer_disease',
#  'pregnancy_disease',
#  'cardiovascular_disease',
#  'eye_disease',
#  'endocrine_disease',
#  'nephrological_disease',
#  'metabolic_disease',
#  'skin_disease',
#  'mental_disease',
#  'reproductive_disease',
#  'musculoskeletal_disease ',
#  'ear_disease',
#  'neuronal_disease',
#  'blood_disease',
#  'immune_disease',
#  'sleep_disease',
#  'nutritional_disease',
#  'oral_disease',
#  'genetic_disease',
#  'smell_taste_disease']

# %% [markdown]
# ## random select 6 disease groups for venn plot ##

# %%
import random
num_groups = len(disease_groups)

group_ids = random.sample(range(0,num_groups), 6)  
group_venn = [disease_groups[i] for i in group_ids] 


#'skin_disease', 'nephrological_disease', 'neuronal_disease', 'pregnancy_disease', 'mental_disease', 'metabolic_disease',

# group_venn = ['cancer_disease','respiratory_disease','gastrointestinal_disease',
#               'infectious_disease', 'immune_disease','cardiovascular_disease']


#group_venn = ["infectious_disease", "cardiovascular_disease", "gastrointestinal_disease", "respiratory_disease", "cancer_disease", "blood_disease","immune_disease"]
#group_venn = list(group2indic2spice.keys())

# get min set for selected disease group 
group2minsetdf = {}
for group in group_venn:
    if group not in drop_list:
        print('---- disease group:', group)
        minsetdf = {}
        spices = results_pd.loc[group, 'Min set']  # min set spices to cover this disease group
        print(','.join(spices))
        minsetdf['spices'] = spices
        num_indic = []
        for s in spices:
            num_indic.append(len(spice2indic[
                s]))
        minsetdf['indication count'] = num_indic  # num indic per spices
        group2minsetdf[group.replace('_disease','')] = pd.DataFrame(minsetdf)
        
print('\n',group2minsetdf.keys())
# Out:
# ---- disease group: cancer_disease
# Avocado,Baneberry,Beet,Belladonna,Black bean,Black cumin,Carrot,Cashew,Celandine,Chinese cucumber,Couchgrass,Echinacea,European elder,Faba bean,Frankincense,Gardenia,Ginkgo,Goldenseal,Goldthread,Henbane,Horseradish tree,Horsetail,Jamaica dogwood,Marijuana,Oakgall,Poison hemlock,Saffron,Sassafras,Snakeroot,Sweet marjoram,Thyme,Turmeric,Wall germander,Wheat,Winged bean,Wormwood,Zedoary,Fig,Broccoli,European pennyroyal,Mustard,Papaya,Thuja
# ---- disease group: respiratory_disease
# Asafetida,Banana,Bayberry,Blackberry,Bloodroot,Borage,Chebulic myrobalan,Dong quai,Dyers woad,Ephedra,Fennel,Ginger,Lemonbalm,Lobelia,Malabar nut,Marijuana,Meadowsweet,Nux vomica,Oregon grape,Water germander,Hops,Wintergreen,Borrachero,Black haw,Cat's claw,Bee balm,Pygeum
# ---- disease group: gastrointestinal_disease
# ...

# %%
from matplotlib_venn import venn2, venn2_circles
from matplotlib_venn import venn3, venn3_circles

# %% [markdown]
# ## random select only 3 groups for venn plot, rerun the cell if gives error (that's because the selected group has no overlap) ##

# %%
group_ids_venn3 = random.sample(group_ids,3)    

def plot_venn3(group2minsetdf,group_ids):
    setsize_dict = {}
    set_dict = {}
    groups = []
    minsets = []
    for i in group_ids:
        group_name = disease_groups[i].replace('_disease','')
        groups.append(group_name)
        minsets.append(set(group2minsetdf[group_name]['spices']))
    #print(minsets)

    set_dict['100'] = minsets[0]
    setsize_dict['100'] = len(set_dict['100'])
    set_dict['010'] = minsets[1]
    setsize_dict['010'] = len(set_dict['010'])
    set_dict['001'] = minsets[2]
    setsize_dict['001'] = len(set_dict['001'])
    set_dict['111'] = minsets[0].intersection(minsets[1]).intersection(minsets[2])
    if not set_dict['111']:
        setsize_dict['111'] = len(set_dict['111'] )
    set_dict['110'] = minsets[0].intersection(minsets[1]) - set_dict['111']
    setsize_dict['110'] = len(set_dict['110'])
    set_dict['101'] = minsets[0].intersection(minsets[2]) - set_dict['111']
    setsize_dict['101'] = len(set_dict['101'])
    set_dict['011'] = minsets[1].intersection(minsets[2]) - set_dict['111']
    setsize_dict['011'] = len(set_dict['011'])

    print(set_dict['111'])
    
    
    v3 = venn3(subsets = {k: v for k, v in setsize_dict.items() if v},
           set_labels = ('', '', '','','',''))
    
#     v3.get_patch_by_id('100').set_color('mediumturquoise')
#     v3.get_patch_by_id('010').set_color('olivedrab')
#     v3.get_patch_by_id('001').set_color('yellowgreen')#mediumseagreen
#     v3.get_patch_by_id('110').set_color('cadetblue')#
#     v3.get_patch_by_id('101').set_color('paleturquoise')
#     v3.get_patch_by_id('011').set_color('palegreen')
#     v3.get_patch_by_id('111').set_color('grey')
    
    v3.get_patch_by_id('100').set_color('steelblue') #skyblue,mediumturquoise
    v3.get_patch_by_id('010').set_color('lightseagreen') # steelblue,cornflowerblue, darkturquoise
    v3.get_patch_by_id('001').set_color('skyblue') #lightseagreen,skyblue
    v3.get_patch_by_id('110').set_color('greenyellow')#limegreen
    v3.get_patch_by_id('101').set_color('greenyellow')
    v3.get_patch_by_id('011').set_color('greenyellow')

    
    v3.get_label_by_id('100').set_text('           %s disease\n\n%d'%(groups[0].capitalize(),setsize_dict['100']))
    v3.get_label_by_id('010').set_text('%s disease\n\n%d'%(groups[1].capitalize(),setsize_dict['010']))
    v3.get_label_by_id('001').set_text('%s disease\n\n%d'%(groups[2].capitalize(),setsize_dict['001']))
    v3.get_label_by_id('110').set_text('\n '.join(set_dict['110']))
    v3.get_label_by_id('101').set_text('\n  '.join(set_dict['101']))
    v3.get_label_by_id('011').set_text('\n         '.join(set_dict['011']))
    if not set_dict['111']:  
        v3.get_patch_by_id('111').set_color('orange') #lawngreen, lemonchiffon
        v3.get_label_by_id('111').set_text('\n'.join(set_dict['111']))
    for j in range(len(v3.subset_labels)):
        text = v3.subset_labels[j]
        if j in [2,6,4,5]:
            try:
                text.set_fontsize(14)
                text.set_color('darkgreen') #darkgreen,forestgreen,darkolivegreen
            except:
                continue
        else:
            text.set_fontsize(19)
            text.set_color('royalblue')#midnightblue,royalblue,mediumslateblue,mediumblue,slateblue,royalblue
    plt.savefig(plot_folder + 'venn3_%s'%'_'.join(groups)+'.png')
    plt.show()

plt.figure(figsize=(18, 18))
plot_venn3(group2minsetdf,group_ids_venn3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-f1ebd9cad3e8> in <module>
#       1
# ----> 2 group_ids_venn3 = random.sample(group_ids,3)
#       3
#       4 def plot_venn3(group2minsetdf,group_ids):
#       5     setsize_dict = {}
#
# NameError: name 'group_ids' is not defined

# %% [markdown]
# ## upset plot for randomly selected 6 disease group or using this link:

# %%
import pyupset as pyu
pyu.plot(group2minsetdf, inters_size_bounds=(1,5)) 
#query = [('infectious_disease', 'cardiovascular_disease'), ('gastrointestinal_disease', 'respiratory_disease')]
plt.autoscale()
plt.savefig(plot_folder + 'group2minset_upset.png')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-12-5e4d7fbe3afe> in <module>()
# ----> 1 import pyupset as pyu
#       2 pyu.plot(group2minsetdf, inters_size_bounds=(1,5))
#       3 #query = [('infectious_disease', 'cardiovascular_disease'), ('gastrointestinal_disease', 'respiratory_disease')]
#       4 plt.autoscale()
#       5 plt.savefig(plot_folder + 'group2minset_upset.png')
#
# ImportError: No module named 'pyupset'

# %% [markdown]
# ### Generate upset input csv below, and use upset webtool: https://gehlenborglab.shinyapps.io/upsetr/

# %%
import csv 
upset_items = []
upset_groups = list(group2minsetdf.keys())
upset_items.append('Name,' + ','.join(upset_groups))
unique_spices = []
for group, minsetdf in group2minsetdf.items():
    unique_spices.extend(list(minsetdf['spices']))
unique_spices = list(set(unique_spices))

for s in unique_spices:
    indicator = [s]
    for g in upset_groups:
        if s in list(group2minsetdf[g]['spices']):
            indicator.append('1')
        else:
            indicator.append('0')
    upset_items.append(','.join(indicator))  # format: 'spice,0,1,0,0,0,1'

upset_df = pd.DataFrame(upset_items)
upset_df.to_csv(plot_folder+'upset_input.csv',header=False,index=False)

# %%
## spices common across sets covering different categories of diseases

spice_allset=[]
for row in results_pd['Min set']:
    spice_allset.extend(row)
count_spices = Counter(spice_allset)
plt.figure(figsize= [18,10])
temp = pd.Series(count_spices)
temp.sort_values(ascending=False)
temp= temp[temp>5].sort_values(ascending = False)
temp.plot(kind='bar')
plt.savefig(result_folder+'Spice_common_sets_groups.png')
plt.show()

# %%
# Generate Min Set Cover for all Indications

bi_graph_all, spice_topset_all, indic_botset_all = Bipartite_graph(spice2indic, set_name)
adjmtx_all = bipartite.biadjacency_matrix(bi_graph_all, row_order=indic_botset_all, column_order=spice_topset_all).toarray()

n2 = adjmtx_all.shape[1]
c = np.hstack([np.ones(n2), [0]])
min_coverset_optim_all = Min_cover_set(spice2indic, spice_topset_all, indic_botset_all, adjmtx_all, c)
min_coverset_greedy_all = Min_cover_set_greedy(spice2indic, indic2spice)

print('Set difference btw Greedy and Optimization approach: ', set(min_coverset_optim_all).difference(set(min_coverset_greedy_all)))
print('Min cover set by optimization:', len(min_coverset_optim_all))
print('Min cover set by greedy:', len(min_coverset_greedy_all))


results_pd.loc['all', '#Spices'] = adjmtx_all.shape[1]
results_pd.loc['all', '#Indications'] = adjmtx_all.shape[0]
results_pd.loc['all', 'Min number of spices to cover indications'] = len(min_coverset_optim_all)
results_pd.loc['all', 'Min set'] = min_coverset_optim_all

# %%
results_pd.to_csv(result_folder+ 'Min set cover results_groups.csv')

# %%
dict2json(min_coverset_optim_all, result_folder+ 'MinSetCover_spice_all.json')

# %%
## spices common across sets covering different categories of diseases

spice_allset=[]
for row in results_pd['Min set']:
    spice_allset.extend(row)
count_spices = Counter(spice_allset)
temp = pd.Series(count_spices)
temp.sort_values(ascending=False)
temp= temp[temp>5].sort_values(ascending = False)
plt.figure(figsize= [18,10])
temp.plot(kind='bar')

plt.savefig(result_folder+ 'Spice_common_sets_groups.png',bbox_inches = "tight")

# %% [markdown]
# ## Trash Below ##

# %%
#result_folder = 'Derived_Data/MinSetCover/'
import pyupset as pyu
from pickle import load
with open('test_data_dict.pckl', 'rb') as f:
    data_dict = load(f)
# pyu.plot(data_dict)
pyu.plot(data_dict, unique_keys = ['title'], 
#          additional_plots=[{'kind':'scatter', 'data_quantities':{'x':'views', 'y':'rating_std'}},
#                            {'kind':'hist', 'data_quantities':{'x':'views'}}],
         query = [('adventure', 'action'), ('romance', 'war')]
        )

# %%
pyu.plot(data_dict, unique_keys = ['title'], 
        additional_plots=[{'kind':'scatter', 
                           'data_quantities':{'x':'views', 'y':'rating_std'},
                           'graph_properties':{'alpha':.8, 'lw':.4, 'edgecolor':'w', 's':50}},
                          {'kind':'hist', 
                           'data_quantities':{'x':'views'},
                           'graph_properties':{'bins':50}}], 
        query = [('adventure', 'action'), ('romance', 'war')])

# %%
import pickle
with open('group2minsetdf.pickle', 'wb') as handle:
    pickle.dump(group2minsetdf, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
from upsetplot import generate_counts
example = generate_counts()
example  # doctest: +NORMALIZE_WHITESPACE

# %%
from upsetplot import plot
plot(example)  # doctest: +SKIP
from matplotlib import pyplot
pyplot.show()  # doctest: +SKIP

# %%
# TRASH
'''
#OPTIMIZATION Approach (moved to MinSetCover.py file)

def Min_cover_set(dict_data, top_set,bot_set, adjmtx):
    import time
    start = time. time()
    n1 = adjmtx.shape[0]
    n2 = adjmtx.shape[1]
    a = ones((1,n1))[0]
    x_min = 0
    x_max = 1
    c = hstack([ones(n2), [0]])
    G1 = zeros((n1,n2 + 1))
    G1[0:n1, 0:n2] = -adjmtx
    G1[:, n2] = -zeros(n1)
    h1 = -a
    x_min = x_min * ones(n2)
    x_max = x_max * ones(n2)

    G2 = vstack([
            hstack([+eye(n2), zeros((n2, 1))]),
            hstack([-eye(n2), zeros((n2, 1))])])
    h2 = hstack([x_max, -x_min])

    c = cvxopt.matrix(c)

    G = cvxopt.matrix(vstack([G1, G2]))
    h = cvxopt.matrix(hstack([h1, h2]))

    (status, sol) = ilp(c,   # c parameter
                        G,     # G parameter
                        h,     # h parameter
                        I=set(range(0, len(c))))
    end = time. time()
    count = 0
    
    # confirm all indications are covered:
    indications_covered = []
    min_coverset = []
    for i in range(len(sol)):
        if sol[i] > 0 :
            count += 1
            min_coverset.append(list(top_set)[i])
            indications_covered.extend(dict_data[list(top_set)[i]])
            sh = list(top_set)[i]
    indications_coverset = set(indications_covered)
    print('All indications are covered: ', len(indications_coverset) == len(bot_set))
    return min_coverset
'''

# %%
'''
# GREEDY Approach (moved to MinSetCover.py file)

# input: dict_data, dict_data_reverse,
# dict_data: {spice/herb: indication list}; dict_data_reverse: {indication: spice/herb list}
    
def Min_cover_set_greedy(dict_data, dict_data_reverse):
    freq_dict_spiceherb = {}
    for s in dict_data.keys():
        freq_dict_spiceherb.update({s: len(dict_data[s])})
    # indication nodes list in order (sorted from node with least spice/herb connection to one with most)
    Bi_indic_sorted = sorted(dict_data_reverse, key = lambda k : len(dict_data_reverse[k]), reverse = False) 
    indic_visited = []
    min_cover = [] # list of spice/herb that could cover all indications
    for indic in Bi_indic_sorted:
        if indic not in indic_visited:
            sub_freq_dict = {s: freq_dict_spiceherb[s] for s in dict_data_reverse[indic]}
            
            # for each spice/herb, update the freq as (original freq - num_overlap with indic_visited)
            for s in sub_freq_dict.keys():
                num_overlap = len(list(set(indic_visited).intersection(set(dict_data[s]))))
                sub_freq_dict[s] = sub_freq_dict[s] - num_overlap

            sub_freq_sorted = sorted(sub_freq_dict.items(), key = lambda p: p[1], reverse= True)  # sorted by value(freq) from high to low
            
            # if the spice/herb with highest freq already in min_cover, skip this indication 
            # if the highest freq spice/herb already in min_cover, means this indication already be visited, so could exclude above step       
            min_cover.append(sub_freq_sorted[0][0])
            indic_visited.extend(dict_data[sub_freq_sorted[0][0]])
            indic_visited = list(set(indic_visited))
    return min_cover
'''

# %%
'''
# Generate Grouped Cause2Indic and Grouped Indic2Spice
code2cause2indic_df = pd.read_excel('../Crawlers/OtherData/Cause2Indication.xlsx',sheet_name = 'Sheet1')
start_idx = 0
cause2indic_grouped = {}
for row in code2cause2indic_df.iterrows():
    idx = row[1]['Causes with Code'].split(' ')[0].split('.')[1]
    cause = row[1]['Causes']
    indic_list = row[1]['Indications'].split(', ') 
    if idx != start_idx:
        if idx == '3':
            main_cause = 'Chronic respiratory diseases'
        elif idx == '10':
            main_cause = 'Other non-communicable diseases'
        elif idx == '8':
            main_cause = 'Diabetes, urogenital, blood, and endocrine diseases'
        else:
            main_cause = cause
        cause2indic_grouped.update({main_cause:{}})  # the first of each idx is the main cause (as category name)
        start_idx = idx
    cause2indic_grouped[main_cause].update({cause:indic_list})

disease_groups = list(cause2indic_grouped.keys())
print(disease_groups)

spice2indic_all = json2dict('Derived_Data/Spice2Phytochemical2Disease/spice2indic_phytononzero.json')# March 21, 2020. this has reduced no of spices, earlier we were using  spiceherb_indication_dict.json


indic2spice_all = reverse_dict(spice2indic_all)

# indications2spice sorted by groups defined by GBD
indic2spice_grouped = {}
for group in disease_groups:
    #print(group)
    indic_list = set(list(chain.from_iterable(cause2indic_grouped[group].values())))
    indic_spice = {}
    for indic in indic_list: 
        if indic in indic2spice_all.keys(): # March 21, 2020. Because no of spices has been reduced to 721, it is possible that some indications are not present anymore
            indic_spice.update({indic:indic2spice_all[indic]}) # March 21, 2020
    indic2spice_grouped.update({group:indic_spice})   
    
dict2json(cause2indic_grouped, result_folder+ 'cause2indic_grouped.json')
dict2json(indic2spice_grouped, result_folder+ 'indic2spicehnd_grouped.json')
'''

# %%
'''
# read category from lav
xls = pd.ExcelFile('Derived_Data/MinSetCover/indic_categorized_lav.xlsx')
data = xls.parse(xls.sheet_names[0])
#print(data)
def unify_name(name):
    name = name.split('(')[0].rstrip().replace("-", "").lower().capitalize().rstrip(',')
    comma_split = name.split(',')
    if comma_split:
        name = ','.join([word.rstrip().lstrip() for word in name.split(',')])
    name = ' '.join(name.split())
    return name
indic_names = [unify_name(name) for name in data['Indication']]
category_names = data['Category']
indic2category = dict(zip(indic_names, category_names))
indic2category_df = pd.DataFrame(indic2category.items(), columns=['Indication', 'Category'])
#print(indic2category_df)
indic2category_df.to_excel('Derived_Data/MinSetCover/indic_categorized_lav.xlsx')
#print(indic2category)
'''

# %%
'''

indic2group = {}
for group, subgroup2indic in cause2indic_grouped.items():
    indic2subgroup = reverse_dict(subgroup2indic)
    for indic, subgroup in indic2subgroup.items():
        if indic not in indic2group.keys():
            indic2group.update({indic: {'Subcategory': ';'.join(subgroup), 'Category': group}})
indic_all = json2dict("Handbook_Data/indic_all.json")
indic2group_data = []
c = 0
for indic in indic_all:
    if indic in indic2group.keys():
        c += 1
        indic2group_data.append({"Indication": indic, "Category": indic2group[indic]["Category"], "Subcategory": indic2group[indic]["Subcategory"]})
    elif indic in indic2category.keys():
        indic2group_data.append({"Indication": indic, "Category": indic2category[indic], "Subcategory":''})
    else:
        indic2group_data.append({"Indication": indic, "Category": '', "Subcategory":''})
indic2group_df = pd.DataFrame(indic2group_data, columns=["Indication", "Category", "Subcategory"])
indic2group_df.to_excel("Handbook_Data/indic_all_categorized.xlsx")
print("# indications with category: ", c)
'''
