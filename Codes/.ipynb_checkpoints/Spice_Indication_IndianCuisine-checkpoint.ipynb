# %%
# CORRECT
import json
import pandas as pd
from collections import Counter
from Graph_Helpers import *
import seaborn as sns
import itertools

from scipy.spatial.distance import cdist
from sklearn.decomposition import PCA

from adjustText import adjust_text
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

from mpl_toolkits.axes_grid1 import make_axes_locatable
import numpy as np
from collections import Counter

# %%
import sys
sys.version
# Out:
# '3.5.6 |Anaconda, Inc.| (default, Aug 26 2018, 16:05:27) [MSC v.1900 64 bit (AMD64)]'

# %%
spice_source = 'handbook' # handbook use 'tarla' to understand cuisines and 'handbook' for spice-indication analysis
include_random = False

result_folder = 'Derived_Data/Spice_Indication_IndianCuisine_new/'

# %%
def myplot(score,coeff,label_sample, labels=None, dist = 'euclidean'):
    from scipy.spatial.distance import cdist
    pc_ob=[0,1]
    print('score shape', score.shape)
    xs = score[:,pc_ob[0]]
    ys = score[:,pc_ob[1]]
    n = coeff.shape[0]
    #scalex = 1.0/(xs.max() - xs.min())
    #scaley = 1.0/(ys.max() - ys.min())
    #plt.scatter(xs * scalex,ys * scaley)
    plt.scatter(xs ,ys )
    dist = cdist(coeff[:,pc_ob], [(0,0)], dist)
    distcomp= np.sort(dist, axis=0)[::-1][26]# plot top 30 loadings
    textall=[]
    #print(n)
    for i in range(n):
        if dist[i]> distcomp:
            plt.arrow(0, 0, coeff[i,0], coeff[i,1],color = [0.1, 0.2, 0.3],alpha = 0.5)
            if labels is None:
                plt.text(coeff[i,0]* 1.0, coeff[i,1] * 1.0, "Var"+str(i+1), color = 'g', ha = 'center', va = 'center')
            else:
                textall.append(plt.text(coeff[i,pc_ob[0]]* 1.0, coeff[i,pc_ob[1]] * 1.0, labels[i], color = 'g', ha = 'center',
                                        va = 'center', 
                         fontsize=12))
    adjust_text(textall)
    
    textall=[]

    for i in range( len(label_sample)):
        textall.append(plt.text(xs[i]*1, ys[i]*1, label_sample[i], fontsize=14))
    adjust_text(textall)
    #plt.xlim(-1,1)
    #plt.ylim(-1,1)
    plt.xlabel("PC{}".format(pc_ob[0]+1), fontsize= 14)
    plt.ylabel("PC{}".format(pc_ob[1]+1), fontsize=14)
    plt.grid()
    
    
    
def plot_heatmap(val_arr,idx_list, col_list, cmap, title, savefig_name):
    #plt.figure(figsize=(16,10))
    ax = plt.gca()
    im = ax.imshow(val_arr, cmap = cmap)

    ax.set_xticks(np.arange(len(idx_list)))
    ax.set_yticks(np.arange(len(col_list)))
    print(len(idx_list))
    print(len(col_list))
    # label with the respective list entries
    ax.set_xticklabels(idx_list)
    ax.set_yticklabels(col_list)

    # Rotate the tick labels and set alignment.
    plt.setp(ax.get_xticklabels(), rotation=90, ha="right",
             rotation_mode="anchor")
    ax.set_title(title)

    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="2%", pad=0.08)

    plt.colorbar(im, cax=cax)
    plt.show()
    #plt.savefig(result_folder+ savefig_name)
    
    
def region2spiceingre_heatmap(region2recipecount, region2cuisinerecipe, cuisinerecipe2spiceingre):
    region2spiceingre = {}
    for region, cuisine_list in region2cuisinerecipe.items():
        spiceingre_list = []  # list of spiceingre per region
        for cuisine in cuisine_list: 
            if cuisine in cuisinerecipe2spiceingre.keys():  # some cuisinerecipe occur in region2cuisinerecipe dict
                                                            #    but not cuisinerecipe2spiceingre dict
                spiceingre_list.extend(cuisinerecipe2spiceingre[cuisine]) 
        count_dict = Counter(spiceingre_list) # count dict of spiceingre per region
        for spice in count_dict.keys():
            count_dict[spice] = count_dict[spice]/region2recipecount[region]
        region2spiceingre.update({region : count_dict}) 
    return region2spiceingre

# %%
# Combined recipes
# READ COMBINED DICT

# cuisine_spicehnd_dict_combined.json contains spice names as mapped in the handbook
#cuisinerecipe2spicerecipe_combined.json contains spice names as in the tarla dalal


if spice_source == 'tarla':
    cuisinerecipe2spiceingre_combined = json2dict('Derived_Data/Overlap/cuisinerecipe2spicerecipe_combined.json') # changed 12.03.2020 from cuisinerecipe2spicerecipe_combined.json
elif spice_source == 'handbook':
    cuisinerecipe2spiceingre_combined = json2dict('Derived_Data/Overlap/cuisine_spicehnd_dict_combined.json')
    
    
    
region2cuisinerecipe_combined = json2dict('Derived_Data/Overlap/region2cuisinerecipe_combined.json')

cuisinerecipe2region_combined = reverse_dict(region2cuisinerecipe_combined)
region2recipecount_combined = dict2countdict(region2cuisinerecipe_combined, region2cuisinerecipe_combined.keys())

# %%
list(region2cuisinerecipe_combined.keys())
# Out:
# ['Mughlai',
#  'Bengali',
#  'Rajasthani',
#  'Andhra',
#  'Uttar Pradesh',
#  'Goan',
#  'Punjabi',
#  'Kashmiri',
#  'Maharashtrian',
#  'Gujarati',
#  'Kerala',
#  'Karnataka',
#  'Tamil Nadu',
#  'Parsi',
#  'Hyderabadi',
#  'Sindhi',
#  'Jain',
#  'South Indian']

# %%
#randomrecipe2spiceingre

# %%
# # we will add random recipe data set as well in the combined data
# #randrecipe_file = 'Derived_Data/CopyMutate/random_recipe_uniform.json'
# randrecipe_file = 'Derived_Data/CopyMutate/cm_randfreq_recipes.json'
# if include_random == True:
#     randomrecipe2spiceingre = json2dict(randrecipe_file)[2]
    
#     cuisinerecipe2spiceingre_combined.update(randomrecipe2spiceingre) # append to Indian cuisine dictionary
#     region2recipecount_combined['Random'] = len(randomrecipe2spiceingre)
#     region2cuisinerecipe_combined['Random'] = list(randomrecipe2spiceingre.keys())

# # Combined 
# region2spiceingre_combined_hm = region2spiceingre_heatmap(region2recipecount_combined, region2cuisinerecipe_combined, 
#                                                           cuisinerecipe2spiceingre_combined)

# %%
# we will add random recipe data set as well in the combined data
#randrecipe_file = 'Derived_Data/CopyMutate/random_recipe_uniform.json'

if include_random == True:
    #Convert from rand recipe2spicerecipe ---> rand recipe2spicehnd
    spicerecipe2spicehnd = json2dict('Derived_Data/Overlap/spicetarla_spicehnd_dict.json') 
    def to_recipe2spicehnd(recipe2spicerecipe):
        recipe2spicehnd = {} 
        for r, s_list in recipe2spicerecipe.items():
            spicehnd_list = []
            for s in s_list:
                spicehnd_list.extend(spicerecipe2spicehnd[s])
            recipe2spicehnd[r] = list(set(spicehnd_list))
        return recipe2spicehnd
    
    recipe2spicerecipe_uniform = to_recipe2spicehnd(json2dict('Derived_Data/CopyMutate/cm_randuniform_recipes.json')[2])   # cm uniform
    recipe2spicerecipe_freq = to_recipe2spicehnd(json2dict('Derived_Data/CopyMutate/cm_randfreq_recipes.json')[2]) # cm freq conserve
    #recipe2spicerecipe_rand = to_recipe2spicehnd(json2dict('Derived_Data/CopyMutate/randomuniform_recipes.json'))  # random uniform 
    recipe2spicerecipe_freq = {'freq' + k: v for k,v in recipe2spicerecipe_freq.items()}
    
    cuisinerecipe2spiceingre_combined.update(recipe2spicerecipe_uniform) # append to Indian cuisine dictionary
    cuisinerecipe2spiceingre_combined.update(recipe2spicerecipe_freq)
    
    #cuisinerecipe2spiceingre_combined.update(recipe2spicerecipe_rand)
    
    region2recipecount_combined['Copy-Mutate Uniform'] = len(recipe2spicerecipe_uniform)
    region2cuisinerecipe_combined['Copy-Mutate Uniform'] = list(recipe2spicerecipe_uniform.keys())
    region2recipecount_combined['Copy-Mutate Frequency-Conserve'] = len(recipe2spicerecipe_freq)
    region2cuisinerecipe_combined['Copy-Mutate Frequency-Conserve'] = list(recipe2spicerecipe_freq.keys())
    
    #region2recipecount_combined['Random Uniform'] = len(recipe2spicerecipe_rand)
    #region2cuisinerecipe_combined['Random Uniform'] = list(recipe2spicerecipe_rand.keys())
    


# Combined 
region2spiceingre_combined_hm = region2spiceingre_heatmap(region2recipecount_combined, region2cuisinerecipe_combined, 
                                                          cuisinerecipe2spiceingre_combined)

# %%
# Combined 
region2spiceingre_df_combined = pd.DataFrame(region2spiceingre_combined_hm).fillna(0)
region2spiceingre_df_combined.sort_index(ascending=True)
region2spiceingre_df_combined = region2spiceingre_df_combined.reindex(sorted(region2spiceingre_df_combined.columns), axis=1)
#region2spiceingre_df_combined.to_excel(result_folder + 'region2spiceingre_countdict_combined.xlsx')
print('Combined spiceingre ', len(region2spiceingre_df_combined.index))
print('Combined regions: ', len(region2spiceingre_df_combined.columns))
# Out:
# Combined spiceingre  105
# Combined regions:  18

# %%
from statistics import mean
recipe_len = [len(i) for i in cuisinerecipe2spiceingre_combined.values()]

plt.hist(recipe_len)
mean(recipe_len), min(recipe_len), max(recipe_len)
# Out:
# (7.849538679914833, 1, 38)

# %% [markdown]
# Sanj spiceingre  57
# Sanj regions:  27
# Tarla spiceingre  82
# Tarla regions:  9

# %%
# Plot heatmap for region-spiceingre mapping for both Tarla and Sanjeev
plt.figure(figsize=(20,10))
plot_heatmap(region2spiceingre_df_combined.values.T, list(region2spiceingre_df_combined.index) , list(region2spiceingre_df_combined.columns), sns.cm.rocket_r, 'Cuisine Style - Spice Ingredient Heat Map (based on Tarla + Sanjeev)', 'region2spiceingre_heatmap_combined.png')
# Out:
# 105
# 18

# %%
region2spiceingre_df_combined
# Out:
#                   Andhra   Bengali      Goan  Gujarati  Hyderabadi      Jain  \
# ajowan          0.019231  0.007168  0.025641  0.057043    0.017647  0.031746
# allspice        0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# almond          0.000000  0.082437  0.012821  0.062864    0.123529  0.038095
# angelica        0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# anise           0.000000  0.021505  0.000000  0.000000    0.000000  0.003175
# apple           0.000000  0.017921  0.000000  0.012806    0.023529  0.034921
# apricot         0.000000  0.003584  0.000000  0.000000    0.011765  0.000000
# arrowroot       0.000000  0.007168  0.000000  0.010477    0.005882  0.000000
# asafetida       0.230769  0.121864  0.038462  0.426077    0.052941  0.377778
# asparagus       0.000000  0.000000  0.000000  0.000000    0.000000  0.006349
# avocado         0.000000  0.000000  0.000000  0.000000    0.000000  0.003175
# ...

# %%
#region2spiceingre_df_combined['Random'].mean()

# %% [markdown]
# # Spice-Indication analysis

# %%
## read spice2indication file. 

# spiceherb_indication.json contains all spices/herbs, codes line for it is labeeld as 1
#spice2ind = json2dict("../Crawlers/phytochemicals/spiceherb_indication.json") 
spice2ind = json2dict("Derived_Data/Spice2Phytochemical2Disease/spice2indic2score_phytononzero.json") 



# "spice2indic_phytononzero.json" contains spices and herbs with non-zero phytochemical activity, code lines tagged as 2

#spice2ind = json2dict("Derived_Data/Spice2Phytochemical2Disease/spice2indic_phytononzero.json")

spice2ind =  {k.lower(): v for k, v in spice2ind.items()} # only for 2

# %%
#list(spice2ind.items())[:1]

# %%
# list(spice2ind['grains  of  paradise'].keys()) # 1

list(spice2ind['guinea grains']) #2
# Out:
# ['Worm',
#  'Blennorrhagia',
#  'Tooth ache',
#  'Wound',
#  'Headache',
#  'Constipation',
#  'Earach',
#  'Smallpox']

# %%
spice_cuisine = region2spiceingre_df_combined.index # names of spices present in Indian cuisines

print('no of spices/herbs in handbook and phytochemicals {}, no of spices in Indian cuisine {}'.format(
    len(spice2ind.keys()), len(spice_cuisine)))

spice_cuisine_found = set(spice2ind.keys()) & set(spice_cuisine) 

print('overlap between cuisine spice and spice handbook', len(spice_cuisine_found))
# Out:
# no of spices/herbs in handbook and phytochemicals 742, no of spices in Indian cuisine 105
# overlap between cuisine spice and spice handbook 98

# %%
print('Indian spices not found in handbook', set(spice_cuisine) -spice_cuisine_found)
# Out:
# Indian spices not found in handbook {'rose petals', 'olive oil', 'indian cassia', 'nepalese cardamom', 'curryleaf', 'bottle gourd', 'oak'}

# %% [markdown]
# #### distribution of indications

# %%
indication_list = [] # find unique indications
for spice in spice_cuisine_found:
    indication_list.extend(spice2ind[spice].keys())

ind_count = pd.DataFrame(data = indication_list, columns = ['indication']).groupby('indication') # find count of indications
#plt.figure(figsize=(20,10))
ind_count.apply(lambda x: len(x)).sort_values(ascending = False)[:20].plot.bar()

# %%
indic2spice_grouped = json2dict('Derived_Data/MinSetCover/group2indic2spice.json') # read the disease category to indications mapping

indication_group_Indian_dict = {}
temp_dict = {}

for group in indic2spice_grouped.keys():
    print(group)
    temp_dict[group] = list(indic2spice_grouped[group].keys())

ind_group_dict = reverse_dict(temp_dict)

for indication in indication_list:
    if indication in ind_group_dict.keys():
        indication_group_Indian_dict[indication] = ind_group_dict[indication][0]
    else:
        
        indication_group_Indian_dict[indication] = 'NotLabelled'

        
l= list(indication_group_Indian_dict.values())

colors = sns.husl_palette(len(set(l)), s=.45)

cat2color = dict(zip(map(str, set(l)), colors))
cat2color['NotLabelled'] = [1,1,1]
col_colors = pd.Series(l, index=list(indication_group_Indian_dict.keys())).map(cat2color)
# Out:
# endocrine_disease
# neuronal_disease
# injury
# infectious_disease
# cardiovascular_disease
# ear_disease
# oral_disease
# gastrointestinal_disease
# sleep_disease
# eye_disease
# nutritional_disease
# smell_taste_disease
# musculoskeletal_disease
# nephrological_disease
# respiratory_disease
# General symptom
# othercauses
# reproductive_disease
# skin_disease
# genetic_disease
# general_disease
# blood_disease
# poisoning
# metabolic_disease
# mental_disease
# pregnancy_disease
# cancer_disease
# immune_disease

# %%
# find the diseases covered by indian cuisne. It doesnt take into account the weights of spices usage
count_dict_indication = {}

for i in indication_list:
    cat = indication_group_Indian_dict[i]
    if cat in count_dict_indication.keys():
        count_dict_indication[cat]+=1
    else:
        count_dict_indication[cat]=1

count_dict_indication, len(count_dict_indication)
# Out:
# ({'General symptom': 811,
#   'blood_disease': 82,
#   'cancer_disease': 681,
#   'cardiovascular_disease': 200,
#   'ear_disease': 44,
#   'endocrine_disease': 75,
#   'eye_disease': 97,
#   'gastrointestinal_disease': 872,
#   'general_disease': 16,
#   'immune_disease': 62,
#   'infectious_disease': 1179,
#   'injury': 100,
#   'mental_disease': 241,
#   'metabolic_disease': 60,
#   'musculoskeletal_disease ': 261,
#   'nephrological_disease': 242,
#   'neuronal_disease': 249,
#   'nutritional_disease': 28,
#   'oral_disease': 2,
#   'othercauses': 14,
#   'poisoning': 42,
#   'pregnancy_disease': 42,
#   'reproductive_disease': 238,
#   'respiratory_disease': 514,
#   'skin_disease': 307,
#   'sleep_disease': 35,
#   'smell_taste_disease': 5},
#  27)

# %% [markdown]
# ### create dataframe of spice and indications.

# %%
indication_list = list(set(indication_list))   # unique indications

#create dataframe with Indian spices found as rows and indications as columns 

spice2ind_cuisine = pd.DataFrame(0, index =spice_cuisine_found  , columns= indication_list)
for spice in spice2ind_cuisine.index:
    for ind in spice2ind[spice].keys():
        spice2ind_cuisine.loc[spice, ind] =1
    
spice2ind_cuisine
# Out:
#                 Cancer,duodenum  Fracture  Pinworm  Urticaria  \
# oats                          0         0        0          0
# saffron                       0         0        0          0
# allspice                      0         0        0          0
# dill                          0         0        0          0
# avocado                       0         0        0          0
# pumpkin                       0         0        0          0
# bayleaf                       0         0        0          0
# ivy                           0         0        0          0
# ajowan                        0         0        0          0
# lovage                        0         0        0          0
# caraway                       0         0        0          0
# guava                         0         0        0          0
# castor                        0         0        0          0
# pigeonpea                     0         0        0          0
# ...

# %%
temp = spice2ind_cuisine.loc['cardamom', :]>0
temp[temp== True]
# Out:
# Cramp                True
# Water retention      True
# Cancer,stomach       True
# Congestion           True
# Biliousness          True
# Gastrosis            True
# Enterosis            True
# Enuresis             True
# Infection            True
# Fever                True
# Morning sickness     True
# Anorexia             True
# Spermatorrhea        True
# Diarrhea             True
# Pain                 True
# Roemheld syndrome    True
# Bleeding             True
# Urethrosis           True
# Hyperacidity         True
# Alcoholism           True
# Cancer,spleen        True
# Uterosis             True
# Hepatosis            True
# Dermatosis           True
# Constipation         True
# Vomiting             True
# Cough                True
# Cancer,abdomen       True
# Cancer,liver         True
# Dyspepsia            True
#                      ...
# Cholecystosis        True
# Cystosis             True
# Headache             True
# Catarrh              True
# ...

# %% [markdown]
# ### find common spices in cuisine-spice ans spice-indication matrix and sort spice names

# %%
# spice2indication

#Indian Spices X indication matrix

temp  = set(region2spiceingre_df_combined.index) - set(spice2ind_cuisine.index)
region2spice_final = region2spiceingre_df_combined.T.drop(columns = temp).sort_index(axis=1)

region2spice_final
# Out:
#                  ajowan  allspice    almond  angelica     anise     apple  \
# Andhra         0.019231  0.000000  0.000000  0.000000  0.000000  0.000000
# Bengali        0.007168  0.000000  0.082437  0.000000  0.021505  0.017921
# Goan           0.025641  0.000000  0.012821  0.000000  0.000000  0.000000
# Gujarati       0.057043  0.000000  0.062864  0.000000  0.000000  0.012806
# Hyderabadi     0.017647  0.000000  0.123529  0.000000  0.000000  0.023529
# Jain           0.031746  0.000000  0.038095  0.000000  0.003175  0.034921
# Karnataka      0.008000  0.000000  0.024000  0.000000  0.000000  0.024000
# Kashmiri       0.000000  0.000000  0.191489  0.000000  0.148936  0.021277
# Kerala         0.015748  0.000000  0.015748  0.000000  0.007874  0.015748
# Maharashtrian  0.013774  0.000000  0.061983  0.000000  0.001377  0.013774
# Mughlai        0.004762  0.000000  0.152381  0.004762  0.019048  0.042857
# Parsi          0.000000  0.000000  0.019608  0.000000  0.000000  0.000000
# ...

# %%
spice2ind_final = spice2ind_cuisine.sort_index(axis=0)
spice2ind_final
# Out:
#                 Cancer,duodenum  Fracture  Pinworm  Urticaria  \
# ajowan                        0         0        0          0
# allspice                      0         0        0          0
# almond                        0         0        0          0
# angelica                      0         0        0          0
# anise                         0         0        0          0
# apple                         0         0        0          0
# apricot                       0         0        0          0
# arrowroot                     0         0        0          0
# asafetida                     0         1        0          0
# asparagus                     0         0        0          0
# avocado                       0         0        0          0
# banana                        0         0        0          1
# barley                        0         0        0          0
# basil                         0         0        0          0
# ...

# %%
spice2ind_final.shape
X = spice2ind_final.T
print(X.shape)
# Out:
# (733, 98)

# %% [markdown]
# ### Visualise Indian Spice-indication mapping

# %% [markdown]
# ### create cuisine-indication matrix

# %%
#region2spice_final[region2spice_final>0]=1
region2spice_final
# Out:
#                  ajowan  allspice    almond  angelica     anise     apple  \
# Andhra         0.019231  0.000000  0.000000  0.000000  0.000000  0.000000
# Bengali        0.007168  0.000000  0.082437  0.000000  0.021505  0.017921
# Goan           0.025641  0.000000  0.012821  0.000000  0.000000  0.000000
# Gujarati       0.057043  0.000000  0.062864  0.000000  0.000000  0.012806
# Hyderabadi     0.017647  0.000000  0.123529  0.000000  0.000000  0.023529
# Jain           0.031746  0.000000  0.038095  0.000000  0.003175  0.034921
# Karnataka      0.008000  0.000000  0.024000  0.000000  0.000000  0.024000
# Kashmiri       0.000000  0.000000  0.191489  0.000000  0.148936  0.021277
# Kerala         0.015748  0.000000  0.015748  0.000000  0.007874  0.015748
# Maharashtrian  0.013774  0.000000  0.061983  0.000000  0.001377  0.013774
# Mughlai        0.004762  0.000000  0.152381  0.004762  0.019048  0.042857
# Parsi          0.000000  0.000000  0.019608  0.000000  0.000000  0.000000
# ...

# %%
region2ind = region2spice_final.dot(spice2ind_final)
region2ind
# Out:
#                Cancer,duodenum  Fracture   Pinworm  Urticaria  \
# Andhra                0.384615  0.230769  0.500000   0.019231
# Bengali               0.491039  0.125448  0.293907   0.046595
# Goan                  0.602564  0.076923  0.692308   0.012821
# Gujarati              0.470314  0.426077  0.211874   0.053551
# Hyderabadi            0.541176  0.052941  0.752941   0.011765
# Jain                  0.393651  0.380952  0.114286   0.111111
# Karnataka             0.384000  0.336000  0.296000   0.048000
# Kashmiri              0.361702  0.361702  0.234043   0.021277
# Kerala                0.464567  0.181102  0.535433   0.110236
# Maharashtrian         0.466942  0.243802  0.353994   0.024793
# Mughlai               0.304762  0.071429  0.557143   0.023810
# Parsi                 0.568627  0.039216  0.764706   0.078431
# Punjabi               0.436135  0.215089  0.512244   0.009265
# Rajasthani            0.468992  0.360465  0.244186   0.003876
# ...

# %%
region2indcat = pd.DataFrame(columns=count_dict_indication.keys() )

temp = {}
for k, v in indication_group_Indian_dict.items():
    temp[k]= [v]
    
temp = reverse_dict(temp) # get category to indication dictionary

for k,v in temp.items():
    region2indcat[k] = region2ind[v].sum(axis=1)#/(len(v))
    
region2indcat
# Out:
#                endocrine_disease  neuronal_disease  infectious_disease  \
# Andhra                  9.153846         38.653846          151.173077
# Bengali                 7.172043         29.827957          119.103943
# Goan                   10.910256         46.820513          198.000000
# Gujarati                7.097788         30.961583          112.804424
# Hyderabadi             10.870588         51.858824          212.629412
# Jain                    6.650794         28.657143          104.952381
# Karnataka               8.424000         33.832000          135.000000
# Kashmiri                7.957447         40.489362          150.170213
# Kerala                  8.976378         34.937008          145.724409
# Maharashtrian           7.811295         32.735537          133.033058
# Mughlai                 8.261905         39.671429          162.100000
# Parsi                   9.901961         40.294118          180.960784
# ...

# %%
temp['general_disease'] , temp['nephrological_disease']
# Out:
# (['Morning sickness', 'Lethargy', 'Hot flashes', 'Trauma', 'Postmenopause'],
#  ['Incontinence',
#   'Bladderailment',
#   'Gonorrhea',
#   'Anuria',
#   'Oliguria',
#   'Pyelosis',
#   'Extrophy',
#   'Urethrosis',
#   'Pyelonephrosis',
#   'Oxalcrystalluria',
#   'Proteinuria',
#   'Bladder infection',
#   'Ischuria',
#   'High urea',
#   'Nephrosis',
#   'Bladder stone',
#   'Lithuria',
#   'Stone',
#   'Dysuria',
#   'Gravel',
#   'Calculosis',
#   'Hematuria',
#   'Diuretic',
#   'Uti',
#   'Urolithiasis',
#   'Strangury',
#   'Kidney stone',
#   'Urogenitosis',
#   'Uremia'])

# %%
col_colors
cat2color
# Out:
# {'General symptom': [0.6636007146741986,
#   0.6090137395657735,
#   0.4503753158506307],
#  'NotLabelled': [1, 1, 1],
#  'blood_disease': [0.5456867022526374, 0.6426617146508851, 0.4489805987976582],
#  'cancer_disease': [0.8105374844344884, 0.531318383552688, 0.6289367529421919],
#  'cardiovascular_disease': [0.4656528568267165,
#   0.6469017702101729,
#   0.6158722621328957],
#  'ear_disease': [0.4685786997751565, 0.644050472081896, 0.6392382107530813],
#  'endocrine_disease': [0.4625171314937809,
#   0.6499151234436389,
#   0.5897148913862738],
#  'eye_disease': [0.7429581287166294, 0.5796153285284775, 0.45151163537788813],
#  'gastrointestinal_disease': [0.4751921303395708,
#   0.6374608688020513,
#   0.6889594476581863],
#  'general_disease': [0.7272201938931007,
#   0.5475718314541174,
#   0.7882984221400144],
#  'immune_disease': [0.45873249941491884,
#   0.6534946578684273,
#   0.5563450802601999],
#  'infectious_disease': [0.8229959884997893,
#   0.5377798588443925,
# ...

# %%
region2indcat.sum().min()
# Out:
# 0.2131440790118623

# %%
region2indcat.columns

rename_dict= {}
for col in region2indcat.columns:
    rename_dict[col] = col.replace("_disease", "").capitalize()
    
region2indcat.rename(rename_dict, axis='columns', inplace=True )
region2indcat.rename({'Smell_taste' : 'Smell & Taste', 'Othercauses': 'Other causes'}, axis='columns', inplace=True )

region2indcat.drop(columns=['General', 'Injury', 'Other causes'], inplace=True)

# %%
def mapcolor(region2indcat):
    temp = region2indcat.sum()
    temp= (temp-temp.min())/(temp.max()-temp.min())
    col_colors = sns.cm.rocket_r(temp, len(temp)) #rocket_r  # mako
    return col_colors

#plt.figure(figsize=(5,5))
sns.set(font_scale=1.7)

sns.clustermap(region2indcat, cmap= sns.cm.rocket_r,  row_colors = mapcolor(region2indcat.T), figsize= (15,10), linewidth=0.1) #rocket_r, ,, linewidths=0.1 

plt.savefig(result_folder+ 'Indiancuisine_diseases.pdf', format='pdf')
#plt.savefig(result_folder+ 'Indiancuisine_diseases.jpeg', format='jpeg', dpi=600)

plt.show()

# %%
region2ind['Fever']
# Out:
# Andhra           6.134615
# Bengali          5.451613
# Goan             8.474359
# Gujarati         5.202561
# Hyderabadi       9.788235
# Jain             5.212698
# Karnataka        5.776000
# Kashmiri         7.531915
# Kerala           6.220472
# Maharashtrian    5.889807
# Mughlai          7.909524
# Parsi            8.196078
# Punjabi          7.732627
# Rajasthani       6.441860
# Random           6.042200
# Sindhi           6.340909
# South Indian     5.057851
# Tamil Nadu       6.106509
# Uttar Pradesh    6.447368
# Name: Fever, dtype: float64

# %%
region2ind.sum(axis=1)
# Out:
# Andhra            768.519231
# Bengali           637.942652
# Goan              982.166667
# Gujarati          619.582072
# Hyderabadi       1105.264706
# Jain              585.187302
# Karnataka         699.624000
# Kashmiri          843.574468
# Kerala            739.629921
# Maharashtrian     688.987603
# Mughlai           860.542857
# Parsi             914.568627
# Punjabi           877.648577
# Rajasthani        736.821705
# Random            485.275000
# Sindhi            697.931818
# South Indian      600.932704
# Tamil Nadu        739.834320
# Uttar Pradesh     732.850877
# dtype: float64

# %%
region2ind.apply(lambda x: len(x[x>0]), axis=1)
# Out:
# Andhra           589
# Bengali          663
# Goan             622
# Gujarati         701
# Hyderabadi       662
# Jain             710
# Karnataka        616
# Kashmiri         621
# Kerala           629
# Maharashtrian    685
# Mughlai          659
# Parsi            577
# Punjabi          718
# Rajasthani       675
# Random           733
# Sindhi           569
# South Indian     669
# Tamil Nadu       630
# Uttar Pradesh    645
# dtype: int64

# %%
region2ind.T.apply(lambda x: x.idxmax(axis=1)) # find top indication for each cuisine
# Out:
# Andhra           Inflammation
# Bengali             Infection
# Goan                Infection
# Gujarati            Infection
# Hyderabadi          Infection
# Jain                Infection
# Karnataka           Infection
# Kashmiri               Cancer
# Kerala              Infection
# Maharashtrian       Infection
# Mughlai             Infection
# Parsi               Infection
# Punjabi             Infection
# Rajasthani             Cancer
# Random                  Fever
# Sindhi                 Fungus
# South Indian        Infection
# Tamil Nadu          Infection
# Uttar Pradesh       Infection
# dtype: object

# %%
plotvar = region2ind.T
n_components=3
pca = PCA(n_components=n_components)
principalComponents = pca.fit_transform(plotvar.T)

    #Call the function. Use only the 2 PCs.
plt.figure(figsize=(20, 10))
myplot(principalComponents[:,0:n_components],np.transpose(pca.components_[0:n_components, :]), plotvar.columns, plotvar.index)
plt.show()
# Out:
# score shape (19, 3)

# %%
plt.figure(figsize=(30, 10))
sns.clustermap(region2ind.T, cmap = sns.cm.rocket_r, row_colors = col_colors)
# Out:
# /Users/fpil/anaconda3/lib/python3.7/site-packages/seaborn/matrix.py:624: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
len(ind_group_dict)
# Out:
# 1327

# %%
# find top diseses for each cuisine

fig = plt.figure(figsize= (10,10))
fig.tight_layout()
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=2)


for i, ind in enumerate(region2ind.index):
    t = region2ind.loc[ind].sort_values(ascending = False)[:10] # find top spices
    #t = t[t>0.5]
    ax = fig.add_subplot(6,4,i+1)
    t.plot.bar(ax=ax)
    #temp = Spice_Indication_df.loc[Spice_Indication_df['Cluster']==ind].index
    #list (Spice_Indication_df.loc[temp].sum(axis=1).sort_values(ascending=False)[:10].index)

    plt.title(ind)

# %%
def plot_top_heatmap(region2ind,k, cmap= sns.cm.rocket_r):
    top_ind_list = []
    for i, ind in enumerate(region2ind.index):
        t = region2ind.loc[ind].sort_values(ascending = False)[:k]
        top_ind_list.extend(list(t.index))

    cluster_ind_df = pd.DataFrame(index=region2ind.index,  columns = list(set(top_ind_list)), dtype='float64')

    for i, ind in enumerate(region2ind.index):
        cluster_ind_df.loc[ind] = region2ind.loc[ind, cluster_ind_df.columns]

    #fig = plt.figure(figsize= (10,5))
    sns.heatmap(cluster_ind_df, cmap= cmap)
    
def cal_relative_prev(region2spiceingre_df_combined):
    no_cuisine = len(region2spiceingre_df_combined.columns)

    avg = region2spiceingre_df_combined.sum(axis=1)

    temp = region2spiceingre_df_combined*no_cuisine
    relative_prev = temp.sub(avg, axis=0)/(no_cuisine-1)
    return relative_prev

def plot_prevalence(region2spiceingre_df_combined, no_subplot=[6,4]):
    fig = plt.figure(figsize= (20,20))
    fig.tight_layout()
    plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=2)


    for i, ind in enumerate(region2spiceingre_df_combined.columns):
        t = region2spiceingre_df_combined[ind].sort_values(ascending = False)[:10] # find top spices
        #t = t[t>0.5]
        ax = fig.add_subplot(no_subplot[0], no_subplot[1], i+1)
        t.plot.bar(ax=ax)
        #temp = Spice_Indication_df.loc[Spice_Indication_df['Cluster']==ind].index
        #list (Spice_Indication_df.loc[temp].sum(axis=1).sort_values(ascending=False)[:10].index)

        plt.title(ind)

fig = plt.figure(figsize= (10,5))    
plot_top_heatmap(region2ind, 10)

# %%
## find authentic indications for each cuisine
relative_prev= cal_relative_prev(region2ind.T)
plot_prevalence(relative_prev)

# %%
fig = plt.figure(figsize= (30,5))
sns.heatmap(relative_prev.T)

fig = plt.figure(figsize = (10,6))
plot_top_heatmap(relative_prev.T,5)

# %%
# set entries with relative prevalnce less than 0 to 0. 

relative_prev[relative_prev<0] = 0
fig = plt.figure(figsize= (30,5))
sns.heatmap(relative_prev.T, cmap= sns.cm.rocket_r)

fig = plt.figure(figsize = (20,6))
plot_top_heatmap(relative_prev.T,5)

# %%
## find authentic cusine for each indication
relative_prev= cal_relative_prev(region2ind.T)

# %%
plot_prevalence(relative_prev.T, [10,5])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-d17127a74b88> in <module>
# ----> 1 plot_prevalence(relative_prev.T, [10,5])
#
# <ipython-input-38-1207c412742e> in plot_prevalence(region2spiceingre_df_combined, no_subplot)
#      31         t = region2spiceingre_df_combined[ind].sort_values(ascending = False)[:10] # find top spices
#      32         #t = t[t>0.5]
# ---> 33         ax = fig.add_subplot(no_subplot[0], no_subplot[1], i+1)
#      34         t.plot.bar(ax=ax)
#      35         #temp = Spice_Indication_df.loc[Spice_Indication_df['Cluster']==ind].index
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1412                     self._axstack.remove(ax)
#    1413
# -> 1414             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1415
# ...

# %%
plot_prevalence(relative_prev)

# %%
#relative_prev_thresh = relative_prev[relative_prev>0]

maxindic = relative_prev.T.idxmax()

# %%
relative_prev

# %%
results_pd = pd.DataFrame(index = relative_prev.columns, columns= [ '#Indications', 'Indications'])

for cuisine in relative_prev.columns:
    temp= maxindic.index[maxindic==cuisine]
    
    results_pd.loc[cuisine, '#Indications'] = len(temp)
    results_pd.loc[cuisine, 'Indications'] = list(temp)
    
    #print(cuisine,len(temp), temp )

# %%
results_pd.to_csv(result_folder+ 'Indian_cuisine_topindications.csv')
results_pd

# %% [markdown]
# ## create cuisine-indication matrix by using relative prevalnce matrix instead of  region2spice matrix

# %%
region2spice_final

relative_prev= cal_relative_prev(region2spice_final.T)
relative_prev

# %%
#relative_prev[relative_prev<0] = 0

fig = plt.figure(figsize= (30,5))
sns.heatmap(relative_prev.T, cmap= sns.cm.rocket_r)

fig = plt.figure(figsize = (20,6))
plot_top_heatmap(relative_prev.T,5, cmap= sns.cm.rocket_r)

# %%
region2ind_norm = relative_prev.T.dot(spice2ind_final)
region2ind_norm

# %%
# plot prevalnce

fig = plt.figure(figsize= (30,5))
sns.heatmap(region2ind_norm, cmap= sns.cm.rocket_r)
fig = plt.figure(figsize = (10,6))
plot_top_heatmap(region2ind_norm,5)

# %%
# relative prevalance
relative_prev= cal_relative_prev(region2ind_norm.T)
relative_prev[relative_prev<0]=0


fig = plt.figure(figsize= (30,5))
sns.heatmap(relative_prev.T, cmap= sns.cm.rocket_r)
fig = plt.figure(figsize = (20,6))
plot_top_heatmap(relative_prev.T,5)

# %%
plot_prevalence(relative_prev)

# %%
'''


from sklearn.decomposition import NMF
model = NMF(n_components=2, init='random', random_state=0)
'''

# %%
'''
W = model.fit_transform(X)
H = model.components_
print(W.shape, H.shape)
'''

# %%
'''
plt.figure(figsize=(20, 10))
n_components = 2
myplot(W[:,0:n_components],np.transpose(H[0:n_components, :]), X.columns, X.index,dist = 'euclidean')
plt.show()
'''

# %%
'''
np.transpose(H[0:n_components, :]).shape
'''

'''
temp1 =cdist(W, W, 'cosine')

n = temp1.shape[0]
temp1[range(n), range(n)] = 0
Sim_disease = pd.DataFrame(temp1, columns= X.T.columns, index=X.T.columns )

Sim_disease.idxmax()
sns.clustermap(Sim_disease, cmap = sns.cm.rocket)
'''

'''

import nimfa
bmf = nimfa.Bmf(X.values, max_iter=10, rank=30, n_run=50, track_factor=True)
bmf_fit = bmf()
W = bmf_fit.basis()
print('Basis matrix shape:',  W.shape)

H = bmf_fit.coef()
print('Mixture matrix shape:', H.shape)

print('K-L divergence: %5.3f' % bmf_fit.distance(metric='kl'))

sm = bmf_fit.summary()
print('Rss: %5.3f' % sm['rss'])
print('Evar: %5.3f' % sm['evar'])
print('Iterations: %d' % sm['n_iter'])
print('Cophenetic correlation: %5.3f' % sm['cophenetic'])
'''

# %%
'''

import scipy.cluster.hierarchy as sch
import matplotlib.gridspec as gridspec
def clean_axis(ax):
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])
    for sp in ax.spines.values():
        sp.set_visible(False)

fig = plt.figure(figsize=(13.9, 10))
heatmapGS = gridspec.GridSpec(1, 2, wspace=.01, hspace=0., width_ratios=[0.25,1])

C = 1- bmf_fit.fit.consensus()
Y = sch.linkage(C, method='average')
print(C.shape)
denAX = fig.add_subplot(heatmapGS[0,0])
denD = sch.dendrogram(Y, orientation='right', link_color_func=lambda k: 'black')
clean_axis(denAX)

heatmapAX = fig.add_subplot(heatmapGS[0,1])
D = C[denD['leaves'], :][:, denD['leaves']]
axi = heatmapAX.imshow(D, interpolation='nearest', aspect='equal', origin='lower', cmap='RdBu') 
clean_axis(heatmapAX)

cb = fig.colorbar(axi, fraction=0.046, pad=0.04, aspect=10) 
cb.set_label('Distance', fontsize=20)
'''

'''

c = 0
k = 20
topk = np.argsort(np.asarray(W[:, c]).flatten())[-k:]
val = np.asarray(W[topk, c]).ravel()
plt.barh(np.arange(k) + .5, val, align="center")
labels = [X.index[idx] for idx in topk]
plt.yticks(np.arange(k) + .5, labels)
plt.xlabel("Weight")
plt.ylabel("Indication")
'''
'''

bmf = nimfa.Bmf(X.T.values, max_iter=10, rank=30, n_run=50, track_factor=True)
bmf_fit = bmf()
W = bmf_fit.basis()
print('Basis matrix shape:',  W.shape)

H = bmf_fit.coef()
print('Mixture matrix shape:', H.shape)
'''


'''
c = 0
k = 20
topk = np.argsort(np.asarray(W[:, c]).flatten())[-k:]
val = np.asarray(W[topk, c]).ravel()
plt.barh(np.arange(k) + .5, val, align="center")
labels = [X.T.index[idx] for idx in topk]
plt.yticks(np.arange(k) + .5, labels)
plt.xlabel("Weight")
plt.ylabel("Indication")
'''

'''

Sim_disease = pd.DataFrame(C, columns= X.columns, index=X.columns )

Sim_disease.idxmax()
sns.clustermap(Sim_disease, cmap = sns.cm.rocket)
'''


'''
plt.figure(figsize=(20, 10))
n_components = 2
myplot(np.array(W[:,0:n_components]),np.transpose(H[0:n_components, :]), X.columns, X.index,dist = 'euclidean')
plt.show()
'''
