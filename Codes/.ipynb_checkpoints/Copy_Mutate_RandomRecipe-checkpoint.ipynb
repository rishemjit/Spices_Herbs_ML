# %% [markdown]
# ## Part 1: random recipe generator##
# 1. uniform random copy mutate model
# 2. frequency-preserving copy mutate model
# 3. uniform random (uniform random sampling)
#
# ### Difference between 1 and 2 ###
# - 1 - no fitness value, the mutate process don't compare fitness value
# - 2 - has fitness value based on spice usage frequency, need to compare fitness value before mutate

# %%
import json
import numpy as np
import random
from Graph_Helpers import *
from MinSetCover import *

# %%
# read recipe2spice dict

result_folder = 'Derived_Data/CopyMutate/'
#r2s_combined = json2dict('Derived_Data/Overlap/cuisine_spicehnd_dict_combined.json')
cuisinerecipe2spicerecipe_orig = json2dict('Derived_Data/Overlap/cuisinerecipe2spicerecipe_combined.json')
print(len(cuisinerecipe2spicerecipe_orig))
# Out:
# 5636

# %%
# Find max, min, max, median count of spice per recipe

def countdict_stats(d):
    s_counts = list(d.values())
    max_count = max(s_counts)
    min_count = min(s_counts)
    avg_count = np.mean(s_counts)
    median_count = np.median(s_counts)
    print('max:', max_count, 'min:', min_count, 'mean:', avg_count, 'median:', median_count)

r2s_count_combined = dict2countdict(cuisinerecipe2spicerecipe_orig, list(cuisinerecipe2spicerecipe_orig.keys()))

print('Tarla + Sanjeev:')
countdict_stats(r2s_count_combined)
# Out:
# Tarla + Sanjeev:
# max: 24 min: 1 mean: 6.6320085166784954 median: 6.0

# %% [markdown]
# ### Model 1: Uniform Random Copy Mutate ###

# %%
# UNIFORM RANDOM 
# Random recipe generator with Copy Mutate Algorithm

# s: spice ingredients r: recipe

def copy_mutate_uniformrand(r2s_orig, r_pool_count=20, s_count=7, s_pool_count=10, M=6, ratio_threshold=0.2):
    '''
    Args: 
        r2s_orig - original r2s dictionary
        
        r_pool_count - initial number of r(recipe) in r_pool, will be updated
        
        s_count - number of s(spice) per one recipe 
        (QUESTION: is s_count a fixed value? is every random recipe contain same number of spices?)
        
        s_pool_count - initial number of s(spice) in s_pool, will be updated 
        
        M - number of mutations per time step
        
        ratio_threshold - threshold to maintain and add s(spice) to s_pool if s2r_ratio below threshold. 
        (QUESTION: what value should ratio_threshold take?)
    
    Return: random recipe sets
    '''
    s_orig = list(set(list(chain.from_iterable(r2s_orig.values())))) # all spices
    print('# of spices:', len(s_orig))
    r_orig = list(r2s_orig.keys()) # all recipes
    s_orig_count = len(s_orig) # number of all spices
    r_orig_count = len(r_orig) # number of all recipes

    # keep track of remaining spice collection
    # initially contains all spices encoded by number
    s_orig_coded = list(range(0,s_orig_count)) 

    s_pool = random.sample(s_orig_coded, s_pool_count) # initialize s_pool with #s_pool_count of spices randomly selected

    # remove spice in s_pool from original spice collection (i.e. s_orig_coded)
    for s in s_pool:
        s_orig_coded.remove(s) 

    # generate initial recipe pool (i.e. r_pool)
    # initialize a list of #r_pool_count of recipes, each containing #s_count of spices randomly selected from s_pool
    r_pool = []
    count = 0
    while(1):
        r_rand = random.sample(s_pool, s_count)
        r_rand.sort()
        if count == r_pool_count:
            break
        if r_rand not in r_pool:
            r_pool.append(r_rand)
            count += 1

    r_pool_orig = r_pool.copy()

    #ratio_threshold = s_pool_count/r_pool_count   
    
    #random.seed(seed)
    random.seed()

    while(1):# time step
        if len(r_pool) == r_orig_count:
            break
        s2r_ratio = s_pool_count/len(r_pool) # ratio btw #s in s_pool and #r in r_pool
        if s2r_ratio < ratio_threshold and len(s_orig_coded):
            if len(s_orig_coded) == 1:
                print('#recipes in r_pool when remaining spices reach zero:', len(r_pool))
            # add new spice into r_pool to maintain the ratio btw #s_pool_count/r_pool_count
            '''
            QUESTION: # total spices is significantly smaller than # recipes, cannot maintain ratio as #recipes in r_pool becomes larger
            in Kinouchi's paper, at each time step, there are R(t)=t recipes, need to make sure there are MR(t) ingredients available to use,
            where M is the ratio
            '''
            # pop out a spice by index from the remaining spice collection, and push to s_pool
            s_pop = random.randint(0,len(s_orig_coded) - 1)
            s_pool.append(s_orig_coded.pop(s_pop))  
        s_pool_count = len(s_pool)
        r_pool_count = len(r_pool)
        # randomly select a recipe from the r_pool (recipe pool) for mutation 
        r_idx = random.randint(0, r_pool_count - 1)
        r_mutate = r_pool[r_idx].copy() 
        for m in range(M): # mutation
            # randomly select a spice from r_mutate's spice list
            s_idx = random.randint(0,s_count - 1)
            s_from_r = r_mutate[s_idx] 
            # randomly select a spice from s_pool
            # random selection is from the subpool that exclude the spice already in current r_mutate
            s_subpool = list(set(s_pool) - set(r_mutate))    
            s_from_subpool = s_subpool[random.randint(0,len(s_subpool) - 1)]  
            r_mutate[s_idx] = s_from_subpool
            r_mutate.sort()
        # add mutated recipe to r_pool
        # removed checking mutated daughter recipe same with mother recipe, could be intrepreted as using different cooking procedure but containing same ingredients
        r_pool.append(r_mutate)
    print('#recipes in r_pool in final stage:', len(r_pool))
    
    # decode random recipes (i.e. replace number with spice name)
    random_recipes = []
    for r in r_pool:
        recipe_list = []
        for s in r:
            recipe_list.append(s_orig[s])
        random_recipes.append(recipe_list)
    return random_recipes

# %% [markdown]
# ### Model 2: Frequency-conserving copy mutate ###

# %%
# s: spice ingredients r: recipe

def copy_mutate_freqconserve(r2s_orig, r_pool_count=20, s_count=7, s_pool_count=10, M=6, ratio_threshold=0.2):
    '''
    Args: 
        r2s_orig - original r2s dictionary
        
        r_pool_count - initial number of r(recipe) in r_pool, will be updated
        
        s_count - number of s(spice) per one recipe 
        (QUESTION: is s_count a fixed value? is every random recipe contain same number of spices?)
        
        s_pool_count - initial number of s(spice) in s_pool, will be updated 
        
        M - number of mutations per time step
        
        ratio_threshold - threshold to maintain and add s(spice) to s_pool if s2r_ratio below threshold. 
        (QUESTION: what value should ratio_threshold take?)
    
    Return: random recipe sets
    '''
    s_orig_list = list(chain.from_iterable(r2s_orig.values())) # all spices list
    
    s_orig = list(set(s_orig_list)) # all spices set
           
    r_orig = list(r2s_orig.keys()) # all recipes
    s_orig_count = len(s_orig) # number of all spices
    r_orig_count = len(r_orig) # number of all recipes

    # keep track of remaining spice collection
    # initially contains all spices encoded by number
    s_orig_coded = list(range(0,s_orig_count)) 
    
    # generate fitness values for each spice based on their frequency
    s2fitnessvals = {}
    for i in range(s_orig_count):
        s2fitnessvals[i] = s_orig_list.count(s_orig[i])

    s_pool = random.sample(s_orig_coded, s_pool_count) # initialize s_pool with #s_pool_count of spices randomly selected

    # remove spice in s_pool from original spice collection (i.e. s_orig_coded)
    for s in s_pool:
        s_orig_coded.remove(s) 

    # generate initial recipe pool (i.e. r_pool)
    # initialize a list of #r_pool_count of recipes, each containing #s_count of spices randomly selected from s_pool
    r_pool = []
    count = 0
    while(1):
        r_rand = random.sample(s_pool, s_count)
        r_rand.sort()
        if count == r_pool_count:
            break
        if r_rand not in r_pool:
            r_pool.append(r_rand)
            count += 1

    r_pool_orig = r_pool.copy()

    #ratio_threshold = s_pool_count/r_pool_count   
    
    #random.seed(seed)
    random.seed()

    while(1):# time step
        if len(r_pool) == r_orig_count:
            break
        s2r_ratio = s_pool_count/len(r_pool) # ratio btw #s in s_pool and #r in r_pool
        if s2r_ratio < ratio_threshold and len(s_orig_coded):
            if len(s_orig_coded) == 1:
                print('#recipes in r_pool when remaining spices reach zero:', len(r_pool))
            # add new spice into r_pool to maintain the ratio btw #s_pool_count/r_pool_count
            '''
            QUESTION: # total spices is significantly smaller than # recipes, cannot maintain ratio as #recipes in r_pool becomes larger
            in Kinouchi's paper, at each time step, there are R(t)=t recipes, need to make sure there are MR(t) ingredients available to use,
            where M is the ratio
            '''
            # pop out a spice by index from the remaining spice collection, and push to s_pool
            s_pop = random.randint(0,len(s_orig_coded) - 1)
            s_pool.append(s_orig_coded.pop(s_pop))  
        s_pool_count = len(s_pool)
        r_pool_count = len(r_pool)
        # randomly select a recipe from the r_pool (recipe pool) for mutation 
        r_idx = random.randint(0, r_pool_count - 1)
        r_mutate = r_pool[r_idx].copy() 
        for m in range(M): # mutation
            #seed += 1
            # randomly select a spice from r_mutate's spice list
            s_idx = random.randint(0,s_count - 1)
            s_from_r = r_mutate[s_idx] 
            # randomly select a spice from s_pool
            # QUESTION: should the random selection from s_pool consider all the spice in s_pool or only those not in the current r_mutate?
            s_subpool = list(set(s_pool) - set(r_mutate))    
            s_from_subpool = s_subpool[random.randint(0,len(s_subpool) - 1)]  
            if s2fitnessvals[s_from_r] < s2fitnessvals[s_from_subpool]:
                r_mutate[s_idx] = s_from_subpool
            r_mutate.sort()
        # add mutated recipe to r_pool
        # removed checking mutated daughter recipe same with mother recipe, could be intrepreted as using different cooking procedure but containing same ingredients
        r_pool.append(r_mutate)
    print('#recipes in r_pool in final stage:', len(r_pool))
    
    # decode random recipes (i.e. replace number with spice name)
    random_recipes = []
    for r in r_pool:
        recipe_list = []
        for s in r:
            recipe_list.append(s_orig[s])
        random_recipes.append(recipe_list)
    return random_recipes

# %% [markdown]
# ## Generate Random Recipes ##

# %%
GEN_NEW = False # generate new random recipe 
NUM_SETS = 50  # number of recipe sets per random algorithm

# %% [markdown]
# ### 1. copy-mutate uniform ###

# %%
# Generate Random Recipes: 
if GEN_NEW:
    randuniform_recipes = []
    for i in range(NUM_SETS):
        random_recipes_uniform = copy_mutate_uniformrand(cuisinerecipe2spicerecipe_orig, r_pool_count=20, s_count=6, s_pool_count=10, M=6, ratio_threshold=0.2)
        r_dict = {}
        for i in range(len(random_recipes_uniform)):
            r_dict['Recipe'+str(i)] = random_recipes_uniform[i]        
        unique_recipe_count= len(list(set(map(tuple, random_recipes_uniform))))
        print('unique recipes count(uniformrand): ', unique_recipe_count)
        randuniform_recipes.append(r_dict)
    dict2json(randuniform_recipes,result_folder+'cm_randuniform_recipes.json')
else:
    randuniform_recipes = json2dict(result_folder+'cm_randuniform_recipes.json')
    print(len(randuniform_recipes))
# Out:
# 50

# %% [markdown]
# ### 2. copy-mutate freq conserve ###

# %%
if GEN_NEW:
    randfreq_recipes = []
    for i in range(NUM_SETS):
        random_recipes_freq = copy_mutate_freqconserve(cuisinerecipe2spicerecipe_orig, r_pool_count=20, s_count=6, s_pool_count=10, M=6, ratio_threshold=0.2)
        r_dict = {}
        for i in range(len(random_recipes_freq)):
            r_dict['Recipe'+str(i)] = random_recipes_freq[i]        
        unique_recipe_count= len(list(set(map(tuple, random_recipes_freq))))
        print('unique recipes count(freqconserve): ', unique_recipe_count)
        randfreq_recipes.append(r_dict)
    dict2json(randfreq_recipes,result_folder+'cm_randfreq_recipes.json')
else:
    randfreq_recipes = json2dict(result_folder+'cm_randfreq_recipes.json')
    print(len(randfreq_recipes))
# Out:
# 50

# %%
import matplotlib.pyplot as plt

# read the Indian cuisine file to get an estimate of the no of spices per recipe
from statistics import mean
recipe_len = [len(i) for i in cuisinerecipe2spicerecipe_orig.values()]

plt.hist(recipe_len)
print('mean, min and max no of spices in a recipe', mean(recipe_len), min(recipe_len), max(recipe_len))
print(len(recipe_len))
# Out:
# mean, min and max no of spices in a recipe 6.6320085166784954 1 24
# 5636

# %%
'''
import random
s_count = 5 # ingredient count
s_pool = list(set(list(chain.from_iterable(r2s_combined.values())))) # all spices
num_recipes = len(r2s_combined.keys()) 
recipe_random = []
recipe_random_dict = {} # this will be used in other codes
k = 0
for i in range(num_recipes):
    sample = random.sample(s_pool, s_count)
    recipe_random.append(sample)
    recipe_random_dict['Recipe{}'.format(i)] = sample
    
'''
# Out:
# "\nimport random\ns_count = 5 # ingredient count\ns_pool = list(set(list(chain.from_iterable(r2s_combined.values())))) # all spices\nnum_recipes = len(r2s_combined.keys()) \nrecipe_random = []\nrecipe_random_dict = {} # this will be used in other codes\nk = 0\nfor i in range(num_recipes):\n    sample = random.sample(s_pool, s_count)\n    recipe_random.append(sample)\n    recipe_random_dict['Recipe{}'.format(i)] = sample\n    \n"

# %% [markdown]
# ### 3. random (draw from uniform distn) ###

# %%
# generate random recipe set that follows the same distribution (of no of ingredients per recipe) as in the Indian cusine data

import random 
s_pool = list(set(list(chain.from_iterable(cuisinerecipe2spicerecipe_orig.values())))) # all spices
# we will randomly generate 5000 recipes and no of ingredients for recipes will be selected based on Indian cuisine
num_recipes = 5636
#s_count = random.sample(recipe_len, num_recipes) 
s_count = [6]*num_recipes
print(mean(s_count), min(s_count), max(s_count))

if GEN_NEW:
    rand_recipes = []
    for k in range(NUM_SETS):
        recipe_random = []
        recipe_random_dict = {} # this will be used in other codes
        for i in range(num_recipes):
            sample = random.sample(s_pool, s_count[i])
            recipe_random.append(sample)
            recipe_random_dict['Recipe{}'.format(i)] = sample
        rand_recipes.append(recipe_random_dict)

    dict2json(rand_recipes,result_folder+ 'randomuniform_recipes.json')
else:
    rand_recipes = json2dict(result_folder+ 'randomuniform_recipes.json')
# Out:
# 6 6 6

# %% [markdown]
# ## Part 2: min set cover (recipe cover for indications) ##
# 1. generate recipe2indication bipartite for real recipe data
# 2. generate recipe2indication bipartite for random recipe
# 3. minset cover for each case

# %% [markdown]
# ### Generate recipe2indic_orig for real recipe ###

# %%
#cuisinerecipe2spicerecipe_combined
# generate {cuisinerecipe : indication} dict
def process_name(s):
    return s.lower().replace(' ', '')

spicerecipe2spicehnd = json2dict('Derived_Data/Overlap/spicetarla_spicehnd_dict.json') 
#spicehnd2indic = json2dict( 'Derived_Data/StateIndicationNetwork/spiceherb_indication_dict.json')
#spicehnd2indic = json2dict('Derived_Data/Spice2Phytochemical2Disease/spice2indic_phytononzero.json')
spicehnd2indic = json2dict('Derived_Data/Spice2Phytochemical2Disease/spice2indic_all.json')
spicehnd2indic =  {process_name(k) : v for k, v in spicehnd2indic.items()}

miss = []
cuisinerecipe2indic_orig = {}
for r in cuisinerecipe2spicerecipe_orig.keys():
    indic_list = []
    for s in cuisinerecipe2spicerecipe_orig[r]:
        for s_hnd in spicerecipe2spicehnd[s]:
            try:
                indic_list.extend(spicehnd2indic[process_name(s_hnd)])
            except:
                miss.append(s_hnd)
    cuisinerecipe2indic_orig[r] = list(set(indic_list))
print('MISSING SPICES (appear in spice2recipe but not in spice2indic_phytononzero): \n', set(miss))
# Out:
# MISSING SPICES (appear in spice2recipe but not in spice2indic_phytononzero):
#  set()

# %%
# Find recipe-indication for all random recipe-spice sets

miss = []

# copy-mutate uniform
recipe2indic_randuniform_list = []
for idx in range(NUM_SETS):
    recipe2indic_randuniform = {}
    for i in range(len(randuniform_recipes[idx])):
        indic_list = []
        for s in randuniform_recipes[idx]['Recipe'+str(i)]:
            for s_hnd in spicerecipe2spicehnd[s]:
                try:
                    indic_list.extend(spicehnd2indic[process_name(s_hnd)])
                except:
                    miss.append(s_hnd)
        recipe2indic_randuniform['Recipe'+str(i)] = list(set(indic_list))
    recipe2indic_randuniform_list.append(recipe2indic_randuniform)


# copy-mutate freq
miss = []
recipe2indic_randfreq_list = []
for idx in range(NUM_SETS):
    recipe2indic_randfreq = {}
    for i in range(len(randfreq_recipes[idx])):
        indic_list = []
        for s in randfreq_recipes[idx]['Recipe'+str(i)]:
            for s_hnd in spicerecipe2spicehnd[s]:
                try:
                    indic_list.extend(spicehnd2indic[process_name(s_hnd)])
                except:
                    miss.append(s_hnd)
        recipe2indic_randfreq['Recipe'+str(i)] = list(set(indic_list))
    recipe2indic_randfreq_list.append(recipe2indic_randfreq)
    
miss = []

# random uniform
recipe2indic_rand_list = []
for idx in range(NUM_SETS):
    recipe2indic_rand = {}
    for i in range(len(rand_recipes[idx])):
        indic_list = []
        for s in rand_recipes[idx]['Recipe'+str(i)]:
            for s_hnd in spicerecipe2spicehnd[s]:
                try:
                    indic_list.extend(spicehnd2indic[process_name(s_hnd)])
                except:
                    miss.append(s_hnd)
        recipe2indic_rand['Recipe'+str(i)] = list(set(indic_list))
    recipe2indic_rand_list.append(recipe2indic_rand)

# %% [markdown]
# ### Min Set Cover for each disease category ###
# ### This takes pretty long ###

# %%
GEN_MINSET = False

# %%
group2indic2spice =  json2dict('Derived_Data/MinSetCover/group2indic2spice.json')

def Minset_recipe_bygroup(recipe2indic, recipe2spice):
    group2minrecipe = {}
    for group, val in group2indic2spice.items():
        print(group)
        indic_select = list(val.keys())
        indic2recipe = reverse_dict(recipe2indic)   #cuisinerecipe2indic_orig

        indic2recipe_sub = {indic: indic2recipe[indic] for indic in indic_select if indic in indic2recipe}
        print('#indic',len(indic_select), '#indic used in recipes:', len(indic2recipe_sub))
        recipe2indic_sub = reverse_dict(indic2recipe_sub) 

       # print(indic2recipe_sub.keys())
        set_name = ['Recipe','Indication']
        bi_graph_sub, recipe_topset_sub, indic_botset_sub = Bipartite_graph(recipe2indic_sub, set_name)
        if recipe_topset_sub and indic_botset_sub:
            adjmtx_sub = bipartite.biadjacency_matrix(bi_graph_sub, row_order=indic_botset_sub, column_order=recipe_topset_sub).toarray()

            n2 = adjmtx_sub.shape[1]
            c = np.hstack([np.ones(n2), [0]])

            min_set_bygroup = Min_cover_set(recipe2indic_sub, recipe_topset_sub, indic_botset_sub, adjmtx_sub, c)
            min_r2s = {}
            for min_r in min_set_bygroup:
                min_r2s[min_r] = recipe2spice[min_r]
            group2minrecipe[group] = min_r2s
    return group2minrecipe
   
if GEN_MINSET:
    # min set for real recipe       
    group2minrecipe_orig = Minset_recipe_bygroup(cuisinerecipe2indic_orig,cuisinerecipe2spicerecipe_orig)
    dict2json(group2minrecipe_orig, result_folder + 'group2minrecipe_orig.json')

    # min set for copy-mutate uniform
    group2minrecipe_randuniform_list = []
    for idx in range(NUM_SETS):
        group2minrecipe_randuniform = Minset_recipe_bygroup(recipe2indic_randuniform_list[idx],randuniform_recipes[idx])
        group2minrecipe_randuniform_list.append(group2minrecipe_randuniform)
    dict2json(group2minrecipe_randuniform_list, result_folder + 'group2minrecipe_randuniform_list.json')

    # min set for copy-mutate freq conserve
    group2minrecipe_randfreq_list = []
    for idx in range(NUM_SETS):
        group2minrecipe_randfreq = Minset_recipe_bygroup(recipe2indic_randfreq_list[idx],randfreq_recipes[idx])
        group2minrecipe_randfreq_list.append(group2minrecipe_randfreq)
    dict2json(group2minrecipe_randfreq_list, result_folder + 'group2minrecipe_randfreq_list.json')

    # min set for random uniform recipes
    group2minrecipe_rand_list = []
    for idx in range(NUM_SETS):
        group2minrecipe_rand = Minset_recipe_bygroup(recipe2indic_rand_list[idx],rand_recipes[idx])
        group2minrecipe_rand_list.append(group2minrecipe_rand)
    dict2json(group2minrecipe_rand_list, result_folder + 'group2minrecipe_rand_list.json')
else:
    group2minrecipe_orig = json2dict(result_folder + 'group2minrecipe_orig.json')
    group2minrecipe_randuniform_list = json2dict(result_folder + 'group2minrecipe_randuniform_list_100.json')
    group2minrecipe_randfreq_list = json2dict(result_folder + 'group2minrecipe_randfreq_list_100.json')
    group2minrecipe_rand_list = json2dict(result_folder + 'group2minrecipe_rand_list_100.json')

# %%
print(len(group2minrecipe_rand_list))
print(group2minrecipe_rand_list[2] == group2minrecipe_rand_list[3])
print(group2minrecipe_rand_list[30]['infectious_disease'] == group2minrecipe_rand_list[20]['infectious_disease'])
# Out:
# 100
# False
# False

# %%
# group2minrecipe_randuniform_list.extend(json2dict(result_folder+'group2minrecipe_randuniform_list_2.json'))
# group2minrecipe_randfreq_list.extend(json2dict(result_folder+'group2minrecipe_randfreq_list_2.json'))
# group2minrecipe_rand_list.extend(json2dict(result_folder+'group2minrecipe_rand_list_2.json'))
# dict2json(group2minrecipe_randuniform_list, result_folder+'group2minrecipe_randuniform_list_100.json')
# dict2json(group2minrecipe_randfreq_list, result_folder+'group2minrecipe_randfreq_list_100.json')
# dict2json(group2minrecipe_rand_list, result_folder+'group2minrecipe_rand_list_100.json')

# %%
# TRASH
import numpy as np
import matplotlib.pyplot as plt
count_orig, count_randfreq, count_randuniform, count_rand = [],[],[],[]
groups = list(group2minrecipe_orig.keys())

mean_list = []  # for each group
countlist_all_rand, countlist_all_randfreq, countlist_all_randuniform = [],[],[]
count_multi_df = []
for group in groups:
    count_orig.append(len(group2minrecipe_orig[group])) # just one set 
    countlist_randfreq, countlist_randuniform, countlist_rand = [],[],[]
    for i in range(len(group2minrecipe_randfreq_list)):  # calculate mean from all sets
        countlist_randfreq.append(len(group2minrecipe_randfreq_list[i][group]))
        countlist_randuniform.append(len(group2minrecipe_randuniform_list[i][group]))
        countlist_rand.append(len(group2minrecipe_rand_list[i][group]))
    countlist_all_rand.append(countlist_rand)
    countlist_all_randfreq.append(countlist_randfreq)
    countlist_all_randuniform.append(countlist_randuniform)

#fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
plt.figure(figsize=(15,5))
# axes[0].violinplot(countlist_rand_all,
#                    showmeans=True,
#                    showmedians=True)
# axes[0].set_title('violin plot')

# # plot box plot
# axes[1].boxplot(countlist_rand_all)
# axes[1].set_title('box plot')

plt.violinplot(countlist_all_randfreq,
                   showmeans=True,
                   showmedians=True)
plt.title('violin plot')

#plt.boxplot(countlist_randfreq_all)
# adding horizontal grid lines
# for ax in axes:
#     ax.yaxis.grid(True)
#     #ax.set_xticks([y+1 for y in range(len(countlist_rand_all))])
#     ax.set_xlabel('xlabel')
#     ax.set_ylabel('ylabel')

plt.show()

# ax = sns.boxplot(x="category", y="count", hue="type", data=count_multi_df, palette="Set2", 
#                showmeans=True, showfliers=True)
# sns.stripplot(x="category", y="count", hue='type',data=count_multi_df, palette='Set2', alpha=0.3, size=10, jitter=True,zorder=0)
# sns.pointplot(x='category', y='count', data=count_multi_df, hue='type', linestyles=':',palette='Set2')


# y = np.arange(1, len(groups)+1)
# counts = [count_orig, count_randuniform, count_randfreq]
# labels = ['real recipes', 'uniform copy-mutate recipes', 'frequency-conserve copy-mutate recipes', 'random uniform']
# plt.figure(figsize=(12,5))
# plot_orig, = plt.plot(y, count_orig,'o:', label=labels[0], markersize=10, linewidth=2)
# plot_randuniform, = plt.plot(y, count_randuniform,'d:',label=labels[1], markersize=10, linewidth=2)
# plot_randfreq, = plt.plot(y, count_randfreq, '^:', label=labels[2], markersize=9, linewidth=2)
# plot_rand, = plt.plot(y,count_rand,'^:', label=labels[2], markersize=9, linewidth=2)
# plt.xticks(y, groups, rotation=90, fontsize=13)
# plt.yticks(np.arange(12))
# plt.legend([plot_orig, plot_randuniform, plot_randfreq, plot_rand], labels)
# plt.ylabel('Size of min set', fontsize=13)
# plt.savefig(result_folder+'minset_recipes.png',bbox_inches = "tight")

# %%
groups_select = ['infectious_disease', 
                 'gastrointestinal_disease',
                 'cancer_disease',
                 'skin_disease',
                 'nephrological_disease',
                 'neuronal_disease',
                 'respiratory_disease',
                 'pregnancy_disease',
                 'mental_disease',
                 'metabolic_disease',
                 'cardiovascular_disease',
                 'immune_disease'
]
                 
#  'pregnancy_disease',

#  'metabolic_disease',
#  'skin_disease',
#  'mental_disease',
#  'reproductive_disease',
#  'musculoskeletal_disease ',
#  'neuronal_disease',
#  'endocrine_disease',

# %%
count_multi_df
# Out:
# []

# %% [markdown]
# ## Box plots by disease category ##

# %%
# FINAL 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

#groups = list(group2minrecipe_orig.keys())
num_set = len(group2minrecipe_randfreq_list)

num_show = 0

fig, axes = plt.subplots(3, 4, sharex=True, figsize=(16,8))

for count_temp11, group in enumerate(groups_select):
    count_orig, countlist_orig, countlist_randfreq, countlist_randuniform, countlist_rand = [],[],[],[],[]
    count_multi_df = []
    orig_count = len(group2minrecipe_orig[group]) # just one set 
    for i in range(num_set):
        countlist_randfreq.append({'count':len(group2minrecipe_randfreq_list[i][group]), 'type':'frequency-conserved copy mutate'})
        countlist_randuniform.append({'count':len(group2minrecipe_randuniform_list[i][group]), 'type':'uniform copy mutate'})
        countlist_rand.append({'count':len(group2minrecipe_rand_list[i][group]), 'type':'random uniform'})
    count_multi_df.extend(countlist_randfreq)
    count_multi_df.extend(countlist_randuniform)
    count_multi_df.extend(countlist_rand)

    count_multi_df = pd.DataFrame(count_multi_df)

    sns.set_style("dark", {"axes.facecolor": ".9"})
    #sns.set_style('ticks', {"xtick.major.size": 8, "ytick.major.size": 8, "axes.facecolor":"1.2"})
    #plt.figure(figsize=(10,3))

    ax =sns.boxplot(x ='type', y='count', hue='type', ax = axes[int(num_show/4),num_show%4], 
                    data=count_multi_df, palette="Set2", showmeans=True, showfliers=False,linewidth=2, 
                   meanprops={"marker":"d",
                       "markerfacecolor":"black", 
                       "markeredgecolor":"black",
                      "markersize":"4"})
    ax.axhline(y=orig_count, color='r', linestyle='--')
    #plt.axhline(y=orig_count, ls='--', c='red')
    #ax.set_xticks(fontsize=12=
    #ax.set_xticklabels(['Freq-conserved CM','Uniform CM','Random Uniform'],fontsize=14,rotation=46)
    ax.set_xticklabels(['FC-CM','U-CM','RU'],fontsize=16,rotation=46)
    #ax.set_xticks([])
    ax.set_xticks(np.arange(0,3,1))
    ax.set_yticks(np.arange(0,12,2))
    ax.set_xlabel('', fontsize=1)
    ax.set_ylabel('', fontsize=14)
    if (count_temp11%4 ==0):
        ax.set_ylabel('Min Set Size', fontsize=14)
    ax.set_title(' '.join(group.split('_')).capitalize(), fontsize=16)
    ax.legend([],[], frameon=False)
    
    num_show +=1 
    if num_show > 11:
        break

fig.subplots_adjust(top=0.9, left=0.1, right=0.9, bottom=0.12)  # create some space below the plots by increasing the bottom-value
L= axes.flatten()[-3].legend(loc='upper center', bbox_to_anchor=(1.1, -0.5), ncol=3, fontsize=16)
L.get_texts()[0].set_text('Frequency Conserved Copy Mutate (FC-CM)')
L.get_texts()[1].set_text('Uniform Copy Mutate (U-CM)')
L.get_texts()[2].set_text('Random uniform (RU)')
plt.savefig(result_folder+'Boxplot_minsetcover_disease.pdf', bbox_inches="tight")

#plt.show()

# %%
#len(countlist_randfreq)
#len(countlist_randuniform)
len(countlist_rand)
# Out:
# 100

# %% [markdown]
# ## upset plot for min set of recipes to cover disease category ##

# %%
len(group2minrecipe_orig)

def get_group2minset(group2minrecipe, groups_select):
    group2minset = dict((k, list(group2minrecipe[k].keys())) for k in groups_select if k in group2minrecipe)
    return group2minset

group2minset_orig = get_group2minset(group2minrecipe_orig, groups_select)
group2minset_rand = get_group2minset(group2minrecipe_rand_list[0], groups_select)
group2minset_randfreq = get_group2minset(group2minrecipe_randfreq_list[0], groups_select)
group2minset_randuniform = get_group2minset(group2minrecipe_randuniform_list[0], groups_select)
#group2minset_randuniform['infectious_disease']
group2minset_randuniform['infectious_disease']
# Out:
# ['Recipe2161', 'Recipe3503', 'Recipe3557', 'Recipe3728', 'Recipe5468']

# %%
def get_upset_data(group2minrecipe, groups_select, recipe_type):
    group2minset = get_group2minset(group2minrecipe,groups_select)
    upset_items = []
    upset_groups = list(group2minset.keys())
    upset_items.append('Name,' + ','.join(upset_groups))
    unique_recipes = []
    for group, minset in group2minset.items():
        unique_recipes.extend(minset)
    unique_recipes = list(set(unique_recipes))

    for r in unique_recipes:
        indicator = [r]  # 0 or 1 
        for g in upset_groups:
            if r in group2minset[g]:
                indicator.append('1')
            else:
                indicator.append('0')
        upset_items.append(','.join(indicator))  # format: 'spice,0,1,0,0,0,1'

    upset_df = pd.DataFrame(upset_items)
    upset_df.to_csv(f'{result_folder}upset_input_{recipe_type}.csv',header=False,index=False)
    

get_upset_data(group2minrecipe_orig, groups_select, 'orig')
get_upset_data(group2minrecipe_rand_list[0], groups_select, 'rand')
get_upset_data(group2minrecipe_randfreq_list[0], groups_select, 'randfreq')
get_upset_data(group2minrecipe_randuniform_list[0], groups_select, 'randuniform')

# %%
import csv 
upset_items = []
upset_groups = list(group2minsetdf.keys())
upset_items.append('Name,' + ','.join(upset_groups))
unique_spices = []
for group, minsetdf in group2minsetdf.items():
    unique_spices.extend(list(minsetdf['spices']))
unique_spices = list(set(unique_spices))

for s in unique_spices:
    indicator = [s]
    for g in upset_groups:
        if s in list(group2minsetdf[g]['spices']):
            indicator.append('1')
        else:
            indicator.append('0')
    upset_items.append(','.join(indicator))  # format: 'spice,0,1,0,0,0,1'

upset_df = pd.DataFrame(upset_items)
upset_df.to_csv(result_folder+'upset_input.csv',header=False,index=False)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

count_orig, countlist_orig, count_randfreq, count_randuniform, count_rand = [],[],[],[],[]
groups = list(group2minrecipe_orig.keys())

mean_list = []  # for each group

countlist_orig, countlist_all_rand, countlist_all_randfreq, countlist_all_randuniform = [],[],[],[]
count_multi_df = []
count_orig_df, mean_randfreq_df, mean_randuniform_df, mean_rand_df = [],[],[],[]
num_set = len(group2minrecipe_randfreq_list)

for group in groups[:10]:
    count_orig.append(len(group2minrecipe_orig[group])) # just one set 
    countlist_randfreq, countlist_randuniform, countlist_rand = [],[],[]
    for i in range(num_set):  # calculate mean from all sets
        countlist_randfreq.append({'count':len(group2minrecipe_randfreq_list[i][group]), 'category':group, 'type':'frequency-conserved copy mutate'})
        #count_multi_df.append({'count':len(group2minrecipe_randuniform_list[i][group]), 'category':group, 'type':'uniform copy mutate'})
        countlist_randuniform.append({'count':len(group2minrecipe_rand_list[i][group]), 'category':group, 'type':'random uniform'})
    count_multi_df.extend(countlist_randfreq)
    count_multi_df.extend(countlist_randuniform)
    count_multi_df.append({'count':len(group2minrecipe_orig[group]), 'category':group, 'type':'real'})        
    count_orig_df.append({'count':len(group2minrecipe_orig[group]), 'category':group, 'type':'real'})
    mean_randfreq_df.append({'count':np.mean([countlist_randfreq[i]['count'] for i in range(num_set)]) , 'category':group, 'type':'frequency-conserved copy mutate'})
    mean_randuniform_df.append({'count':np.mean([countlist_randuniform[i]['count'] for i in range(num_set)]) , 'category':group, 'type':'random uniform'})

count_multi_df = pd.DataFrame(count_multi_df)
count_orig_df = pd.DataFrame(count_orig_df)
mean_randfreq_df = pd.DataFrame(mean_randfreq_df)
mean_randuniform_df = pd.DataFrame(mean_randuniform_df)
# Grouped violinplot
sns.set_style("darkgrid", {"axes.facecolor": ".9"})
plt.figure(figsize=(16,8))

ax = sns.boxplot(x="category", y="count", hue="type", data=count_multi_df,palette="Set2", 
               showmeans=True, showfliers=True)
sns.stripplot(x="category", y="count", hue='type',data=count_multi_df, palette='Set2', alpha=0.3, size=10, jitter=True,zorder=0)
sns.pointplot(x='category', y='count', data=count_multi_df, hue='type', linestyles=':',palette='Set2')



#sns.pointplot(x='category', y='count', data=count_multi_df, hue='type', ci=None, linestyle='.', join=True)
#sns.pointplot(x='category', y='count', data=count_orig_df, join=True)

#sns.pointplot(countlist_orig)
#sns.scatterplot(data=count_orig_df, x='category', y='count', marker='o', s=150, color='#3498db')
#sns.scatterplot(data=mean_randfreq_df, x='category', y='count', marker='o', s=150 )
#sns.scatterplot(data=mean_randuniform_df, x='category', y='count', marker='o', s=150)


handles, labels = ax.get_legend_handles_labels()

plt.xticks(rotation=70, fontsize=17)
plt.yticks(fontsize=17)
plt.xlabel('Category', fontsize=17)
plt.ylabel('Min Set Size', fontsize=17)
# When creating the legend, only use the first two elements
# to effectively remove the last two.
l = plt.legend(handles[0:3], labels[0:3],fontsize=17) #, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.

plt.autoscale()

plt.savefig(result_folder+'minset_boxplot_10.png',bbox_inches="tight")
plt.show()



# g = sns.FacetGrid(row="l", data=count_multi_df)
# g.map(sns.violinplot,"category", "count", hue='type', palette='Pastel1')

# # iterate over axes of FacetGrid
# for ax in g.axes.flat:
#     labels = ax.get_xticklabels() # get x labels
#     for i,l in enumerate(labels):
#         if(i%2 == 0): labels[i] = '' # skip even labels
#     ax.set_xticklabels(labels, rotation=30) # set new labels
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
countlist_orig, count_randfreq, count_randuniform, count_rand = [],[],[],[]
groups = list(group2minrecipe_orig.keys())

mean_list = []  # for each group
coutlist_orig, countlist_all_rand, countlist_all_randfreq, countlist_all_randuniform = [],[],[],[]
count_multi_df = []
count_orig_df, mean_randfreq_df, mean_randuniform_df, mean_rand_df = [],[],[],[]
num_set = len(group2minrecipe_randfreq_list)
for group in groups[:10]:
    count_orig.append(len(group2minrecipe_orig[group])) # just one set 
    countlist_randfreq, countlist_randuniform, countlist_rand = [],[],[]
    for i in range(num_set):  # calculate mean from all sets
        countlist_randfreq.append({'count':len(group2minrecipe_randfreq_list[i][group]), 'category':group, 'type':'frequency-conserved copy mutate'})
        #count_multi_df.append({'count':len(group2minrecipe_randuniform_list[i][group]), 'category':group, 'type':'uniform copy mutate'})
        countlist_randuniform.append({'count':len(group2minrecipe_rand_list[i][group]), 'category':group, 'type':'random uniform'})
    count_multi_df.extend(countlist_randfreq)
    count_multi_df.extend(countlist_randuniform)
    count_multi_df.append({'count':len(group2minrecipe_orig[group]), 'category':group, 'type':'real'})        
    count_orig_df.append({'count':len(group2minrecipe_orig[group]), 'category':group, 'type':'real'})
    mean_randfreq_df.append({'count':np.mean([countlist_randfreq[i]['count'] for i in range(num_set)]) , 'category':group, 'type':'frequency-conserved copy mutate'})
    mean_randuniform_df.append({'count':np.mean([countlist_randuniform[i]['count'] for i in range(num_set)]) , 'category':group, 'type':'random uniform'})

count_multi_df = pd.DataFrame(count_multi_df)
count_orig_df = pd.DataFrame(count_orig_df)
mean_randfreq_df = pd.DataFrame(mean_randfreq_df)
mean_randuniform_df = pd.DataFrame(mean_randuniform_df)
# Grouped violinplot
sns.set_style("darkgrid", {"axes.facecolor": ".9"})
plt.figure(figsize=(16,10))


### PLOT ####


plt.figure(figsize=(16,8))
ax = sns.violinplot(x="category", y="count", hue="type", data=count_multi_df, palette="Set2", 
               estimator=mean, showmeans=True, inner='box', scale='count',
               meanprops={"marker":".",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"white",
                      "markersize":"25"}) #Pastel1, Set2,muted
sns.pointplot(x='category', y='count', data=count_multi_df, hue='type', linestyles=':',palette='Set2')


handles, labels = ax.get_legend_handles_labels()


plt.xticks(rotation=70, fontsize=17)
plt.yticks(fontsize=17)
plt.xlabel('Category', fontsize=17)
plt.ylabel('Min Set Size', fontsize=17)
# When creating the legend, only use the first two elements
# to effectively remove the last two.
l = plt.legend(handles[0:3], labels[0:3],fontsize=17) #, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.

plt.autoscale()
plt.savefig(result_folder+'minset_violinplot_10.png',bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Trash Below ##

# %%
sns.axes_style()
# Out:
# {'axes.facecolor': '.9',
#  'axes.edgecolor': 'white',
#  'axes.grid': True,
#  'axes.axisbelow': True,
#  'axes.labelcolor': '.15',
#  'figure.facecolor': 'white',
#  'grid.color': 'white',
#  'grid.linestyle': '-',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'ytick.color': '.15',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': 'round',
#  'patch.edgecolor': 'w',
#  'image.cmap': 'rocket',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'patch.force_edgecolor': True,
#  'xtick.bottom': False,
#  'xtick.top': False,
#  'ytick.left': False,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))

# generate some random test data
all_data = [np.random.normal(0, std, 100) for std in range(6, 10)]
print(len(all_data))
print(all_data[0].shape)
# plot violin plot

axes[0].violinplot(all_data,
                   showmeans=True,
                   showmedians=True)
axes[0].set_title('violin plot')

# plot box plot
axes[1].boxplot(all_data)
axes[1].set_title('box plot')

# adding horizontal grid lines
for ax in axes:
    ax.yaxis.grid(True)
    ax.set_xticks([y+1 for y in range(len(all_data))])
    ax.set_xlabel('xlabel')
    ax.set_ylabel('ylabel')

# add x-tick labels
plt.setp(axes, xticks=[y+1 for y in range(len(all_data))],
         xticklabels=['x1', 'x2', 'x3', 'x4'])
#plt.savefig('box_viol_plot_example.png')
plt.show()
# Out:
# 4
# (100,)

# %% [markdown]
# ## END HERE ##

# %%
# TRASH
import numpy as np
import matplotlib.pyplot as plt
count_orig, count_randfreq, count_randuniform, count_rand = [],[],[],[]
groups = list(group2minrecipe_orig.keys())
for group in groups:
    count_orig.append(len(group2minrecipe_orig[group]))
    count_randfreq.append(len(group2minrecipe_randfreq[group]))
    count_randuniform.append(len(group2minrecipe_randuniform[group]))
    count_rand.append(len(group2minrecipe_rand[group]))

# y = np.arange(1, len(groups)+1)
# counts = [count_orig, count_randuniform, count_randfreq]
# labels = ['real recipes', 'uniform copy-mutate recipes', 'frequency-conserve copy-mutate recipes', 'random uniform']
# plt.figure(figsize=(12,5))
# plot_orig, = plt.plot(y, count_orig,'o:', label=labels[0], markersize=10, linewidth=2)
# plot_randuniform, = plt.plot(y, count_randuniform,'d:',label=labels[1], markersize=10, linewidth=2)
# plot_randfreq, = plt.plot(y, count_randfreq, '^:', label=labels[2], markersize=9, linewidth=2)
# plot_rand, = plt.plot(y,count_rand,'^:', label=labels[2], markersize=9, linewidth=2)
# plt.xticks(y, groups, rotation=90, fontsize=13)
# plt.yticks(np.arange(12))
# plt.legend([plot_orig, plot_randuniform, plot_randfreq, plot_rand], labels)
# plt.ylabel('Size of min set', fontsize=13)
# plt.savefig(result_folder+'minset_recipes.png',bbox_inches = "tight")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-10d30a7992a7> in <module>
#       2 import matplotlib.pyplot as plt
#       3 count_orig, count_randfreq, count_randuniform, count_rand = [],[],[],[]
# ----> 4 groups = list(group2minrecipe_orig.keys())
#       5 for group in groups:
#       6     count_orig.append(len(group2minrecipe_orig[group]))
#
# NameError: name 'group2minrecipe_orig' is not defined

# %%
result_folder
# Out:
# 'Derived_Data/CopyMutate/'

# %%
count_orig == count_randuniform
# Out:
# True

# %%
print('size of min set cover (orig recipes): ', len(min_set_orig), min_set_orig)

# %% [markdown]
# ### Find Min Set Cover for random recipes ###
# #### set MODEL_IDX to select either uniform model or frequency-conserve model ####
# #### Note!! it takes very long to compute ####

# %%
'''
For Model 3 : random uniform model
'''
#spicehnd2indic = json2dict('Derived_Data/Spice2Phytochemical2Disease/spice2indic_all.json')
#spicehnd2indic =  {process_name(k) : v for k, v in spicehnd2indic.items()}
spicerecipe2spicehnd = json2dict('Derived_Data/Overlap/spicetarla_spicehnd_dict.json') 

miss = []

cuisinerecipe2indic_rand = {}

for i in range(len(random_recipes_freq)):
    indic_list = []
    for s in randfreq_recipes[i]:
        for s_hnd in spicerecipe2spicehnd[s]:
            try:
                indic_list.extend(spicehnd2indic[process_name(s_hnd)])
            except:
                miss.append(s_hnd)
    cuisinerecipe2indic_rand[i] = list(set(indic_list))

print(set(miss))


# min real recipe set cover for indications
set_name = ['Recipes', 'Indications']
bi_graph_orig, recipe_topset_orig, indic_botset_orig = Bipartite_graph(cuisinerecipe2indic_random, set_name)
adjmtx_orig = bipartite.biadjacency_matrix(bi_graph_orig, row_order=indic_botset_orig, column_order=recipe_topset_orig).toarray()

n2 = adjmtx_orig.shape[1]
c = np.hstack([np.ones(n2), [0]])

#min_set_orig = Min_cover_set(cuisinerecipe2indic_random, recipe_topset_orig, indic_botset_orig, adjmtx_orig, c)
# Out:
# set()
# Total Recipes(top):  5636
# Total Indications(bot):  69

# %%
'''
For Model 1, 2 : the two copy mutate models 
'''
# min random recipe set cover for indications
NUM_RANDSET = 5
MODEL_IDX = 1
recipelist_uniform = []
recipelist_freq = []

for i in range(NUM_RANDSET):
    if MODEL_IDX == 1:
        try:
            print('current # of min set cover (freq-conserve model): ', len(minset_freq))
        except:
            minset_freq = []
    else:
        try:
            print('current # of min set cover (uniform model): ', len(minset_uniform))
        except:
            minset_uniform = []
    '''
    Generate Random Recipes for both models
    '''
    random_recipes_uniform = copy_mutate_uniformrand(r2s_combined, r_pool_count=20, s_count=5, s_pool_count=10, M=6, ratio_threshold=0.2)
    unique_recipe_count= len(list(set(map(tuple, random_recipes_uniform))))
    print('unique recipes count(uniformrand): ', unique_recipe_count)
    random_recipes_freq = copy_mutate_freqconserve(r2s_combined, r_pool_count=20, s_count=5, s_pool_count=10, M=6, ratio_threshold=0.2)
    unique_recipe_count= len(list(set(map(tuple, random_recipes_freq))))
    print('unique recipes count(freqconserve): ', unique_recipe_count)
    
    recipelist_uniform.append(random_recipes_uniform)
    recipelist_freq.append(random_recipes_freq)
    '''
    Generate {random recipe: indication} dict
    Select either result from uniform model or freq-conserve model
    '''
    cuisinerecipe2indic_rand = {}
    RAND_RECIPES = [random_recipes_uniform, random_recipes_freq]
    for i in range(len(random_recipes_freq)):
        indic_list = []
        for s in RAND_RECIPES[MODEL_IDX][i]:
            for s_hnd in spicerecipe2spicehnd[s]:
                indic_list.extend(spicehnd2indic[s_hnd])
        cuisinerecipe2indic_rand[i] = list(set(indic_list))
        
    '''
    Find min random recipe set cover for indications
    '''
    bi_graph_rand, recipe_topset_rand, indic_botset_rand = Bipartite_graph(cuisinerecipe2indic_rand, set_name)
    adjmtx_rand = bipartite.biadjacency_matrix(bi_graph_rand, row_order=indic_botset_rand, column_order=recipe_topset_rand).toarray()

    
    n2 = adjmtx_rand.shape[1]
    c = np.hstack([np.ones(n2), [0]])
    
    min_set_rand = Min_cover_set(cuisinerecipe2indic_rand, recipe_topset_rand, indic_botset_rand, adjmtx_rand, c)
    if MODEL_IDX == 1:
        minset_freq.append(min_set_rand)
    else:
        minset_uniform.append(min_set_rand)

# %%
# Save intermediate results
dict2json(recipelist_freq,result_folder+ 'recipelist_freq.json')
dict2json(minset_freq, result_folder+ 'minset_freq.json')
dict2json(recipelist_uniform, result_folder+ 'recipelist_uniform.json')
dict2json(minset_uniform,result_folder+  'minset_uniform.json')

# %% [markdown]
# ## Generate minset_freq with recipe name ##
# ### replace recipe idx in minset with real recipe with spice names ###

# %%
minset_freq = json2dict('Derived_Data/CopyMutate/minset_freq.json')
recipelist_freq = json2dict('Derived_Data/CopyMutate/recipelist_freq.json')

minset_freq_withname = [[recipelist_freq[i][recipe_idx] for recipe_idx in minset_freq[i]] for i in range(len(recipelist_freq))]
dict2json(minset_freq_withname, result_folder+ 'minset_freq_withname.json')

# %% [markdown]
# ### --- Trash below --- ###

# %%
'''
SAVED RESULTS (minset for random recipe):
# of spices: 130
#recipes in r_pool when remaining spices reach zero: 646
#recipes in r_pool in final stage: 5636
unique recipes count(uniformrand):  5627
#recipes in r_pool when remaining spices reach zero: 646
#recipes in r_pool in final stage: 5636
unique recipes count(freqconserve):  3698
Total Recipes(top):  5636
Total Indications(bot):  792
All indications are covered:  True
# of spices: 130
#recipes in r_pool when remaining spices reach zero: 646
#recipes in r_pool in final stage: 5636
unique recipes count(uniformrand):  5628
#recipes in r_pool when remaining spices reach zero: 646
#recipes in r_pool in final stage: 5636
unique recipes count(freqconserve):  3553
Total Recipes(top):  5636
Total Indications(bot):  791
All indications are covered:  True
# of spices: 130
#recipes in r_pool when remaining spices reach zero: 646
#recipes in r_pool in final stage: 5636
unique recipes count(uniformrand):  5630
#recipes in r_pool when remaining spices reach zero: 646
#recipes in r_pool in final stage: 5636
unique recipes count(freqconserve):  4089
Total Recipes(top):  5636
Total Indications(bot):  795
All indications are covered:  True
# of spices: 130
#recipes in r_pool when remaining spices reach zero: 646
#recipes in r_pool in final stage: 5636
unique recipes count(uniformrand):  5632
#recipes in r_pool when remaining spices reach zero: 646
#recipes in r_pool in final stage: 5636
unique recipes count(freqconserve):  2404
Total Recipes(top):  5636
Total Indications(bot):  767
All indications are covered:  True
# of spices: 130
#recipes in r_pool when remaining spices reach zero: 646
#recipes in r_pool in final stage: 5636
unique recipes count(uniformrand):  5631
#recipes in r_pool when remaining spices reach zero: 646
#recipes in r_pool in final stage: 5636
unique recipes count(freqconserve):  3179
Total Recipes(top):  5636
Total Indications(bot):  795
All indications are covered:  True
'''

'''

### Min set cover results ###
size of min set cover (random recipes by freq-conserve model):  4 
<br> [1167, 1338, 2875, 3191] <br>
size of min set cover (random recipes by uniform model): 6 
<br> [201, 300, 621, 1854, 3061, 4550] <br>
<br> size of min set cover (orig recipes):  8 <br>
['Pizza Khichu', 'Bengali Mixed Vegetable Dry Sabzi,  Panch Phodoner Chorchori', 'Flaxseeds Dry Chutney, South Indian Flax Seeds Podi', 'Salad with Papad', 'Pappadam', 'Chat (khakra)', 'Paneer Tava Masala, Punjabi Tawa Paneer Masala Recipe', 'Batatyachi Amti Recipe Card'] 
'''

# %%
'''
ABANDON 
'''
# ORIGINAL VERSION

# Random recipe generator with Copy Mutate Algorithm

# s: spice ingredients r: recipe

def copy_mutate_orig(r2s_orig, r_pool_count=20, s_count=7, s_pool_count=10, M=6, ratio_threshold=0.2, seed=0):
    '''
    Args: 
        r2s_orig - original r2s dictionary
        
        r_pool_count - initial number of r(recipe) in r_pool, will be updated
        
        s_count - number of s(spice) per one recipe 
        (QUESTION: is s_count a fixed value? is every random recipe contain same number of spices?)
        
        s_pool_count - initial number of s(spice) in s_pool, will be updated 
        
        M - number of mutations per time step
        
        ratio_threshold - threshold to maintain and add s(spice) to s_pool if s2r_ratio below threshold. 
        (QUESTION: what value should ratio_threshold take?)
    
    Return: random recipe sets
    '''
    s_orig = list(set(list(chain.from_iterable(r2s_orig.values())))) # all spices
    r_orig = list(r2s_orig.keys()) # all recipes
    s_orig_count = len(s_orig) # number of all spices
    r_orig_count = len(r_orig) # number of all recipes

    # keep track of remaining spice collection
    # initially contains all spices encoded by number
    s_orig_coded = list(range(0,s_orig_count)) 

    fitness_vals = np.random.uniform(0,1,s_orig_count) # generate random fitness values for all spices
    s2fitnessvals = dict(zip(s_orig_coded, fitness_vals)) # generate spice2fitnessvals mapping 

    s_pool = random.sample(s_orig_coded, s_pool_count) # initialize s_pool with #s_pool_count of spices randomly selected

    # remove spice in s_pool from original spice collection (i.e. s_orig_coded)
    for s in s_pool:
        s_orig_coded.remove(s) 

    # generate initial recipe pool (i.e. r_pool)
    # initialize a list of #r_pool_count of recipes, each containing #s_count of spices randomly selected from s_pool
    r_pool = []
    count = 0
    while(1):
        r_rand = random.sample(s_pool, s_count)
        r_rand.sort()
        if count == r_pool_count:
            break
        if r_rand not in r_pool:
            r_pool.append(r_rand)
            count += 1

    r_pool_orig = r_pool.copy()

    #ratio_threshold = s_pool_count/r_pool_count

    seed = 0  # QUESTION: how should we set random seed? different seed per iteration?
    random.seed(seed)

    while(1):# time step
        if len(r_pool) == r_orig_count:
            break
        s2r_ratio = s_pool_count/len(r_pool) # ratio btw #s in s_pool and #r in r_pool
        if s2r_ratio < ratio_threshold and len(s_orig_coded):
            if len(s_orig_coded) == 1:
                print('#recipes in r_pool when remaining spices reach zero:', len(r_pool))
            # add new spice into r_pool
            # pop out a spice by index from the remaining spice collection, and push to s_pool
            s_pop = random.randint(0,len(s_orig_coded) - 1)
            s_pool.append(s_orig_coded.pop(s_pop))  
        s_pool_count = len(s_pool)
        r_pool_count = len(r_pool)
        # randomly select a recipe from the r_pool (recipe pool) for mutation 
        r_idx = random.randint(0, r_pool_count - 1)
        r_mutate = r_pool[r_idx].copy() 
        for m in range(M): # mutation
            seed += 1
            # randomly select a spice from r_mutate's spice list
            s_idx = random.randint(0,s_count - 1)
            s_from_r = r_mutate[s_idx] 
            # randomly select a spice from s_pool
            # QUESTION: should the random selection from s_pool consider all the spice in s_pool or only those not in the current r_mutate?
            s_subpool = list(set(s_pool) - set(r_mutate))    
            s_from_subpool = s_subpool[random.randint(0,len(s_subpool) - 1)]  
            if s2fitnessvals[s_from_r] < s2fitnessvals[s_from_subpool]:
                r_mutate[s_idx] = s_from_subpool
            r_mutate.sort()
        # add mutated recipe to r_pool
        # removed checking mutated daughter recipe same with mother recipe, could be intrepreted as using different cooking procedure but containing same ingredients
        r_pool.append(r_mutate)
    print('#recipes in r_pool in final stage:', len(r_pool))
    
    # decode random recipes (i.e. replace number with spice name)
    random_recipes = []
    for r in r_pool:
        recipe_list = []
        for s in r:
            recipe_list.append(s_orig[s])
        random_recipes.append(recipe_list)
    return random_recipes

# %%
'''
# generate {cuisinerecipe : indication} dict
cuisinerecipe2spicerecipe_orig = json2dict('cuisinerecipe2spicerecipe_combined_overlap.json')
spicerecipe2spicehnd = json2dict('spicerecipe_spicehnd_dict.json')
spicehnd2indic = json2dict('spiceherb_indication_dict.json')
spicehnd2indic =  {' '.join(k.lower().split()): v for k, v in spicehnd2indic.items()}

cuisinerecipe2indic_orig = {}
for r in cuisinerecipe2spicerecipe_orig.keys():
    indic_list = []
    for s in cuisinerecipe2spicerecipe_orig[r]:
        for s_hnd in spicerecipe2spicehnd[s]:
            indic_list.extend(spicehnd2indic[s_hnd])
    cuisinerecipe2indic_orig[r] = list(set(indic_list))
'''
