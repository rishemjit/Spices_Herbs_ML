# %%
import json
import re
from xlrd import open_workbook
import pandas
from pandas import ExcelWriter
import math
import numpy as np
from itertools import chain
from bs4 import BeautifulSoup
import networkx as nx
from networkx.algorithms import bipartite
from Graph_Helpers import *
from itertools import islice

# %% [markdown]
# ## no of recipes in tarla dalal and Sanjeev Kapoor crawled

# %%
# recipe_tarla -> list of dicts, recipes with fields such as '_id', 'country', etc
# recipe_sanj -> list of dicts, recipes with fields such as  'country', etc

with open('TarlaDalal.json', 'rb') as json_file:
    recipe_tarla = [json.loads(line.decode('utf-8')) for line in json_file]
with open('SanjeevKapoor.json', 'r') as json_file:
    recipe_sanj = json.load(json_file)

print('Number of Recipe (Tarla): ', len(recipe_tarla))
print('Number of Recipe (Sanjeev): ', len(recipe_sanj))
# Out:
# Number of Recipe (Tarla):  3876
# Number of Recipe (Sanjeev):  9336

# %% [markdown]
# ## no of recipes belnging to different Cuisines
# ** In tarla Dalal, we have region tags and there  can be multiple multiple tags corresponding to a cuisine. e.g.  'Punjabi': ['Punjabi Breakfast', 'Punjabi Dals / Kadhis', 'Punjabi Drinks, Lassi', 'Punjabi Paneer Delicacies', ....],
#
# ** In Tarla dalal, we have 9 cuisines

# %% [markdown]
# ### finding the tags corresponding to every cuisine :  tarla dalal

# %%
# Tarla

# CUISINE REGION : CUISINE TAGS
# cuisine category is modified to be the same in cuisine-state excel sheet

# There are multiple tags corresponding to a cuisine such as Bengali : 'Bengali Chutney / Raitas', 'Bengali Dals / Curry'
# cuisinetag_map_tarla -> dict, keys-> cuisine , values-> list of tags associated with partcular cusine

import re 
from string import digits 
import json

read_file = 'cuisine_tag_tarla.txt'
write_file = 'cuisinetag_map_tarla.json'
with open(read_file) as r_f:
    content = r_f.readlines()
    
cuisinetag_map_tarla = {}
tag_list = []
for line in content:
    
    if line[0].isdigit():
        # update dict with collected category: tag list mapping before move on to the next category
        if tag_list != []:
            cuisinetag_map_tarla.update({category: tag_list})
        # the next category and new tag list 
        category = re.sub('\(.*\)','', line).lstrip(digits).lstrip().rstrip()
        
        if category != 'South Indian':
            # to match the cuisine type in cuisineregion_state excel sheet
            category = category.split()[0]
        tag_list = [category] # this hould be changed to include category as well by rishem
    else:
        tag = re.sub('\(.*\)','',line).lstrip().rstrip()
        if tag == 'Maharashtrian Bhaat': # by rishem
            tag = tag+ ' (Rice)'          # by rishem
        if tag == 'Maharashtrian Upvas':   # by rishem
            tag= tag+ ' (Fasting)'         # by rishem
        tag_list.append(tag)
cuisinetag_map_tarla.update({category: tag_list})

print(cuisinetag_map_tarla,'\n\n # of cuisines: ',len(cuisinetag_map_tarla.keys()))

regiontags_tarla = list(chain.from_iterable(cuisinetag_map_tarla.values()))

dict2json(cuisinetag_map_tarla, write_file)

print(cuisinetag_map_tarla.keys())
# Out:
# {'Maharashtrian': ['Maharashtrian', 'Maharashtrian Bhaat (Rice)', 'Maharashtrian Bhaji', 'Maharashtrian Breakfast', 'Maharashtrian Chutneys / Pickles', 'Maharashtrian Chutneys, Maharashtrian Pickles', 'Maharashtrian Dal, Varan / Amti / Kalvan', 'Maharashtrian Rotis / Polis', 'Maharashtrian Snacks Nashta', 'Maharashtrian Sweet Dishes', 'Maharashtrian Upvas (Fasting)'], 'Bengali': ['Bengali', 'Bengali Chutney / Raitas', 'Bengali Dals / Curry', 'Bengali Khichdi / Rice', 'Bengali Rotis / Puri', 'Bengali Snacks', 'Bengali Subzi / Gravies', 'Bengali Sweets'], 'Jain': ['Jain', 'Jain Dal / Kadhi', 'Jain Naashta', 'Jain Paryushan', 'Jain Pickles / Chutneys / Raita / Salad', 'Jain Rice', 'Jain Rotis', 'Jain Soups', 'Jain Subzi / Gravies'], 'Hyderabadi': ['Hyderabadi', 'Hyderabadi Dishes', 'Hyderabad Famous Sweets', 'Hyderabadi Curry', 'Hyderabadi Dal', 'Hyderabadi Indian Bread', 'Hyderabadi Rice Dishes', 'Hyderabadi Sabzis', 'Hyderabadi Side Dishes/Accompaniments', 'Hyderabadi Soups', 'Hyderabadi Veg Biryani'], 'Mughlai': ['Mughlai', 'Mughlai Chawal / Biryani', 'Mughlai Dals', 'Mughlai Drinks', 'Mughlai Mithai', 'Mughlai Rotis', 'Mughlai Shahi Shurvat', 'Mughlai Subzis / Curries'], 'Gujarati': ['Gujarati', 'Gujarati Drinks', 'Gujarati Dry Snacks', 'Gujarati Faral, Faraal', 'Gujarati Breakfast', 'Gujarati Dal / Kadhi', 'Gujarati Farsans', 'Gujarati Kachumber / Chutneys / Achar', 'Gujarati Kathols', 'Gujarati Khichdi', 'Gujarati One Dish Meals', 'Gujarati Rotli, Gujarati Thepla', 'Gujarati Shaak Sabzi', 'Gujarati Sweet Mithai'], 'Rajasthani': ['Rajasthani', 'Rajasthani Food', 'Rajasthani Achaar Launji', 'Rajasthani Dry Snacks', 'Rajasthani Kadhi, Dal', 'Rajasthani Khichdi, Pulao', 'Rajasthani Mithai, Sweets', 'Rajasthani Naashta', 'Rajasthani Roti / Puri / Paratha', 'Rajasthani Subzi', 'Rajasthani Traditional Combinations'], 'Punjabi': ['Punjabi', 'Punjabi Breakfast', 'Punjabi Dals / Kadhis', 'Punjabi Drinks, Lassi', 'Punjabi Paneer Delicacies', 'Punjabi Pulao, Rice, Biryani', 'Punjabi Raita / Chtutney / Achar', 'Punjabi Rotis, Parathas', 'Punjabi Shorbas, Soups', 'Punjabi Subzis', 'Punjabi Swadisht Nashta', 'Punjabi Sweets'], 'South Indian': ['South Indian', 'Andhra Cuisine', 'Different types of Idlis', 'Different Types of Dosa', 'Karnataka Cuisine', 'Kerala Cuisine', 'South Indian Appe', 'South Indian Breakfast', 'South Indian Chutney', 'South Indian Curries / Subzis', 'South Indian Evening Snacks', 'South Indian Pachadi, Raita', 'South Indian Pickles', 'South Indian Podis', 'South Indian Rasam', 'South Indian Rice', 'South Indian Sambar', 'South Indian Sweets', 'South Indian Uttapam', 'South Indian Vada', 'Tamil Nadu Food']}
#
#  # of cuisines:  9
# dict_keys(['Maharashtrian', 'Bengali', 'Jain', 'Hyderabadi', 'Mughlai', 'Gujarati', 'Rajasthani', 'Punjabi', 'South Indian'])

# %% [markdown]
# ### tarla dalal: recipes and corresponding tags

# %%
# Tarla CUISINE recipe names and corresponding cuisine tags 
# cuisine_tag_dict_tarla -> keys -> recipe names, values-> corresponding cuisine tags (not cuisine)


cuisine_tag_dict_tarla = {}
for i in range(len(recipe_tarla)):
    tag = recipe_tarla[i]['cuisine']
    if tag != []:
        cuisine_tag_dict_tarla.update({recipe_tarla[i]['title']['text'] : tag})
    else:
        print('recipe without tags ',recipe_tarla[i]['title']['text'] )
        
dict2json(cuisine_tag_dict_tarla, 'cuisine_tag_dict_tarla.json')

print('\n no of recipes with cuisine tags , tarla dalal', len(cuisine_tag_dict_tarla))

dict(islice(cuisine_tag_dict_tarla.items(), 4))
# Out:
# recipe without tags  Burhani Raita, Hyderabadi Masala Curd Raita
# recipe without tags  Gil-e- Firdaus, Hyderabadi Rice Kheer
# recipe without tags  Hyderabadi Osmania Biscuit, Saffron Flavoured Biscuits
# recipe without tags  Hyderabadi Mixed Veg Korma
# recipe without tags  Khubani Halwa, Apricot Halwa
# recipe without tags  Hyderabadi Paneer Potato Kulcha
# recipe without tags  Hyderabadi Sofiyani Biryani
# recipe without tags  Hyderabadi Lauki Kheer with Mini Rasgullas
# recipe without tags  Sheer Khurma Or Hyderabadi Sheer Korma
#
#  no of recipes with cuisine tags , tarla dalal 3863
# {'Malai Kofta Curry': ['Punjabi Subzis', 'Mughlai Subzis / Curries'],
#  'Navratri Special Khichdi': ['Gujarati  Faral, Faraal'],
#  'Palak Parathas  By Ushaki': ['Punjabi Rotis, Parathas'],
#  'Vegetable Kootu  By shuba18': ['South Indian Curries / Subzis']}

# %% [markdown]
# ### tarla dalal: recipes and corresponding cuisine name
# ** Please note that a recipe can belong to more than one cuisine e.g. Vegetable Corn Bake ( Diabetic Recipe )': ['Jain', 'Gujarati'],

# %%
#cuisinerecipe2region_tarla -> dict, keys-> name of recipe, values-> list of name of cuisines
# one recipe can be associated with multiple cuisines

tag_notpresent = []
cuisine_regiontag_dict_tarla = {}
for cuisine, tags in cuisine_tag_dict_tarla.items():
    regiontag_list = []
    for t in tags:
        t = re.sub(' +', ' ', t).rstrip() ## by rishem 
        if t in regiontags_tarla:
            regiontag_list.append(t)
        else:
            
            tag_notpresent.append(t)  # by rishem
            
    if regiontag_list:
        cuisine_regiontag_dict_tarla.update({cuisine: regiontag_list})
dict2json(cuisine_regiontag_dict_tarla, 'cuisine_regiontag_dict_tarla.json')


print('tags not found ', len(set(tag_notpresent)), set(tag_notpresent)   )


cuisinerecipe2region_tarla = {}
for cuisine, regiontags in cuisine_regiontag_dict_tarla.items():
    region_list = []
    for regiontag in regiontags:
        for region in cuisinetag_map_tarla.keys():
            if regiontag in cuisinetag_map_tarla[region]: 
                region_list.append(region)
    # remember to drop the duplicate regions (there may be multiple region tags point to same region)
    cuisinerecipe2region_tarla.update({cuisine : list(set(region_list))}) 
    
region2cuisinerecipe_tarla = reverse_dict(cuisinerecipe2region_tarla) #shuchen
dict2json(region2cuisinerecipe_tarla, 'region2cuisinerecipe_tarla.json') #shuchen
region2recipecount_tarla = dict2countdict(region2cuisinerecipe_tarla, region2cuisinerecipe_tarla.keys()) #shuchen
dict2json(region2recipecount_tarla, 'region2recipecount_tarla.json') #shuchen

print('\n no of recipes in tarla Dalal after cleaning region tags', len(cuisinerecipe2region_tarla))

dict(islice(cuisinerecipe2region_tarla.items(), 4))
# Out:
# tags not found  37 {'Mexican Starters', 'Chinese Accompaniments', 'Chinese Stir Fry Vegetables', 'Indian Veg Recipes', 'American Main Dish', 'Mexican Tacos', 'Chinese Vegetable', 'Mexican Nachos', 'Bengali Recipes', 'American Breakfast', 'Chinese Starters', 'Mexican Main Dish', 'Lebanese Appetizers', 'Lebanese Dips', 'Italian Starters', 'Italian Veg Pasta', 'Chinese Basic', 'Jain International', 'French Baked dishes', 'Chinese Rice Dishes', 'French Breads', 'Mexican Dips', 'Thai Noodles', 'American Ice - Creams & Deserts', 'Chinese Soups', 'Italian Basic', 'Mexican Quesadillas', 'Thai Starters', 'Lebanese Soups', 'Thai Vegetables', 'Lebanese Salads', 'Thai Dips', 'Cuisine', 'Italian Desserts', 'Thai Salads', 'American Burgers / Grills', 'Chinese Mini Meals'}
#
#  no of recipes in tarla Dalal after cleaning region tags 3746
# {'Malai Kofta Curry': ['Mughlai', 'Punjabi'],
#  'Navratri Special Khichdi': ['Gujarati'],
#  'Palak Parathas  By Ushaki': ['Punjabi'],
#  'Vegetable Kootu  By shuba18': ['South Indian']}

# %% [markdown]
# ### Sanjeev kapoor, finding the tags corresponding to every cuisine
# ** The country information is availble in country field and it has associated cuisine tags. But clearly it is noisy. Country code "IN" is also associated with cuisine tags "Italian", "Middle Eastern", etc. Also, multiple tags are associated with one recipe

# %%
tag_list_s = []

for i in range(len(recipe_sanj)):
    country = recipe_sanj[i]['country']
    tag = recipe_sanj[i]['tags']['cuisine']
    #print( country, tag, recipe_sanj[i]['title']['text'],)
    # Consider tags that's related to 'IN" India
    if country == 'IN':
        tag = recipe_sanj[i]['tags']['cuisine']
        if tag != []:
            tag_list_s.append(tag[0].rstrip().lstrip())


tag_set_s = set(tag_list_s)  # 102 cuisine type, see cuisinestate file for all indian cuisine name
print('tags associated with country code IN \n', len(tag_set_s), tag_set_s)



#region2cuisinerecipe_sanj[tag].append(recipe_sanj[i]['title']['text'])
# Out:
# tags associated with country code IN
#  96 {'South African', 'Indo-Chinese', 'Other Cuisines', 'Spanish', 'Mumbai', 'Indo Chinese', 'Chettinaad', 'Indo-Mexican', 'German Cuisine', 'fusion', 'TamilNadu', 'Awadhi', 'Malaysian', 'Georgian', 'Sri Lankan', 'African', 'Turkish', 'Uttar Pradesh', 'Coorg', 'Russian', 'Swiss', 'British', 'Indian', 'Chettinad', 'Tex-Mex', 'Punjabi', 'Italian', 'North Eastern', 'Singaporean', 'Hyderabadi', 'Viennese', 'Scottish', 'Indian Fusion', 'Moroccan', 'Bengali', 'Lebanese', 'Portuguese', 'Indonesian', 'Marwari', 'Korean', 'Indo-Italian', 'Karnataka', 'Bihari', 'Greek', 'Moghlai', 'Mediterranean', 'Oriental', 'Middle Eastern', 'Assam', 'Jordanian', 'Phillipine', 'Other cuisines', 'Continental', 'Peruvian', 'Maharashtrian', 'Indo-chinese', 'Mangalorean', 'Andhra', 'Rome', 'Kerala', 'Chinese', 'Tamil Nadu', 'Persian', 'Sindhi', 'Odia', 'Gujarati', 'Thai', 'Mexican', 'Madhya Pradesh', 'Goan', 'Caribbean', 'Australian', 'Fusion', 'American', 'Burmese', 'Pakistani', 'German', 'indian', 'Mongolian', 'Jain', 'Cuban', 'Brazilian', 'Rajasthani', 'Canadian', 'karnataka', 'South Indian', 'French', 'Vietnamese', 'Japanese', 'Polish', 'Kashmiri', 'Jamaican', 'parsi', 'Denmark', 'Other', 'Parsi'}

# %% [markdown]
# ** spelling and case-senstivity : Karnatka and karnataka, 'Chettinad' and  'Chettinaad', 'TamilNadu' and 'Tamil Nadu'
#
# ** 4 south indian states separate as well as 'South Indian' tag
#
# ** 'Mumbai' can be mapped to 'Maharashtra', but have kept separtely for the time being.
#
# ** ignoring Coorg for the time being, but can be mapped to karnatka
#
# ** 'Hyderabadi' can be mapped to andhra
#
# ** 'Chettinad' can be mapped to tamil nadu
#
# ** 'Mangalorean' can be mapped to Karnataka

# %%
# tagcuisine_map_sanjeev -> dict (set manually), keys-> tag , values-> associated cusine

tagcuisine_map_sanj ={ 'Jain': 'Jain',
                         'Maharashtrian':'Maharashtrian', 
                         'Rajasthani': 'Rajasthani', 'Punjabi':'Punjabi','Gujarati':'Gujarati',
                         'South Indian':'South Indian',  'Bengali':'Bengali',
                         'Hyderabadi': 'Hyderabadi', 
                         'Karnataka': 'Karnataka',
                         'karnataka' : 'Karnataka',
                        'Goan': 'Goan',
                        'Kerala': 'Kerala',
                        'Uttar Pradesh': 'Uttar Pradesh',
                        'Tamil Nadu':'Tamil Nadu',
                         'TamilNadu': 'Tamil Nadu',
                        'Kashmiri': 'Kashmiri', 
                        'Andhra': 'Andhra',
                      'Parsi' : 'Parsi',
                        'Sindhi':'Sindhi','parsi':'Parsi',
                        'Moghlai':'Mughlai'
                         } #'Mumbai': 'Mumbai','Awadhi': 'Awadhi','Parsi' : 'Parsi',
                        #'Marwari': 'Marwari','Sindhi':'Sindhi','parsi':'Parsi','North Eastern': 'North Eastern',
                        #'Chettinad' :'Chettinad','Assam': 'Assam','Bihari':'Bihari' ,'Moghlai':'Mughlai',
                         # 'Mangalorean':'Mangalorean', 'Madhya Pradesh': 'Madhya Pradesh',

cuisines_sanj =list(set(tagcuisine_map_sanj.values()))


print('no of cuisines in Sanjeev Kapoor:', len(cuisines_sanj ))


tag_sanj = list(tagcuisine_map_sanj.keys())
# Out:
# no of cuisines in Sanjeev Kapoor: 18

# %% [markdown]
# ### sanjeevKapoor: recipes and corresponding cuisine name
# ### counting of recipes in each cuisine, cuisine2recipecount_sanj¶
#
# ** recipes can belong to more than one cuisine but it seems that most of the recipes belong to one cuisine

# %%
#cuisinerecipe2region_sanj -> dict, keys-> name of recipe, values-> list of name of cuisines
# cuisine2recipecount_sanj -> dict, keys-> cuisine name, values-> count of recipes
# cuisine_overlapcount_sanj-> dataframe


cuisine2recipecount_sanj = dict.fromkeys(cuisines_sanj, 0)
cuisinerecipe2region_sanj = {}
tag_notpresent = []

for i in range(len(recipe_sanj)):
    cuisine = recipe_sanj[i]['title']['text']
    country = recipe_sanj[i]['country']
    region_list = []
    if country == 'IN':           # if country is India
        tag = recipe_sanj[i]['tags']['cuisine']
        #print( country, tag, cuisine)
        if tag != []:
            for t in tag:
                temp = t.rstrip().lstrip()
                if temp in tag_sanj:
                    region_list.append(tagcuisine_map_sanj[temp])
                    cuisine2recipecount_sanj[tagcuisine_map_sanj[temp]] +=1
                else:
                    tag_notpresent.append(temp)
                                                
            if region_list != []:
                cuisinerecipe2region_sanj.update({cuisine : list(set(region_list))})
            
dict2json(cuisine2recipecount_sanj, 'region2recipecount_sanj.json') #shuchen
region2cuisinerecipe_sanj = reverse_dict(cuisinerecipe2region_sanj) #shuchen
dict2json(region2cuisinerecipe_sanj, 'region2cuisinerecipe_sanj.json') #shuchen

print('no of recipes in Sanjeev Kapoor belonging to Indian cusines', len(cuisinerecipe2region_sanj))

print('\n tags not found: ', set(tag_notpresent))

print('\n', cuisine2recipecount_sanj)
dict(islice(cuisinerecipe2region_sanj.items(), 4))
cuisine2recipecount_sanj
# Out:
# no of recipes in Sanjeev Kapoor belonging to Indian cusines 2090
#
#  tags not found:  {'South African', 'Swiss', 'British', 'Indian', 'Caribbean', 'Indo-Chinese', 'Australian', 'Fusion', 'Oriental', 'American', 'Burmese', 'Pakistani', 'Other Cuisines', 'Middle Eastern', 'German', 'indian', 'Spanish', 'Chettinad', 'Assam', 'Mumbai', 'Jordanian', 'Indo Chinese', 'Tex-Mex', 'Italian', 'Mongolian', 'Other cuisines', 'Phillipine', 'Continental', 'North Eastern', 'Chettinaad', 'Peruvian', 'Singaporean', 'Viennese', 'Scottish', 'Cuban', 'Indian Fusion', 'Moroccan', 'Brazilian', 'Indo-Mexican', 'Canadian', 'German Cuisine', 'Lebanese', 'Indo-chinese', 'Portuguese', 'fusion', 'French', 'Mangalorean', 'Indonesian', 'Marwari', 'Rome', 'Vietnamese', 'Awadhi', 'Chinese', 'Malaysian', 'Japanese', 'Sri Lankan', 'Polish', 'Georgian', 'Korean', 'Indo-Italian', 'Persian', 'African', 'Turkish', 'Bihari', 'Odia', 'Greek', 'Thai', 'Coorg', 'Jamaican', 'Mexican', 'Denmark', 'Other', 'Madhya Pradesh', 'Russian', 'Mediterranean'}
#
#  {'Maharashtrian': 442, 'Goan': 79, 'Tamil Nadu': 179, 'Bengali': 113, 'Karnataka': 133, 'Sindhi': 51, 'Jain': 1, 'South Indian': 25, 'Kerala': 141, 'Gujarati': 195, 'Kashmiri': 48, 'Andhra': 57, 'Parsi': 52, 'Uttar Pradesh': 118, 'Rajasthani': 91, 'Mughlai': 5, 'Hyderabadi': 150, 'Punjabi': 353}
# {'Andhra': 57,
#  'Bengali': 113,
#  'Goan': 79,
#  'Gujarati': 195,
#  'Hyderabadi': 150,
#  'Jain': 1,
#  'Karnataka': 133,
#  'Kashmiri': 48,
#  'Kerala': 141,
#  'Maharashtrian': 442,
#  'Mughlai': 5,
#  'Parsi': 52,
#  'Punjabi': 353,
#  'Rajasthani': 91,
#  'Sindhi': 51,
#  'South Indian': 25,
#  'Tamil Nadu': 179,
#  'Uttar Pradesh': 118}

# %% [markdown]
# ### sanjeev Kapoor, counting overlap of recipes
# #### we know in sanjeev kapoor and tarla dalal,  a recipe has been associated with maximum of 3 cuisines, using this information to hard code which is not a good practice
#
# #### most of the recipes are associated with single recipe

# %%
#cuisine_overlapcount_sanj -> dataframe

import matplotlib.pyplot as plt
cuisine_overlapcount_sanj = pandas.DataFrame(0, columns=cuisines_sanj, index=cuisines_sanj )
no_region= []

for recipe, region_list in cuisinerecipe2region_sanj.items():
    temp= len(region_list)
    no_region.append(temp)
    if temp == 2:
        cuisine_overlapcount_sanj[region_list[0]][region_list[1]]+=1
        cuisine_overlapcount_sanj[region_list[1]][region_list[0]]+=1
    elif temp ==3:
        cuisine_overlapcount_sanj[region_list[0]][region_list[1]]+=1
        cuisine_overlapcount_sanj[region_list[1]][region_list[2]]+=1
        cuisine_overlapcount_sanj[region_list[0]][region_list[2]]+=1
        cuisine_overlapcount_sanj[region_list[1]][region_list[0]]+=1
        cuisine_overlapcount_sanj[region_list[2]][region_list[1]]+=1
        cuisine_overlapcount_sanj[region_list[2]][region_list[0]]+=1
    else:
        cuisine_overlapcount_sanj[region_list[0]][region_list[0]]+=1
#print(cuisine_overlapcount_sanj)
temp = plt.hist(no_region)
plt.title('Sanjeev Kapoor')
plt.show()
print('fraction of recipes associated with single cuisine', temp[0][0]/sum(temp[0]))
# Out:
# fraction of recipes associated with single cuisine 0.988995215311

# %% [markdown]
# ### Tarla dalal: counting overlap among cuisines

# %%
cuisines_tarla = list(cuisinetag_map_tarla.keys())


cuisine_overlapcount_tarla = pandas.DataFrame(0, columns=cuisines_tarla, index=cuisines_tarla )
no_region= []

for recipe, region_list in cuisinerecipe2region_tarla.items():
    temp= len(region_list)
    no_region.append(temp)
    if temp == 2:
        cuisine_overlapcount_tarla[region_list[0]][region_list[1]]+=1
        cuisine_overlapcount_tarla[region_list[1]][region_list[0]]+=1
    elif temp ==3:
        cuisine_overlapcount_tarla[region_list[0]][region_list[1]]+=1
        cuisine_overlapcount_tarla[region_list[1]][region_list[2]]+=1
        cuisine_overlapcount_tarla[region_list[0]][region_list[2]]+=1
        cuisine_overlapcount_tarla[region_list[1]][region_list[0]]+=1
        cuisine_overlapcount_tarla[region_list[2]][region_list[1]]+=1
        cuisine_overlapcount_tarla[region_list[2]][region_list[0]]+=1
    else:
        cuisine_overlapcount_tarla[region_list[0]][region_list[0]]+=1

temp = plt.hist(no_region)
plt.title('Tarla Dalal')
plt.show()
print('fraction of recipes associated with single cuisine', temp[0][0]/sum(temp[0]))
cuisine_overlapcount_tarla
# Out:
# fraction of recipes associated with single cuisine 0.913774693006
#                Maharashtrian  Bengali  Jain  Hyderabadi  Mughlai  Gujarati  \
# Maharashtrian            247        1     4           0        1        69
# Bengali                    1      174     3           0        2         3
# Jain                       4        3   212           0        7        54
# Hyderabadi                 0        0     0          15        4         1
# Mughlai                    1        2     7           4      155         0
# Gujarati                  69        3    54           1        0       564
# Rajasthani                 1        1     7           0        0         2
# Punjabi                   13       19    23           4       43        12
# South Indian              11        2    24           5        3         6
#
#                Rajasthani  Punjabi  South Indian
# Maharashtrian           1       13            11
# Bengali                 1       19             2
# Jain                    7       23            24
# Hyderabadi              0        4             5
# Mughlai                 0       43             3
# Gujarati                2       12             6
# Rajasthani            160       16             0
# Punjabi                16     1080             4
# South Indian            0        4           816

# %%
np.sum(cuisine_overlapcount_tarla)
# Out:
# Maharashtrian     347
# Bengali           205
# Jain              334
# Hyderabadi         29
# Mughlai           215
# Gujarati          711
# Rajasthani        187
# Punjabi          1214
# South Indian      871
# dtype: int64

# %% [markdown]
# ### We can
#
# * remove the recipes associated with more than 1 cuisine
# * count them in all cuisines associated with them
# * randomly assign it to one of the cuisines

# %%
'''
def remove_recipe_multiplecuisines(cuisinerecipe2region):
    updated_cuisinerecipe2region={}
    for recipe, region_list in cuisinerecipe2region.items():
        if len(region_list)==1:
            updated_cuisinerecipe2region[recipe] = region_list
    return updated_cuisinerecipe2region
             
print( 'no ofrecipes in tarla dalal ', len(cuisinerecipe2region_tarla))       
cuisinerecipe2region_tarla_nonoverlap= remove_recipe_multiplecuisines(cuisinerecipe2region_tarla)  
print( 'no ofrecipes after removing the overlapping cusisnes ', len(cuisinerecipe2region_tarla_nonoverlap))

print( '\n no ofrecipes in sanjeev kapoor ', len(cuisinerecipe2region_sanj))
cuisinerecipe2region_sanj_nonoverlap= remove_recipe_multiplecuisines(cuisinerecipe2region_sanj)  
print( 'no ofrecipes after removing the overlapping cusisnes ', len(cuisinerecipe2region_sanj_nonoverlap))

'''
# Out:
# "\ndef remove_recipe_multiplecuisines(cuisinerecipe2region):\n    updated_cuisinerecipe2region={}\n    for recipe, region_list in cuisinerecipe2region.items():\n        if len(region_list)==1:\n            updated_cuisinerecipe2region[recipe] = region_list\n    return updated_cuisinerecipe2region\n             \nprint( 'no ofrecipes in tarla dalal ', len(cuisinerecipe2region_tarla))       \ncuisinerecipe2region_tarla_nonoverlap= remove_recipe_multiplecuisines(cuisinerecipe2region_tarla)  \nprint( 'no ofrecipes after removing the overlapping cusisnes ', len(cuisinerecipe2region_tarla_nonoverlap))\n\nprint( '\n no ofrecipes in sanjeev kapoor ', len(cuisinerecipe2region_sanj))\ncuisinerecipe2region_sanj_nonoverlap= remove_recipe_multiplecuisines(cuisinerecipe2region_sanj)  \nprint( 'no ofrecipes after removing the overlapping cusisnes ', len(cuisinerecipe2region_sanj_nonoverlap))\n\n"

# %%
print( 'no ofrecipes in tarla dalal ', len(cuisinerecipe2region_tarla)) 
cuisinerecipe2region_tarla_nonoverlap= cuisinerecipe2region_tarla
print( 'no ofrecipes after not removing the overlapping cusisnes ', len(cuisinerecipe2region_tarla_nonoverlap))


print( '\n no ofrecipes in sanjeev kapoor ', len(cuisinerecipe2region_sanj))
cuisinerecipe2region_sanj_nonoverlap= cuisinerecipe2region_sanj
print( 'no ofrecipes after not removing the overlapping cusisnes ', len(cuisinerecipe2region_sanj_nonoverlap))
# Out:
# no ofrecipes in tarla dalal  3746
# no ofrecipes after not removing the overlapping cusisnes  3746
#
#  no ofrecipes in sanjeev kapoor  2090
# no ofrecipes after not removing the overlapping cusisnes  2090

# %% [markdown]
# ## find spices present in tarla dalal and sanjeev kapoor after cleaning.

# %%
# SPICE RECIPE - SPICE (HANDBOOK) 
# Mapping between spice (appeared in recipes) and spice/herb ingre(appeared in handbooks)
 
# spice recipe data excel modified after compared to tarla and sanjeev 
# bay leaves or bay leaf 
# pigeon pea (if contain pegeon pea then include)
# roasted coconut (if contain coconut then include)
# couldn't find cassia, chinese 5 spice powder, sage, sandwich masala, marjoram, coloured aniseed sweets,black mustard seed oil in tarla or sanjeev

import unidecode

write_file = 'spicetarla_spicehnd_dict.json'
spice_excel = pandas.read_excel('recipespice_data1.xlsx')   # remove 'corainder' since it doesn't occur in the handbook
spice_list = spice_excel.values.tolist()

spice_dict = {}

for line in spice_list: 
    if type(line[1]) is not float and line[1] !='NS': # if not 'NS' and 'NA'; line[1] is entire unicode string
        l = re.sub('(NA_|NS_)[^,]*,','',line[1]) # remove 'NA_','NS_' prefix from the string 
        l = [re.sub('  ',' ',item.lstrip().rstrip().lower()) for item in l.split(',')] # convert string of items to list of items and remove leading spaces
        if(l == []): # if item empty, not insert into dict
            continue
        s = re.sub('  ',' ',line[0]).strip()
        #print(s,l)
        spice_dict.update({s.lower():l})
dict2json(spice_dict, write_file)   

spices_hnd = set(list(chain.from_iterable(spice_dict.values()))) # hndbook spice ingredients in spice recipe
spice_excel= list(spice_dict.keys())  # spices appeared in Tarla Dalal recipe data  

print('Number of Spices in tarla dalal (manual annotation): ', len(spice_excel)) # 109
print('Number of related Spices (handbook): ', len(spices_hnd)) # 46
# Out:
# Number of Spices in tarla dalal (manual annotation):  77
# Number of related Spices (handbook):  47

# %% [markdown]
# #### Tarlal dalal : finds recipes and corresponding ingredients (all, not just spices)

# %%
# cuisine_dict_orig -> dict, keys-> name of recipe, valjues-> list of ingredients present in recipe
# this code writes a file tarla_recipename_ingr_dict.json 

cuisine_dict_orig = {}
write_file = 'tarla_recipename2ingr_dict.json'

for i in range(len(recipe_tarla)):
    if recipe_tarla[i]['title']['text'] in cuisinerecipe2region_tarla_nonoverlap.keys():
        
        ingredients = recipe_tarla[i]['ingredients']['name']
        ingredients = [' '.join(re.sub(r'\(.*?\)', ' ', name).split()) for name in ingredients]
        cuisine_dict_orig.update({recipe_tarla[i]['title']['text']:ingredients})

j = json.dumps(cuisine_dict_orig,indent = 4)
with open(write_file,'w') as w_file:
    w_file.write(j)

len(cuisine_dict_orig)
# Out:
# 3746

# %% [markdown]
# #### Tarlal dalal : finds recipes and corresponding spices

# %%
# spices present in recipes
# RECIPE name : SPICEs(TARLA DALA)
# Exclude non-spice ingredients (spice recipe lower case, single space)
#cuisine_dict -> dict,keys-> recipe name, values-> list of spices
# writes tarla_recipename2spice.json with recipe names and spices

write_file = 'tarla_recipename2spice.json'
cuisine_dict = cuisine_dict_orig.copy()
other_ingr=[]
for cuis in cuisine_dict_orig.keys():
    ingr_list = []
    for ingr in cuisine_dict_orig[cuis]:
        
        
        #if ' '.join(ingr.lower().split()) in spice_excel:
        index= np.where(list(map(' '.join(ingr.lower().split()).__contains__, spice_excel)))[0] # by rishem, map string with list of substrings
        
                                                                  
        if len(index)>0:
            #print(ingr, index,  list(map(spice_excel.__getitem__, index) ))
            ingr_list.extend(list(map(spice_excel.__getitem__, index) ))# by rishem
        else:
            other_ingr.append(ingr)
            
            #ingr_list.append(' '.join(ingr.lower().split()))
        if 'coconut' in ingr.lower():
            ingr_list.append('coconut')
        if 'pigeon pea' in ingr.lower():
            ingr_list.append('pigeon pea')
        if 'pomegranate' in ingr.lower():
            ingr_list.append('pomegranate')
    cuisine_dict[cuis] = list(set(ingr_list))
    if ingr_list == []:   # Remove the  recipe that doesn't contain spices
        #print(cuisine_dict_orig[cuis])
        cuisine_dict.pop(cuis)

j = json.dumps(cuisine_dict,indent = 4)
with open(write_file, 'w') as w_file:
    w_file.write(j)
    
spice_tarla = set(list(chain.from_iterable(cuisine_dict.values()))) 

print('# of  recipes contain spices in Tarla:', len(cuisine_dict.keys()))
print('# of spice  in Tarla: ', len(spice_tarla)) # 84 from tarla
print('# of spice  in total: ', len(spice_excel)) # 109
#print('\nSpice recipes missed from the entire spice recipe set for Tarla: \n', set(spice_excel) - set(spice_tarla))

print(spice_tarla)
# Out:
# # of  recipes contain spices in Tarla: 3497
# # of spice  in Tarla:  64
# # of spice  in total:  77
# {'dill', 'bayleaf', 'peppercorn', 'tulsi', 'fenugreek', 'cassia', 'malgapodi powder', 'carom seeds', 'nigella seeds', 'biryani masala powder', 'dried ginger', 'degi mirch', 'yellow mustard seeds', 'ginger', 'mango', 'sambhar powder', 'pulao masala', 'fennel', 'curry powder', 'chaat masala', 'jal jeera powder', 'turmeric', 'chole masala', 'flax', 'sesame', 'angelica', 'pomegranate', 'kitchen king masala', 'asafoetida', 'poppy seeds', 'dabeli masala', 'kebab masala', 'tamarind', 'pav bhaji masala', 'black cardamom', 'chilli', 'mustard', 'bay lea', 'cardamom', 'curry leaves', 'panch phoron', 'saffron', 'aniseed', 'cumin', 'coconut', 'coriander', 'oregano', 'dried mixed herbs', 'star anise', 'tandoori masala', 'black pepper', 'caraway', 'rasam powder', 'all spice powder', 'goda masala', 'mint', 'chai masala', 'madras curry powder', 'garam masala', 'cinnamon', 'clove', 'garlic', 'basil', 'nutmeg'}

# %% [markdown]
# #### Sanjeev Kapoor : finds recipes and corresponding ingredients (all, not just spices)

# %%
# Sanjeev
# CUISINE RECIPE : INGREDIENTS (ALL)
# cuisine_dict_orig_s -> dict, keys-> name of recipe, valjues-> list of ingredients present in recipe
# this code writes a file sanjeev_recipename2ingr_dict.json

cuisine_dict_orig_s = {}

write_file = 'sanjeev_recipename2ingr_dict.json'
for i in range(len(recipe_sanj)):
    if recipe_sanj[i]['title']['text'] in cuisinerecipe2region_sanj_nonoverlap.keys():
        ingredients = recipe_sanj[i]['ingredients']['name']
        ingredients = [' '.join(re.sub(r'\(.*?\)', ' ', name).split()) for name in ingredients]
        cuisine_dict_orig_s.update({recipe_sanj[i]['title']['text']:ingredients})
        
j = json.dumps(cuisine_dict_orig_s,indent = 4)

with open(write_file,'w') as w_file:
    w_file.write(j)

    
print(len(cuisine_dict_orig_s))
# Out:
# 2090

# %% [markdown]
# #### Sanjeev : finds recipes and corresponding spices

# %% [markdown]
# ####

# %%
# Sanjeev
#  cuisine_dict_s -> dict, key-> RECIPE name , va;ue-> SPICE  (spice recipes lower case, single space)

write_file = 'sanj_recipename2spice.json'
cuisine_dict_s = cuisine_dict_orig_s.copy()
other_ingr=[]
for cuis in cuisine_dict_orig_s.keys():
    ingr_list = []
    for ingr in cuisine_dict_orig_s[cuis]:
        
        index= np.where(list(map(' '.join(ingr.lower().split()).__contains__, spice_excel)))[0] # by rishem, map string with list of substrings
        
        #if ' '.join(ingr.lower().split()) in spice_excel:
        #    ingr_list.append(' '.join(ingr.lower().split()))
        if len(index)>0:
            #print(ingr,  list(map(spice_excel.__getitem__, index) ))
            ingr_list.extend(list(map(spice_excel.__getitem__, index) )) # by rishem
        else:
            other_ingr.append(ingr)
        
        if 'coconut' in ingr.lower():
            ingr_list.append('coconut')
        if 'pigeon pea' in ingr.lower():
            ingr_list.append('pigeon pea')
        if 'pomegranate' in ingr.lower():
            ingr_list.append('pomegranate')
    cuisine_dict_s[cuis] = list(set(ingr_list))
    if ingr_list == []:   # remove the cuisine recipe that doesn't contain spice recipes
        
        cuisine_dict_s.pop(cuis)

j = json.dumps(cuisine_dict_s,indent = 4)
with open(write_file, 'w') as w_file:
    w_file.write(j)
    
spice_sanjeev = set(list(chain.from_iterable(cuisine_dict_s.values()))) 
print('# of recipes contain spices in Sanjeev:', len(cuisine_dict_s.keys()))
print('# of spices  in Sanjeev:', len(spice_sanjeev)) # 80 from sanjeev
print('# of spice  from excel :', len(spice_excel)) # 109
print('\nSpice recipes missed from the entire spice recipe set for Sanjeev: \n', set(spice_excel) - set(spice_sanjeev))

# Note: cardamon (green cardamon, and many other cardamom in sanjeev)
# Out:
# # of recipes contain spices in Sanjeev: 1980
# # of spices  in Sanjeev: 52
# # of spice  from excel : 77
#
# Spice recipes missed from the entire spice recipe set for Sanjeev:
#  {'cayenne pepper', 'marjoram', 'bayleaf', 'malgapodi powder', 'tarragon', 'nigella seeds', 'biryani masala powder', 'degi mirch', 'pulao masala', 'jal jeera powder', 'angelica', 'flax', 'kitchen king masala', 'kebab masala', 'rosemary', 'panch phoron', 'oregano', 'dried mixed herbs', 'dried basil', 'tandoori masala', 'all spice powder', 'chai masala', 'madras curry powder', 'chinese 5 spice powder\xa0.', 'sandwich masala'}

# %%
with open('allspiceherb.json') as dict_file: # read from spice
    spice_handbook = json.loads(dict_file.read())
    
type(spice_handbook)

spice_handbook = [x.lower() for x in spice_handbook]

# %%
## map all spices from handbook to ingredients in sanjeev kapoor
#spice_handbook, other_ingr


match_list = []
temp=[]
for ingr in  other_ingr:
    
    index= np.where(list(map(' '.join(ingr.lower().split()).__contains__,spice_handbook)))[0] # by rishem, map string with list of substrings
    #print(index)   
        #if ' '.join(ingr.lower().split()) in spice_excel:
        #    ingr_list.append(' '.join(ingr.lower().split()))
    if len(index)>0:
        print(ingr, list(map(spice_handbook.__getitem__, index) ))
            #print(ingr, index,  list(map(spice_excel.__getitem__, index) ))
        match_list.extend(list(map(spice_handbook.__getitem__, index) )) # by rishem
    else:
        temp.append(ingr)
# Out:
# Tomato Puree ['tomato']
# Onions chopped ['onion']
# Tomato puree ['tomato']
# Onion finely chopped ['onion']
# Cashewnuts soaked ['cashew', 'oak']
# Green capsicum cut into roundels ['capsicum']
# Potatoes cut into roundels ['potato']
# Boiled onion paste ['onion']
# White Pumpkin ['pumpkin']
# Rice flour ['rice']
# Skinless Split Black Gram soaked for 3-4 hours ['oak']
# Bananas puree ['banana']
# Instant coffee powder ['coffee']
# Castor sugar ['castor']
# Vanilla essence ['vanilla']
# Basmati rice ['rice']
# Cashewnuts ['cashew']
# Almonds ['almond']
# Split black gram soaked ['oak']
# Tomatoes ['tomato']
# Onion chopped ['onion']
# Tomatoes chopped ['tomato']
# Lemon juice ['lemon']
# Spinach blanched and chopped ['spinach']
# Chickpeas soaked and boiled ['chickpea', 'oak']
# Potatoes boiled and mashed ['potato']
# Onion chopped ['onion']
# Tomato chopped ['tomato']
# Almonds ['almond']
# Almonds blanched, peeled and sliced ['almond']
# Split piegeon pea soaked ['oak']
# Onions ['onion']
# Tomato ['tomato']
# Dates ['date']
# Almonds blanched and sliced ['almond']
# Raw bananas 1 cm cubes ['banana']
# Rice ['rice']
# Lemon juice ['lemon']
# Onions chopped ['onion']
# Potatoes ['potato']
# Dates ['date']
# Onions finely chopped ['onion']
# Potatoes ['potato']
# Onion,sliced finely ['onion']
# Wheat flour ['wheat']
# Rice flour ['rice']
# Juice of 2 lemons ['lemon']
# Lemon juice ['lemon']
# Rice soaked for 15-20 minutes ['rice', 'oak']
# Onion chopped ['onion']
# Onions chopped ['onion']
# Red Pumpkin peeled and cut into medium-sized cubes ['pumpkin']
# Baby potatoes with skin boiled ['potato']
# Red pumpkin peeled and sliced ['pumpkin']
# Dried red chavli beans soaked overnight and boiled ['oak']
# Potatoes ['potato']
# Onion, sliced ['onion']
# Lemon juice ['lemon']
# Lemon juice ['lemon']
# Lemon rind ['lemon']
# Sambhar onions ['onion']
# Onions chopped ['onion']
# Dates ['date']
# Lemon juice ['lemon']
# Small onions sliced ['onion']
# Tomatoes chopped ['tomato']
# Banana leaves ['banana']
# Wheat flour ['wheat']
# Onion ['onion']
# Cashewnuts chopped ['cashew']
# Almonds slivered ['almond']
# Almonds coarsely powdered ['almond']
# Dried dates coarsely powdered ['date']
# Onion ['onion']
# Tomatoes ['tomato']
# Onion chopped ['onion']
# Tomato chopped ['tomato']
# Onion ['onion']
# Onion seeds ['onion']
# Tomatoes ['tomato']
# White Pumpkin seeded and cubed ['pumpkin', 'pumpkin seed']
# Rice flour mixed with 2 tablespoon water ['rice']
# Potatoes peeled ['potato']
# Carrot ['carrot']
# Tomato ['tomato']
# Soya nuggets soaked ['oak']
# Custard apple ['apple']
# Rice soaked ['rice', 'oak']
# Rice soaked and ground ['rice', 'oak']
# Baby potatoes ['potato']
# Lemon ['lemon']
# Cashewnut powder ['cashew']
# Basmati Rice soaked ['rice', 'oak']
# Almonds slivered ['almond']
# Kolam rice ['rice']
# Cashewnuts ['cashew']
# Elaichi bananas ['banana']
# Onions chopped ['onion']
# Carrots cut into cubes and blanched ['carrot']
# Cashewnuts ['cashew']
# Pineapple juice ['pineapple', 'apple']
# Lemon juice ['lemon']
# Kiwi fruit peeled and finely chopped ['kiwi']
# Rice soaked and coarsely ground ['rice', 'oak']
# Almonds slivered ['almond']
# Rice ['rice']
# Spring onion greens chopped ['onion']
# Tomatoes roughly chopped ['tomato']
# Ivy Gourd quartered vertically ['ivy', 'ivy gourd']
# Spinach Leaves leaves separated and blanched ['spinach']
# Onion ['onion']
# Juice of ¼ lemon ['lemon']
# Thin strips of red bell capsicum for garnishing ['capsicum']
# Tomatoes chopped ['tomato']
# Onions chopped ['onion']
# Baby potatoes boiled and peeled ['potato']
# Onions grated ['onion']
# Spinach Leaves blanched ['spinach']
# Onion chopped ['onion']
# Chickpeas soaked ['chickpea', 'oak']
# Juice of 1 lemon ['lemon']
# Tomatoes ['tomato']
# Onion seeds ['onion']
# Onion seeds ['onion']
# Spinach puree ['spinach']
# Spinach leaves shredded ['spinach']
# Spinach ['spinach']
# Onions chopped ['onion']
# Carrot ['carrot']
# Potatoes boiled and mashed ['potato']
# Onions chopped ['onion']
# Olive oil ['olive oil']
# Bananas ['banana']
# Lemon juice ['lemon']
# Kiwi peeled ['kiwi']
# Vanilla ice cream ['vanilla']
# Guavas ['guava']
# Tomatoes chopped ['tomato']
# Lemon juice ['lemon']
# Spring onions with greens ['onion']
# 1 flower made with spring onion bulb ['onion']
# Onions ['onion']
# Onions chopped ['onion']
# Tomatoes chopped ['tomato']
# Rice ['rice']
# Onion finely chopped ['onion']
# Lemon ['lemon']
# Almonds blanched and slivered ['almond']
# Red pumpkin peeled and cut into 1 inch cubes ['pumpkin']
# Potatoes boiled, peeled and cut into 1 inch cubes ['potato']
# Whole wheat flour ['wheat']
# Onions sliced ['onion']
# Pumpkin 1/2 inch cubes ['pumpkin']
# Potato 1/2 inch cubes ['potato']
# Tomatoes chopped ['tomato']
# Sweet potatoes boiled, peeled and mashed ['sweet potato', 'potato']
# Seedless dates ['date']
# Lemon juice ['lemon']
# Tomato ['tomato']
# Tomato ['tomato']
# Basmati rice soaked and drained ['rice', 'oak']
# Onion ['onion']
# Tomatoes finely chopped ['tomato']
# Onions chopped ['onion']
# Basmati rice soaked ['rice', 'oak']
# Almonds ['almond']
# Cashewnuts ['cashew']
# Rice raw ['rice']
# Onions finely chopped ['onion']
# Basmati rice soaked and drained ['rice', 'oak']
# Split skinless green gram soaked and drained ['oak']
# Peanuts ['peanut']
# Rice ['rice']
# Onions sliced and browned ['onion']
# Lemon juice ['lemon']
# Lemon Juice ['lemon']
# Lemon juice ['lemon']
# Roasted peanuts ['peanut']
# Medium onion grated ['onion']
# Banana Leaves ['banana']
# Tomatoes chopped ['tomato']
# Juice of 2 lemons ['lemon']
# Banana leaves ['banana']
# Basmati Rice ['rice']
# Onion sliced ['onion']
# Sweet potato finely chopped ['sweet potato', 'potato']
# Carrot finely chopped ['carrot']
# Onion finely chopped ['onion']
# Tomato sliced ['tomato']
# Onions finely chopped ['onion']
# Tomato puree thick ['tomato']
# Onion chopped ['onion']
# Carrots peeled cut into 1 inch pieces and blanched ['carrot']
# Green capsicums ['capsicum']
# Cashewnuts ['cashew']
# Onions chopped ['onion']
# Tomatoes chopped ['tomato']
# Kokum petals soaked in ¼ cup water ['oak']
# Lemon juice ['lemon']
# Lemon juice ['lemon']
# Tomato puree ['tomato']
# Potatoes boiled, peeled and mashed ['potato']
# Cashewnuts soaked ['cashew', 'oak']
# Onions finely chopped ['onion']
# Potatoes cut into cubes ['potato']
# Onions,chopped ['onion']
# Potatoes ['potato']
# Rice flour ['rice']
# Onions chopped ['onion']
# Tomatoes chopped ['tomato']
# Tomato puree ['tomato']
# Onions ['onion']
# Onion finely chopped ['onion']
# Rice ['rice']
# Onion ['onion']
# Chenna ['henna']
# Onion ['onion']
# Spring onion greens chopped ['onion']
# Onions chopped ['onion']
# Tomato puree ['tomato']
# Carrot roughly chopped ['carrot']
# Raw bananas ['banana']
# Onion chopped ['onion']
# Lemon juice ['lemon']
# Carrots grated ['carrot']
# Seedless dates roughly chopped ['date']
# Roasted peanuts coarsely powdered ['peanut']
# Rice old ['rice']
# Sweet potatoes ['sweet potato', 'potato']
# Lemon juice ['lemon']
# Onion finely chopped ['onion']
# Lemon juice ['lemon']
# Castor sugar ['castor']
# Chickpeas ['chickpea']
# Onion sliced ['onion']
# Castor sugar ['castor']
# Almonds coarsely powdered ['almond']
# Cashewnuts coarsely powdered ['cashew']
# Spinach Leaves ['spinach']
# Onion ['onion']
# Sambhar onions ['onion']
# Almonds chopped ['almond']
# Cashewnuts chopped ['cashew']
# Melon seeds ['melon']
# Cashewnuts ['cashew']
# Almonds ['almond']
# Cashewnuts ['cashew']
# Onions chopped ['onion']
# Onions chopped ['onion']
# Tomatoes chopped ['tomato']
# Potatoes boiled, peeled and cut into cubes ['potato']
# Onion chopped ['onion']
# Whole Wheat Flour ['wheat']
# Rice Flour ['rice']
# Basmati rice soaked ['rice', 'oak']
# Cashewnuts halved ['cashew']
# Almonds halved ['almond']
# Dried dates chopped ['date']
# Lemon juice ['lemon']
# Wholewheat Flour ['wheat']
# Cashewnuts chopped ['cashew']
# Almonds slivered ['almond']
# Tomatoes ['tomato']
# Tomato ketchup ['tomato']
# Potatoes boiled and peeled ['potato']
# Rice raw ['rice']
# Oats ['oats']
# Onion finely chopped ['onion']
# Carrots grated ['carrot']
# Cashewnuts chopped ['cashew']
# Bottle Gourd peeled and grated ['bottle gourd']
# Skinless Split Green Gram soaked ['oak']
# Lemon juice ['lemon']
# Lovage leaves ['lovage']
# Split Bengal gram soaked ['oak']
# Onions chopped ['onion']
# Lemon juice ['lemon']
# Onions cut into fine rings ['onion']
# Rice soaked ['rice', 'oak']
# Rice soaked for an hour ['rice', 'oak']
# Onion chopped ['onion']
# Tomato chopped ['tomato']
# Mutton chops ['hops']
# Lemon juice ['lemon']
# Rice ['rice']
# Cashewnuts ground ['cashew']
# Almonds ['almond']
# Almonds blanched ['almond']
# Onions finely chopped ['onion']
# Dried rose petals ['rose petals']
# Dried kokum petals soaked in 2 cups water ['oak']
# Castor sugar ['castor']
# Split green gram skinless soaked for ½ hour and boiled ['oak']
# Broken wheat 1/2 inch cubes ['wheat']
# Deep fried onions ['onion']
# Lemon wedges ['lemon']
# Baby Potatoes ['potato']
# Tomatoes ['tomato']
# Onions chopped ['onion']
# Tomatoes chopped ['tomato']
# Onion chopped ['onion']
# Onions sliced ['onion']
# Medium onion finely chopped ['onion']
# Tomatoes chopped ['tomato']
# Onions chopped ['onion']
# Cashewnuts ['cashew']
# Onions sliced ['onion']
# Onions roughly chopped ['onion']
# Rice flour ['rice']
# Lemon juice ['lemon']
# Onion, sliced ['onion']
# Red pumpkin cubed ['pumpkin']
# Chickpeas soaked overnight ['chickpea', 'oak']
# Onion finely chopped ['onion']
# Tomatoes quartered ['tomato']
# Fresh spinach blanched and pureed ['spinach']
# Onions chopped ['onion']
# Potatoes diced ['potato']
# Basmati rice soaked ['rice', 'oak']
# Wheat flour dough to seal ['wheat']
# Rose petals ['rose petals']
# Peanuts ['peanut']
# Onion sliced ['onion']
# Onion seeds ['onion']
# Onions chopped ['onion']
# Green capsicums roasted and peeled and chopped ['capsicum']
# Lemon juice ['lemon']
# Apple gourds - peeled ['apple']
# Onions finely chopped ['onion']
# Lemon wedges ['lemon']
# Ripe banana peeled ['banana']
# Rice flour ['rice']
# Cashewnuts chopped ['cashew']
# Bengal gram soaked for 8 hours ['oak']
# Potatoes boiled, peeled and cut into cubes ['potato']
# Lemon juice ['lemon']
# Onion seeds ['onion']
# Onions,sliced ['onion']
# Tomato paste ['tomato']
# Onions chopped ['onion']
# Tomato,chopped ['tomato']
# Onions,sliced ['onion']
# Cashewnut paste ['cashew']
# Rice ['rice']
# Peanuts ['peanut']
# Raw papaya paste ['papaya']
# Fried onions ['onion']
# Lemon juice ['lemon']
# Whole wheat flour dough ['wheat']
# Rice ['rice']
# Basmati rice soaked and drained ['rice', 'oak']
# Spinach ['spinach']
# Almonds ['almond']
# Rice ['rice']
# Onions ['onion']
# Spring onions with greens finely chopped ['onion']
# Liquid orange food colour ['orange']
# Onions chopped ['onion']
# Almonds chopped ['almond']
# Medium potatoes boiled, peeled and mashed ['potato']
# Whole Red Lentils soaked ['oak']
# Onion chopped ['onion']
# Cashewnuts ['cashew']
# Castor sugar ['castor']
# Lemon juice ['lemon']
# Onions finely chopped ['onion']
# Onions sliced ['onion']
# Tomatoes finely chopped ['tomato']
# Onion seeds ['onion']
# Strawberry jam thick ['strawberry']
# Vanilla essence ['vanilla']
# Potato,boiled and diced ['potato']
# Onions finely chopped ['onion']
# Rice ['rice']
# Red pumpkin ['pumpkin']
# Pressed rice ['rice']
# Raw peanuts ['peanut']
# Cashewnuts halved ['cashew']
# Onions chopped ['onion']
# Tomatoes chopped ['tomato']
# Roasted peanuts ['peanut']
# Onions roughly chopped ['onion']
# Spinach leaves blanched, drained and chopped ['spinach']
# Chickpeas soaked overnight and boiled ['chickpea', 'oak']
# Castor sugar ['castor']
# Medium onions peeled ['onion']
# Red capsicums cut into thin strips ['capsicum']
# Spinach blanched ['spinach']
# Cashewnuts ['cashew']
# fresh Spinach Leaves ['spinach']
# Wholewheat Flour ['wheat']
# Fresh spinach leaves ['spinach']
# Onion chopped ['onion']
# Onions sliced ['onion']
# Onion seeds ['onion']
# Tomato ['tomato']
# Green capsicum ['capsicum']
# Onions ['onion']
# Red capsicum ['capsicum']
# Almond paste ['almond']
# Rice flour ['rice']
# Lotus stem ['lotus']
# Onions sliced ['onion']
# Almonds blanched and peeled Ground ['almond']
# Rice ['rice']
# Almonds slivered ['almond']
# Almonds coarsely ground ['almond']
# Pineapple peeled and cubed ['pineapple', 'apple']
# Onions sliced ['onion']
# Onions finely chopped ['onion']
# Tomatoes finely chopped ['tomato']
# Whole wheat flour ['wheat']
# Whole wheat flour ['wheat']
# Potato boiled ['potato']
# Cashewnuts ['cashew']
# Whole red lentils soaked ['oak']
# Dates ['date']
# Basmati Rice soaked ['rice', 'oak']
# Onion ['onion']
# Onion sliced ['onion']
# Onion finely chopped ['onion']
# Fresh tomato puree ['tomato']
# Potato peeled and cut into half ['potato']
# Castor sugar ['castor']
# Potatoes ['potato']
# Potatoes ['potato']
# Onion ['onion']
# Lemon ['lemon']
# Lemon ['lemon']
# Lemons ['lemon']
# Peanuts roasted ['peanut']
# Onion chopped ['onion']
# Onions finely chopped ['onion']
# Tomato puree ['tomato']
# Juice of 1½ lemons ['lemon']
# Lemon wedges ['lemon']
# Rice soaked ['rice', 'oak']
# Cashewnuts ['cashew']
# Edible camphor optional ['camphor']
# Rice flour ['rice']
# Lemon juice ['lemon']
# Whole wheat flour ['wheat']
# Split Bengal gram soaked for 1-2 hours and drained ['oak']
# Chopped onion ['onion']
# Lemon wedges ['lemon']
# Whole wheat flour ['wheat']
# Onion chopped ['onion']
# Tomatoes ['tomato']
# Onions ['onion']
# Curd and tomato based chutney ['tomato']
# Potatoes boiled and peeled ['potato']
# Whole wheat flour ['wheat']
# Potatoes grated, For koftas ['potato']
# Onions,roughly chopped ['onion']
# Tomato puree ['tomato']
# Cashewnuts ['cashew']
# Potatoes ['potato']
# Onion seeds ['onion']
# Potatoes peeled and cut into 1 inch pieces ['potato']
# Onions roughly chopped ['onion']
# Tomatoes roughly chopped ['tomato']
# Onions finely chopped ['onion']
# Onion finely chopped ['onion']
# Potato peeled and chopped ['potato']
# Tomato finely chopped ['tomato']
# Lemon wedges ['lemon']
# Cooked rice ['rice']
# Onions chopped ['onion']
# Tomato puree ['tomato']
# Browned Onions ['onion']
# Rice flour ['rice']
# Onion chopped ['onion']
# Tomato chopped ['tomato']
# Custard Apple ['apple']
# Medium onion finely chopped ['onion']
# Molaga podi ['aga']
# Banana leaves ['banana']
# Rice Flour ['rice']
# Rice ['rice']
# Potatoes boiled and mashed ['potato']
# Capsicum finely chopped ['capsicum']
# Onions chopped ['onion']
# Tomato puree fresh ['tomato']
# Readymade tomato puree ['tomato']
# Lemon juice ['lemon']
# A lemon slice ['lemon']
# Whole wheat flour ['wheat']
# Raw papaya ['papaya']
# Wheat Grass ['wheat']
# Lemon Juice ['lemon']
# Rice soaked ['rice', 'oak']
# Bottle gourd grated ['bottle gourd']
# Almonds sliced ['almond']
# Dried rose petals ['rose petals']
# Onions roughly chopped ['onion']
# Tomatoes ['tomato']
# Onions chopped ['onion']
# Tomato chopped ['tomato']
# Broken wheat soaked for 1 hour ['wheat', 'oak']
# Cashewnuts chopped ['cashew']
# Pumpkin 1 inch cubes ['pumpkin']
# Onions sliced ['onion']
# Tomatoes chopped ['tomato']
# Cashewnuts ['cashew']
# Potatoes halved ['potato']
# Onions cut into wedges ['onion']
# Rice ['rice']
# Lemon juice ['lemon']
# Carrots ['carrot']
# Lemon juice ['lemon']
# Small onions ['onion']
# Lemon juice ['lemon']
# Lemon juice ['lemon']
# Banana leaves ['banana']
# Onion chopped ['onion']
# Rice ['rice']
# Ripe banana mashed ['banana']
# Onion chopped ['onion']
# Juice of ½ lemon ['lemon']
# Rice ['rice']
# Lemon juice ['lemon']
# Onion rings ['onion']
# Green capsicum thin strips ['capsicum']
# Red capsicum thin strips ['capsicum']
# Yellow capsicum thin strips ['capsicum']
# Potatoes boiled and peeled ['potato']
# Roasted peanuts coarsely crushed ['peanut']
# Rice flour ['rice']
# Whole wheat flour ['wheat']
# Tomato ketchup ['tomato']
# Tomatoes roughly chopped ['tomato']
# Onion chopped ['onion']
# Tomato chopped ['tomato']
# Lemon juice ['lemon']
# Onions chopped ['onion']
# Tomatoes chopped ['tomato']
# Soya Nuggets soaked and drained ['oak']
# Onion finely chopped ['onion']
# Green capsicum finely chopped ['capsicum']
# Tomato finely chopped ['tomato']
# Tomato flowers ['tomato']
# Onion sliced ['onion']
# Cabbage shredded ['cabbage']
# Carrot grated ['carrot']
# Wholewheat Flour ['wheat']
# Chickpeas soaked overnight ['chickpea', 'oak']
# Olive oil ['olive oil']
# Onion ['onion']
# Split skinless black gram soaked for 8-10 hours and drained ['oak']
# Rice flour ['rice']
# Tomatoes ['tomato']
# Onions ['onion']
# Onions cut into cubes ['onion']
# Whole Wheat Flour 3/4 cup ['wheat']
# Carrot grated ['carrot']
# Lemon juice ['lemon']
# Onions ['onion']
# Dagad phool ['aga']
# Tomatoes chopped ['tomato']
# Peanuts ground coarsely ['peanut']
# Wheat flour ['wheat']
# Rice flour ['rice']
# Bananas mashed ['banana']
# Whole black gram boiled and soaked ['oak']
# Potato boiled and mashed ['potato']
# Rice flour ['rice']
# Chickpeas soaked overnight ['chickpea', 'oak']
# Onions sliced ['onion']
# Tomato puree fresh ['tomato']
# Red kidney beans soaked and boiled ['oak']
# Jeera rice ['rice']
# Medium onion finely chopped ['onion']
# Fresh tomato puree ['tomato']
# Potato ['potato']
# Lemon juice ['lemon']
# Onions ['onion']
# Green capsicums cut into 1 inch pieces ['capsicum']
# Tomatoes Seeded and cut into 1 inch pieces ['tomato']
# Tomato puree ['tomato']
# Lemon juice ['lemon']
# Onion sliced ['onion']
# Onions finely chopped ['onion']
# Onion chopped ['onion']
# Tomato chopped ['tomato']
# Whole wheat flour ['wheat']
# Onions ['onion']
# Red pumpkin ['pumpkin']
# Lemon grass ['lemon']
# Castor sugar ['castor']
# Sambar Onions ['onion']
# Sambhar onions ['onion']
# Rice flour ['rice']
# Cooked Rice ['rice']
# Peanuts ['peanut']
# Spinach ['spinach']
# Green capsicum ['capsicum']
# Tomato ['tomato']
# Onion ['onion']
# Cashewnuts ['cashew']
# Potatoes boiled peeled and cut into ½ inch cubes ['potato']
# Roasted peanuts ['peanut']
# Onion finely chopped ['onion']
# Tomatoes finely chopped ['tomato']
# Basmati rice soaked ['rice', 'oak']
# Onions sliced ['onion']
# Almond and Pistachio slivers ['almond']
# Carrot ['carrot']
# Pumpkin ['pumpkin']
# Potatoes peeled ['potato']
# Rice flour ['rice']
# Onion sliced finely ['onion']
# Basmati Rice soaked ['rice', 'oak']
# Onions sliced and deep fried ['onion']
# Dried rose petals ['rose petals']
# Bottle gourd ['bottle gourd']
# Onion chopped ['onion']
# Chickpeas soaked overnight and drained ['chickpea', 'oak']
# Whole wheat flour ['wheat']
# Raw peanuts ['peanut']
# Lemon juice ['lemon']
# Tomato finely chopped ['tomato']
# Banana ['banana']
# Steamed white rice ['rice']
# Onion chopped ['onion']
# Almonds blanched and sliced ['almond']
# Apple cubed ['apple']
# Bananas cubed ['banana']
# Spinach ['spinach']
# Lemon juice ['lemon']
# Lotus root ['lotus']
# Fresh spinach leaves chopped ['spinach']
# Wheat flour ['wheat']
# Tomato paste ['tomato']
# Rice flour ['rice']
# Lemon juice ['lemon']
# Carrots grated ['carrot']
# Lemon juice ['lemon']
# Lemon juice ['lemon']
# Lemon ['lemon']
# Onion sliced ['onion']
# Black eyed peas soaked for 4-6 hours ['oak']
# Medium onion roughly chopped ['onion']
# Green Papaya peeled and cut into thin strips ['papaya']
# Carrot cut into thin strips ['carrot']
# Onions finely chopped ['onion']
# Onion chopped ['onion']
# Tomato chopped ['tomato']
# Potato fried wedges ['potato']
# Dried yellow peas soaked overnight and pressure cooked ['oak']
# Medium onions sliced ['onion']
# Fresh tomato puree ['tomato']
# Onion chopped ['onion']
# Potatoes boiled and peeled ['potato']
# Onions sliced ['onion']
# Red pumpkin ['pumpkin']
# Lemon juice ['lemon']
# Lemon juice ['lemon']
# Spinach ['spinach']
# Onion ['onion']
# Tomato ['tomato']
# Rice soaked ['rice', 'oak']
# Lemon juice ['lemon']
# Rice ['rice']
# Bananas ['banana']
# Potatoes ['potato']
# Fried onion paste ['onion']
# Pear ['pear']
# Apples ['apple']
# Plums ['plum']
# Pineapple ['pineapple', 'apple']
# Dates ['date']
# Banana ['banana']
# Almonds ['almond']
# Tomatoes raw, cut into cubes ['tomato']
# Onions finely chopped ['onion']
# Spring onions with greens chopped ['onion']
# Potato peeled ['potato']
# Red pumpkin peeled ['pumpkin']
# Sambhar onions ['onion']
# Pressed rice soaked and drained ['rice', 'oak']
# Onion ['onion']
# Raw peanuts ['peanut']
# Potato boiled ['potato']
# Onions chopped ['onion']
# Roasted peanuts ['peanut']
# Rose petals ['rose petals']
# Whole wheat flour ['wheat']
# Onion ['onion']
# Juice of 1 lemon ['lemon']
# Rice flour ['rice']
# Rice Flour Coarse chopped ['rice']
# Rice flour coarse ['rice']
# Rice ['rice']
# Parboiled rice ['rice']
# Onion ['onion']
# Raw banana ['banana']
# Cashewnuts chopped ['cashew']
# Almonds chopped ['almond']
# Lotus stems cut into pieces and boiled ['lotus']
# Potatoes boiled ['potato']
# Onion chopped ['onion']
# Almonds blanched, peeled and sliced ['almond']
# Lemon juice ['lemon']
# Tomato puree ['tomato']
# Split piegeon pea soaked ['oak']
# Whole wheat flour ['wheat']
# Peanuts ['peanut']
# Onion , finely chopped ['onion']
# Lemon ['lemon']
# Cabbage chopped ['cabbage']
# Rice soaked ['rice', 'oak']
# Carrots grated ['carrot']
# Split skinless green gram soaked ['oak']
# Lemon juice ['lemon']
# Carrot ['carrot']
# Lemon ['lemon']
# Onions grated ['onion']
# Lemon juice ['lemon']
# Potatoes boiled, peeled and grated ['potato']
# Rice ['rice']
# Carrot ['carrot']
# Grapes ['grape']
# Raw papaya paste ['papaya']
# Onions chopped ['onion']
# Tomatoes chopped ['tomato']
# Peanuts,roasted and crushed ['peanut']
# kolam rice ['rice']
# Rice ['rice']
# Onion sliced ['onion']
# Potatoes 2cm cubes ['potato']
# Rice ['rice']
# Parboiled rice ['rice']
# Bottle Gourd grated ['bottle gourd']
# Lemon ['lemon']
# Onions roundels ['onion']
# Lemon juice ['lemon']
# Medium tomatoes chopped ['tomato']
# Cashewnuts ['cashew']
# Almonds slivered ['almond']
# Cashewnuts chopped ['cashew']
# Carrots cut into ¼ inch pieces ['carrot']
# Green capsicum cut into ¼ inch pieces ['capsicum']
# Onion sliced ['onion']
# Tomato roughly chopped ['tomato']
# Red pumpkin peeled and grated ['pumpkin']
# Onions finely chopped ['onion']
# Wholewheat Flour ['wheat']
# Broken wheat soaked ['wheat', 'oak']
# Split Bengal gram soaked ['oak']
# Cashewnuts ¼ cup + ['cashew']
# Green capsicum ['capsicum']
# Juice of 1 lemon ['lemon']
# Onions sliced ['onion']
# Rice soaked ['rice', 'oak']
# Onions chopped ['onion']
# Rice soaked ['rice', 'oak']
# Potatoes ['potato']
# Onions ['onion']
# Tomato ['tomato']
# Cashewnuts ['cashew']
# Roasted onion seed powder ['onion']
# Whole Wheat Flour ['wheat']
# Onion finely chopped ['onion']
# Lemon wedges ['lemon']
# Basmati rice soaked ['rice', 'oak']
# Onions sliced ['onion']
# Tomatoes chopped ['tomato']
# Onions ['onion']
# Whole wheat flour ['wheat']
# Peanuts ['peanut']
# Lime leaves ['lime']
# Onions finely chopped ['onion']
# Tomatoes chopped ['tomato']
# Split skinless green gram soaked ['oak']
# Medium onion ['onion']
# Mutton a mix of chops, marrowbone and shoulder pieces ['hops']
# Basmati rice ['rice']
# Onions sliced ['onion']
# Lemon Juice ['lemon']
# Lemon juice ['lemon']
# Onion roughly chopped ['onion']
# Onions chopped ['onion']
# Slivered almonds ['almond']
# Wheat flour ['wheat']
# Whole Wheat Flour ['wheat']
# Rice Flour ['rice']
# Lemon juice ['lemon']
# Rice flour coarse ['rice']
# Lemon,cut into wedges ['lemon']
# Chickpeas soaked ['chickpea', 'oak']
# Split Bengal gram soaked ['oak']
# Onions sliced ['onion']
# Basmati rice soaked ['rice', 'oak']
# Medium onions sliced ['onion']
# Fried onions ['onion']
# Tomatoes ['tomato']
# Onions chopped ['onion']
# Peanuts ['peanut']
# Onion puree ['onion']
# Fresh tomato puree ['tomato']
# Readymade tomato puree ['tomato']
# Onion ['onion']
# Tomato ['tomato']
# Sambhar onions ['onion']
# Lemon juice ['lemon']
# Raw bananas ['banana']
# Onion ['onion']
# Tomato ['tomato']
# Onion seeds ['onion']
# Medium onions sliced ['onion']
# Whole wheat flour ['wheat']
# Ready made vanilla ice cream ['vanilla']
# Radishes with leaves ['radish']
# Radish leaves boiled in salt water ['radish']
# Onions ['onion']
# Potatoes quartered vertically and sliced ['potato']
# Onion ['onion']
# Tomatoes ['tomato']
# Potatoes boiled , peeled and grated ['potato']
# Tomatoes ['tomato']
# Tomatoes chopped ['tomato']
# Onions chopped ['onion']
# Tomato puree ['tomato']
# Potato wafers ['potato']
# Rice ['rice']
# Peanuts roasted ['peanut']
# Radish chopped leaves ['radish']
# Wheat Flour ['wheat']
# Lemon juice ['lemon']
# Onions sliced ['onion']
# Cabbage shredded ['cabbage']
# Bottle Gourd grated ['bottle gourd']
# Almonds blanched peeled and slivered ['almond']
# Rice soaked ['rice', 'oak']
# Onions sliced ['onion']
# Tomato Puree ['tomato']
# Rice ['rice']
# Potatoes cubed ['potato']
# Onion ,sliced ['onion']
# Rice soaked ['rice', 'oak']
# Cooked rice ['rice']
# Rice ['rice']
# Onion sliced ['onion']
# Potato cut into cubes ['potato']
# Spinach roughly chopped ['spinach']
# Onion chopped ['onion']
# Tomato chopped ['tomato']
# Cashewnuts ['cashew']
# Rice ['rice']
# Onions chopped ['onion']
# Tomato, chopped ['tomato']
# Rolled Oats ['oats']
# Onions finely chopped ['onion']
# Rolled oats ['oats']
# Basmati rice flour ['rice']
# Seedless dates chopped ['date']
# Jasmine flowers ['jasmine']
# Rice ['rice']
# Onion ['onion']
# Spinach ['spinach']
# Lemon juice ['lemon']
# Cashewnut powder ['cashew']
# Spring onion bulb flower ['onion']
# Cow's milk chenna ['henna']
# Rice powder ['rice']
# Almonds blanched and slivered ['almond']
# Coarse Whole Wheat flour ['wheat']
# Basmati rice ['rice']
# Onions sliced ['onion']
# Tomatoes chopped ['tomato']
# Onions sliced and fried brown ['onion']
# Carrots diced and boiled ['carrot']
# Onions chopped ['onion']
# Tomatoes chopped ['tomato']
# Medium onion sliced ['onion']
# Onion chopped ['onion']
# Green capsicum chopped ['capsicum']
# Tomato chopped ['tomato']
# Potato bhaji ['potato']
# Lemon juice ['lemon']
# Onions ['onion']
# Onions finely chopped ['onion']
# Cashewnuts ['cashew']
# Medium onions ['onion']
# Onions sliced thinly ['onion']
# Whole wheat flour dough ['wheat']
# Onions ['onion']
# Potatoes ['potato']
# Onions,sliced ['onion']
# Mutton chops cleaned and washed ['hops']
# Onions finely chopped ['onion']
# Tomatoes finely chopped ['tomato']
# Fresh spinach leaves ['spinach']
# Olive oil ['olive oil']
# Onions sliced ['onion']
# Almonds sliced thinly ['almond']
# Whole wheat flour ['wheat']
# Onion finely chopped ['onion']
# Papaya ['papaya']
# Wholewheat Flour ['wheat']
# Whole wheat flour ['wheat']
# Split green gram skinless soaked ['oak']
# Almonds sliced ['almond']
# Cashewnuts ['cashew']
# Onion chopped ['onion']
# Onion chopped ['onion']
# Onion diced and layers separated ['onion']
# Tomatoes chopped ['tomato']
# Medium onions finely chopped ['onion']
# Potatoes ['potato']
# Lemon juice ['lemon']
# Banana leaves ['banana']
# Green capsicums ['capsicum']
# Bottle gourd grated ['bottle gourd']
# Spinach blanched and pureed ['spinach']
# Lemon juice ['lemon']
# Tomatoes ['tomato']
# Rice ['rice']
# Onions chopped ['onion']
# Whole wheat flour for dusting ['wheat']
# Rose petals ['rose petals']
# Basmati rice soaked ['rice', 'oak']
# Onion sliced ['onion']
# Onions chopped ['onion']
# Vanilla essence ['vanilla']
# Cashewnuts ['cashew']
# Whole wheat flour ['wheat']
# Cashewnuts chopped ['cashew']
# Almonds chopped ['almond']
# Potato boiled ['potato']
# Rice Flour ['rice']
# Wholewheat Flour ['wheat']
# Tomato ketchup ['tomato']
# Onions sliced ['onion']
# Seedless dates ['date']
# Lemon juice ['lemon']
# Tomatoes ['tomato']
# Green capsicum deseeded & chopped ['capsicum']
# Spring onions with greens chopped ['onion']
# Arrowroot powder ['arrowroot']
# Tomato puree ['tomato']
# Rice, parboiled ['rice']
# Rice,parboiled ['rice']
# Lemon ['lemon']
# Whole wheat flour ['wheat']
# Parboiled rice ['rice']
# Potatoes 1/2 inch cubes ['potato']
# Lemon juice ['lemon']
# Potato salli ['potato']
# Chickpeas ['chickpea']
# Potatoes puree ['potato']
# Onions Chopped ['onion']
# Potatoes cubed ['potato']
# Onion ['onion']
# Onion seeds ['onion']
# Rice ['rice']
# Onions chopped ['onion']
# Baby potatoes boiled and peeled ['potato']
# Onions ['onion']
# Rice ['rice']
# Onion sliced ['onion']
# Potatoes 2 cm cubes ['potato']
# Whole wheat flour ['wheat']
# Onions sliced ['onion']
# Split Bengal Gram, Split Red Lentils soaked for 1 hour ['oak']
# Split red lentils soaked for 1 hour ['oak']
# Onion ['onion']
# Melon seed paste ['melon']
# Banana ['banana']
# Apple ['apple']
# Almonds,blanched, peeled and slivered ['almond']
# Whole wheat flour ['wheat']
# Pressed Rice ['rice']
# Onion chopped ['onion']
# Tomatoes chopped ['tomato']
# Green capsicum sliced ['capsicum']
# Onions finely chopped ['onion']
# Tomatoes finely chopped ['tomato']
# Tomato puree ['tomato']
# Rice boiled ['rice']
# Carrots peeled and cut into cubes ['carrot']
# Onion chopped ['onion']
# Roasted peanuts ['peanut']
# Onions chopped ['onion']
# Tomato ['tomato']
# Basmati rice soaked ['rice', 'oak']
# Onions sliced ['onion']
# Fried onions ['onion']
# Onion ['onion']
# Onions finely chopped ['onion']
# Almonds blanched peeled and slivered ['almond']
# Vanilla essence ['vanilla']
# Whole wheat flour kneaded into dough ['wheat']
# Lemon juice ['lemon']
# Onions chopped ['onion']
# Tomatoes chopped ['tomato']
# Wheat Flour kneaded into dough ['wheat']
# Almonds ['almond']
# Onions chopped ['onion']
# Tomatoes chopped ['tomato']
# Chenna freshly made ['henna']
# Almonds blanched and chopped ['almond']
# Green grapes halved ['grape']
# Banana cubed small ['banana']
# Potatoes Potatoes,boiled 1 inch pieces ['potato']
# Onions chopped ['onion']
# Tomatoes chopped ['tomato']
# Kokum petals soaked in 2 cups water ['oak']
# Boiled beetroot grated ['beet']
# Rice flour ['rice']
# Onions finely chopped ['onion']
# Black eyed beans , soaked for 5-6 hours ['oak']
# Onion finely chopped ['onion']
# potatoes thickly sliced ['potato']
# Onions thin slices ['onion']
# Tomatoes chopped ['tomato']
# Carrots chopped ['carrot']
# Onion chopped ['onion']
# Basmati Rice ['rice']
# Onion thinly sliced ['onion']
# Lemon juice ['lemon']
# Split Bengal gram , soaked ['oak']
# Split black gram skinless , soaked ['oak']
# Onions ['onion']
# Tomato, chopped ['tomato']
# Onion seeds ['onion']
# Lemon pickle ['lemon']
# Chickpeas boiled ['chickpea']
# Cooked rice ['rice']
# Onions chopped ['onion']
# Tomatoes ['tomato']
# Juice of 1 lemon ['lemon']
# Onion seeds ['onion']
# Almond chopped ['almond']
# Cashewnuts chopped ['cashew']
# Sweet potato cubed ['sweet potato', 'potato']
# Carrot ['carrot']
# Carrots cubed ['carrot']
# Tomatoes quartered ['tomato']
# Onions sliced ['onion']
# Onion sliced ['onion']
# Tomato chopped ['tomato']
# Onions cut into cubes ['onion']
# Lemon juice ['lemon']
# Onion , chopped ['onion']
# Tomato, chopped ['tomato']
# Peanuts ['peanut']
# Lime juice ['lime']
# Cooked rice ['rice']
# Cashewnuts ['cashew']
# Peanuts ['peanut']
# Whole-wheat flour ['wheat']
# Onion chopped ['onion']
# Olive oil 1 tablespoon plus extra ['olive oil']
# Lemon juice ['lemon']
# Lemon wedges ['lemon']
# Rice ['rice']
# Carrots,cubed ['carrot']
# Basmati rice ['rice']
# Onions ['onion']
# Tomatoes chopped ['tomato']
# Puffed lotus seeds ['lotus']
# Potatoes boiled and peeled ['potato']
# Rice Flour ['rice']
# Lemon juice ['lemon']
# Fresh parsley ['parsley']
# Carrots ['carrot']
# Beetroot ['beet']
# Custard Apples Pulp ['apple']
# Chenna ['henna']
# Almonds chopped ['almond']
# Cashewnuts chopped ['cashew']
# Onions finely chopped ['onion']
# Tindli ivy gourds , 4 slits on both edges ['ivy', 'ivy gourd']
# Onions finely chopped ['onion']
# Lemon juice ['lemon']
# Carrots ['carrot']
# Lemon juice ['lemon']
# Onion chopped ['onion']
# Tomato deseeded & chopped ['tomato']
# Potato diced, boiled ['potato']
# Lemon juice ['lemon']
# Split Bengal gram soaked ['oak']
# Split red lentil soaked ['oak']
# Split green gram skinless soaked ['oak']
# Peanuts ['peanut']
# Wheat flour sieved ['wheat']
# Banana leaf cut into 12 inch pieces ['banana']
# Tomatoes roughly chopped ['tomato']
# Apple ['apple']
# Almonds blanched and Sliced ['almond']
# Basmati rice soaked and drained ['rice', 'oak']
# Onions ['onion']
# Potatoes boiled and peeled ['potato']
# Tomatoes ['tomato']
# Deep fried onions ['onion']
# Rice soaked ['rice', 'oak']
# Onions finely chopped ['onion']
# Potatoes quartered ['potato']
# Onions finely chopped ['onion']
# Onions chopped ['onion']
# Sago soaked overnight ['oak']
# Samo rice ['rice']
# Potatoes boiled, peeled and mashed ['potato']
# Lemon juice ['lemon']
# Onion chopped ['onion']
# Tomato chopped ['tomato']
# Onions sliced ['onion']
# Potatoes sliced ['potato']
# Spinach bunch ['spinach']
# Poppy seed paste soaked and ground ['oak']
# Onion chopped ['onion']
# Whole wheat flour ['wheat']
# Tomato puree ['tomato']
# Onions ['onion']
# Potatoes boiled and mashed ['potato']
# Cashewnut paste ['cashew']
# Potatoes ['potato']
# Onions ['onion']
# Potatoes ['potato']
# Tomatoes grated ['tomato']
# Rice soaked ['rice', 'oak']
# Onions chopped ['onion']
# Tomato chopped ['tomato']
# Potatoes ['potato']
# Onion chopped ['onion']
# Rice flour ['rice']
# Onions,chopped ['onion']
# Tomatoes,chopped ['tomato']
# Lemon juice ['lemon']
# Carrots grated ['carrot']
# Lemon juice ['lemon']
# Medium onion finely chopped ['onion']
# Bottle gourd ['bottle gourd']
# Cashewnuts chopped ['cashew']
# Almonds blanched and slivered ['almond']
# Vanilla essence ['vanilla']
# Onion thinly sliced ['onion']
# Tomatoes chopped ['tomato']
# Potatoes cubed ['potato']
# Black Bengal Gram soaked overnight and boiled with salt ['oak']
# Red pumpkin ['pumpkin']
# Almonds blanched and slivered ['almond']
# Whole wheat flour ['wheat']
# Cooked rice ['rice']
# Onion ['onion']
# Carrot cut into small cubes ['carrot']
# Lemon ['lemon']
# Basmati Rice ['rice']
# Prawns soaked ['oak']
# Onions finely chopped ['onion']
# Lemon ['lemon']
# Onion finely chopped ['onion']
# Stone apple halved and seeded ['apple']
# Lemon juice ['lemon']
# Rice ['rice']
# Rice bran oil ['rice']
# Basmati rice soaked and drained ['rice', 'oak']
# Cashewnuts ['cashew']
# Large onion sliced ['onion']
# Onion chopped ['onion']
# Tomatoes chopped ['tomato']
# Seedless dates ['date']
# Onion seeds ['onion']
# Potatoes boiled, peeled and chopped ['potato']
# Onion finely chopped ['onion']
# Cashewnuts ['cashew']
# Onions chopped ['onion']
# Basmati rice soaked ['rice', 'oak']
# Onion chopped ['onion']
# Tomatoes chopped ['tomato']
# Fried onions ['onion']
# Extra virgin olive oil ['olive oil']
# Cashewnuts ['cashew']
# Red pumpkin seeded and cubed ['pumpkin', 'pumpkin seed']
# Ripe banana peeled amd mashed ['banana']
# Basmati rice soaked ['rice', 'oak']
# Cashewnuts ['cashew']
# Onions thinly sliced ['onion']
# Tomato thinly sliced ['tomato']
# Brown rice ['rice']
# Lemon juice ['lemon']
# Olive oil ['olive oil']
# Onion chopped ['onion']
# Onion chopped ['onion']
# Tomatoes chopped ['tomato']
# Chickpeas ['chickpea']
# Onions ['onion']
# Onion ['onion']
# Tomatoes ['tomato']
# Rice ['rice']
# Onions sliced ['onion']
# Tomato puree ['tomato']
# Banana Leaves ['banana']
# Spinach Leaves ['spinach']
# Khatta Leaves ['khat']
# Khatta Leaves ['khat']
# Onion ['onion']
# Tomatoes roughly chopped ['tomato']
# Split Bengal gram soaked ['oak']
# Potatoes cut into 1 inch cubes ['potato']
# Potatoes peeled ['potato']
# Rice flour ['rice']
# Raw bananas, parboiled peeled and grated ['banana']
# Potatoes soaked in water grated ['oak', 'potato']
# Onion finely chopped ['onion']
# Tomato finely chopped ['tomato']
# Spring onion green chopped ['onion']
# Split black gram with skin soaked ['oak']
# Split Bengal gram soaked ['oak']
# Onion finely chopped ['onion']
# Carrots 1 1/2 inch pieces ['carrot']
# Cashewnuts soaked for an hour ['cashew', 'oak']
# Onion chopped ['onion']
# Tomatoes chopped ['tomato']
# Tomato puree ['tomato']
# Mixed capsicums finely chopped ['capsicum']
# Split Bengal gram soaked ['oak']
# Onion chopped ['onion']
# Lotus seeds ['lotus']
# Almonds, chopped ['almond']
# Cashewnuts chopped ['cashew']
# Rice soaked ['rice', 'oak']
# Split green gram with skin soaked ['oak']
# Carrot, 1/2 inch cubes ['carrot']
# Potato, 1/2 inch cubes ['potato']
# Tomatoes, 1/2 inch pieces ['tomato']
# Raw banana ['banana']
# Rice Flour ['rice']
# Rice flour ['rice']
# Onion ['onion']
# Potatoes boiled and grated ['potato']
# Onions sliced ['onion']
# Rajasthani lehsun apple chutney ['apple']
# Onions sliced ['onion']
# Onion seeds ['onion']
# Lemon juice ['lemon']
# Green capsicum, 1/4 inch pieces , seeded ['capsicum']
# Onion , finely chopped ['onion']
# Lemon juice ['lemon']
# Whole wheat flour ['wheat']
# Chocolate powder ['cola']
# Almonds ['almond']
# 1½ cups basmati rice, soaked and drained ['rice', 'oak']
# ¾ cup whole cashewnuts ['cashew']
# 1 large onion, finely chopped ['onion']
# Lemon ['lemon']
# Extra virgin olive oil ['olive oil']
# Orange juice ['orange']
# Green capsicums cut into 1/2 inch pieces ['capsicum']
# Cooked rice ['rice']
# Brown Rice soaked in water for 3-4 hours ['rice', 'oak']
# Cashewnuts chopped ['cashew']
# Dates seeded and chopped ['date']
# Onion finely chopped ['onion']
# Tomato finely chopped ['tomato']
# Lemon juice ['lemon']
# Peanuts ['peanut']
# Lemon juice ['lemon']
# Rice flour +1 teaspoon ['rice']
# Wholewheat Flour ['wheat']
# Onion finely chopped ['onion']
# Potatoes ['potato']
# Rice soaked and drained ['rice', 'oak']
# Onion sliced finely ['onion']
# Tomato quartered ['tomato']
# Cashewnuts ['cashew']
# Onion Finely chopped ['onion']
# Tomato finely chopped ['tomato']
# Fresh spinach leaves blanched and chopped ['spinach']
# Onion finely chopped ['onion']
# Rice soaked ['rice', 'oak']
# Cashewnuts ['cashew']
# Peanuts ['peanut']
# Lemon juice ['lemon']
# Onion seeds ['onion']
# Chickpeas ['chickpea']
# Rice flour ['rice']
# Cashewnut soaked for 1 hour ['cashew', 'oak']
# Onion chopped ['onion']
# Tomatoes chopped ['tomato']
# Tomato puree ['tomato']
# Onions sliced ['onion']
# Cashewnuts ['cashew']
# Raw bananas ['banana']
# Spinach leaves ['spinach']
# Red Pumpkin cut into thick strips ['pumpkin']
# Carrots cut into thick strips ['carrot']
# White radish cut into thick strips ['radish']
# Broken Wheat soaked ['wheat', 'oak']
# Split black gram skinless soaked ['oak']
# Split red lentil soaked ['oak']
# Broken wheat soaked ['wheat', 'oak']
# Rice soaked ['rice', 'oak']
# Fried onions ['onion']
# Lemon cut into wedges ['lemon']
# Parboiled rice soaked for 4 hours ['rice', 'oak']
# Kolam rice soaked for 4 hours ['rice', 'oak']
# Split skinless black gram soaked for 4 hours ['oak']
# Lotus Root ['lotus']
# Rice Flour ['rice']
# Potatoes boiled ['potato']
# Lemon juice ['lemon']
# Sambhar onions ['onion']
# Baby potatoes ['potato']
# Cherry tomatoes ['tomato']
# Onion seeds ['onion']
# Onion finely chopped ['onion']
# Tomato finely chopped ['tomato']
# Lemon juice ['lemon']
# Peanuts ['peanut']
# Lemon juice ['lemon']
# Lemon sliced ['lemon']
# Tomato cubed ['tomato']
# Tirphal soaked ['oak']
# Ripe Bananas ['banana']
# Dark chocolate melted ['cola']
# Rice soaked ['rice', 'oak']
# Strawberry crush ['strawberry']
# Whole wheat flour ['wheat']
# Potatoes boiled, peeled, mashed ['potato']
# Onions finely chopped ['onion']
# Tomatoes finely chopped ['tomato']
# Potatoes ['potato']
# Tomatoes ['tomato']
# Onions ['onion']
# Potatoes ['potato']
# Cashewnuts chopped ['cashew']
# Tomato puree ['tomato']
# Onion chopped ['onion']
# Onion paste ['onion']
# Rice flour ['rice']
# Lemon juice ['lemon']
# Onions ['onion']
# Rice flour ['rice']
# Onion sliced ['onion']
# Lemon juice ['lemon']
# Onions finely chopped ['onion']
# Medium potatoes boiled, peeled and quartered ['potato']
# Peanuts boiled ['peanut']
# Peanuts coarsely crushed ['peanut']
# Rice Flour ['rice']
# Split Bengal gram soaked ['oak']
# Browned onion paste ['onion']
# Rose petals ['rose petals']
# Whole wheat flour dough to seal ['wheat']
# Tomato finely chopped ['tomato']
# Rice soaked ['rice', 'oak']
# Onion chopped ['onion']
# Split Bengal gram soaked ['oak']
# Split green gram skinless soaked ['oak']
# Cashewnuts ['cashew']
# Split Bengal Gram soaked ['oak']
# Skinless Split Green Gram soaked ['oak']
# Onions chopped ['onion']
# Split Bengal Gram Soaked in water for 3-4 hours ['oak']
# Rice flour ['rice']
# Spinach ['spinach']
# Lemon juice ['lemon']
# Onion chopped ['onion']
# Split Bengal gram soaked and boiled ['oak']
# Split Bengal gram soaked ['oak']
# Stone apple ['apple']
# Sweet potatoes ['sweet potato', 'potato']
# Chocolate grated ['cola']
# Chocolate syrup ['cola']
# Rice flour ['rice']
# Basmati Rice ['rice']
# Potatoes 1/2 inch cubes ['potato']
# Carrots 1/2 inch cubes ['carrot']
# Onions thinly sliced ['onion']
# Cashewnuts quartered ['cashew']
# Almonds blanched and halved ['almond']
# Wheat flour dough to seal ['wheat']
# Basmati rice soaked ['rice', 'oak']
# Cashewnuts ['cashew']
# Onion seeds ['onion']
# Onions ['onion']
# Lemon juice ['lemon']
# Onion marinade ['onion']
# Whole wheat flour ['wheat']
# Onions ['onion']
# Lemon juice ['lemon']
# Custard apple ['apple']
# Rice soaked ['rice', 'oak']
# Rice ['rice']
# Cabbage shredded ['cabbage']
# Onion sliced thinly ['onion']
# Bottle gourd grated ['bottle gourd']
# Onions finely chopped ['onion']
# Potatoes cut into cubes and deep-fried ['potato']
# Rice flour ['rice']
# Potatoes ['potato']
# Potatoes Boiled, peeled And Grated ['potato']
# Rice soaked for 30 minutes and drained ['rice', 'oak']
# Green gram soaked for 30 minutes and drained ['oak']
# Split Bengal gram soaked for 30 minutes and drained ['oak']
# Rice soaked for 30 minutes and drained ['rice', 'oak']
# Onions chopped ['onion']
# Tomato puree ['tomato']
# Rice tempered ['rice']
# Onions,chopped ['onion']
# Whole wheat flour ['wheat']
# Cherry tomatoes ['tomato']
# Potatoes peeled and diced ['potato']
# Broccoli separated into florets ['broccoli']
# Spinach leaves shredded ['spinach']
# Medium onions finely chopped ['onion']
# Cabbage shredded ['cabbage']
# Sweet potatoes 1 inch pieces ['sweet potato', 'potato']
# White radish 1 inch pieces ['radish']
# Red pumpkin 1 inch pieces ['pumpkin']
# Potato 1 inch pieces ['potato']
# Large onion finely chopped ['onion']
# Almonds ['almond']
# Mutton Chops ['hops']
# Lemon juice ['lemon']
# Whole wheat flour ['wheat']
# Tomatoes ['tomato']
# Large onion finely chopped ['onion']
# Medium tomato finely chopped ['tomato']
# Small carrot chopped ['carrot']
# Rice flour ['rice']
# Almonds ['almond']
# Carrot boiled and cut into small cubes ['carrot']
# Red Pumpkin ['pumpkin']
# Onion, chopped ['onion']
# Rice ['rice']
# Wheat flour coarse ['wheat']
# Almonds chopped ['almond']
# Potatoes ['potato']
# Onion ['onion']
# Onions ['onion']
# Tomato ['tomato']
# Almonds blanched, peeled and sliced ['almond']
# Split black gram skinless soaked and drained ['oak']
# Cashewnuts ['cashew']
# Rice soaked and drained ['rice', 'oak']
# Onion chopped ['onion']
# Raw peanuts ['peanut']
# Lemon juice ['lemon']
# Jasmine rice ['rice', 'jasmine']
# Lemon ['lemon']
# Rice ['rice']
# Onion sliced ['onion']
# Potato cut into cubes ['potato']
# Sweet Potatoes small cubes ['sweet potato', 'potato']
# Onions finely chopped ['onion']
# Tomatoes finely chopped ['tomato']
# Ripe banana ['banana']
# Lemon juice ['lemon']
# Medium white onion sliced ['onion']
# Almonds blanched and peeled ['almond']
# Cashewnuts halved ['cashew']
# Onion roughly chopped ['onion']
# Tomatoes ['tomato']
# Tomatoes chopped ['tomato']
# Lemon ['lemon']
# Tomato chopped ['tomato']
# Medium onions finely chopped ['onion']
# Lemon wedge ['lemon']
# Onions,chopped ['onion']
# Spinach Leaves ['spinach']
# Whole wheat flour ['wheat']
# Rice ['rice']
# Onion sliced ['onion']
# Tomato chopped ['tomato']
# Castor sugar ['castor']
# Onion seeds ['onion']
# Baby potatoes boiled ['potato']
# Spring onions chopped ['onion']
# Tomatoes chopped, ripe and large ['tomato']
# Fresh pineapple peeled and chopped ['pineapple', 'apple']
# Potatoes ['potato']
# Potato ['potato']
# Ripe Bananas ['banana']
# Grapes seedless ['grape']
# Dates ['date']
# Cashewnuts ['cashew']
# Carrot roughly chopped ['carrot']
# Pumpkin cubed ['pumpkin']
# Raw banana peeled and cubed ['banana']
# Sweet potato peeled and cubed ['sweet potato', 'potato']
# Roasted peanuts ['peanut']
# Onion grated ['onion']
# Potato ['potato']
# Radish ['radish']
# Medium onion finely chopped ['onion']
# Whole green grams soaked ['oak']
# Olive oil chopped ['olive oil']
# Tomatoes chopped ['tomato']
# Lemon juice ['lemon']
# Spring onion greens chopped ['onion']
# Rice ['rice']
# Whole black gram soaked for 6-8 hours and drained ['oak']
# Red kidney beans soaked for 6-8 hours and drained ['oak']
# Onion finely chopped ['onion']
# Medium tomatoes finely chopped ['tomato']
# Split green gram with skin soaked ['oak']
# Split Bengal gram soaked ['oak']
# Tomato finely chopped ['tomato']
# Onion finely chopped ['onion']
# Whole wheat flour ['wheat']
# Onion chopped ['onion']
# Onion chopped ['onion']
# Lemon juice ['lemon']
# Almonds toasted ['almond']
# Split Red Lentil soaked ['oak']
# Onions ['onion']
# Potato peeled ['potato']
# Raw peanuts ['peanut']
# Onion chopped ['onion']
# Lemon juice ['lemon']
# Lemon juice ['lemon']
# Carrots peeled and grated ['carrot']
# Lemon juice ['lemon']
# Roasted peanuts ['peanut']
# Lemon juice ['lemon']
# Raw peanuts ['peanut']
# Rice ['rice']
# Onions chopped ['onion']
# Lotus stem ['lotus']
# Split red lentils soaked overnight ['oak']
# Split skinless green gram soaked overnight ['oak']
# Split green grams with skin soaked overnight ['oak']
# Medium potato peeled and cubed ['potato']
# Red pumpkin peeled and cubed ['pumpkin']
# Medium onions finely chopped ['onion']
# Medium tomatoes finely chopped ['tomato']
# Tomato puree ['tomato']
# Lemon juice ['lemon']
# Onion seeds ['onion']
# Onion ['onion']
# Onions ['onion']
# Rice flour ['rice']
# Cherry tomatoes ['tomato']
# Raw Banana ['banana']
# Potatoes grated ['potato']
# Cashewnuts broken ['cashew']
# Castor ['castor']
# Onion rings ['onion']
# Wholewheat Flour kneadedintodough with salt and sufficient water ['wheat']
# Onions finely chopped ['onion']
# Tomatoes finely chopped ['tomato']
# Lemon juice ['lemon']
# Carrot ['carrot']
# Tomatoes ['tomato']
# Potatoes ['potato']
# Onion chopped ['onion']
# Wholewheat flour ['wheat']
# Almonds coarsely powdered ['almond']
# Cashewnuts coarsely powdered ['cashew']
# Lemon juice ['lemon']
# Medium tomatoes finely chopped ['tomato']
# Banana leaves ['banana']
# Potatoes boiled, peeled and mashed ['potato']
# Onions sliced ['onion']
# Rice ['rice']
# Okra ['okra']
# Lemon Juice grated ['lemon']
# Tomato chopped ['tomato']
# Spinach Leaves shredded ['spinach']
# Onion chopped ['onion']
# Chenna ['henna']
# Almonds blanched peeled and chopped ['almond']
# Split green gram skinless soaked ['oak']
# Whole wheat flour ['wheat']
# Black Bengal gram soaked overnight, drained and boiled in fresh wate ['oak']
# Potato boiled and peeled ['potato']
# Onions sliced ['onion']
# Potatoes boiled and peeled ['potato']
# Onion paste ['onion']
# Tomato paste ['tomato']
# Lemon juice ['lemon']
# Banana flower ['banana']
# Potatoes ['potato']
# Onions ['onion']
# Potatoes boiled and mashed ['potato']
# Lamb chops ['hops']
# Raw papaya paste ['papaya']
# Medium onions finely chopped ['onion']
# Lemon juice ['lemon']
# Onion ['onion']
# Onion chopped ['onion']
# Peanuts roasted and ground ['peanut']
# Red Pumpkin peeled and grated ['pumpkin']
# Whole wheat flour ['wheat']
# Onions chopped ['onion']
# Split green gram skinless soaked in water for 3-4 hours ground ['oak']
# Oats ['oats']
# Spinach leaves chopped ['spinach']
# Olive oil ['olive oil']
# Onion sliced ['onion']
# Tomato puree ['tomato']
# Roasted peanuts crushed ['peanut']
# Potato peeled and cut into cubes ['potato']
# Lemon juice ['lemon']
# Fresh parsley chopped ['parsley']
# Potatoes ['potato']
# Onion finely chopped ['onion']
# Onions sliced thinly ['onion']
# Tomatoes ['tomato']
# Onion ['onion']
# Rice flour ['rice']
# Castor sugar ['castor']
# Black grapes ['grape']
# Apple ['apple']
# Basmati Rice soaked ['rice', 'oak']
# Carrots cut into ½ inch cubes ['carrot']
# Onion sliced ['onion']
# Onion boiled and ground ['onion']
# Raw banana 1 inch cubes ['banana']
# Rice ['rice']
# Rice Flour ['rice']
# Poppy seed paste soaked ['oak']
# Onions chopped ['onion']
# Tomatoes ['tomato']
# Red capsicum chopped ['capsicum']
# Cashewnuts chopped ['cashew']
# Raw shelled peanuts ['peanut']
# Onions sliced ['onion']
# Rice flour ['rice']
# Onions, sliced ['onion']
# Whole Wheat Flour ['wheat']
# Onion finely chopped ['onion']
# Basmati rice boiled ['rice']
# Potatoes boiled, peeled and mashed ['potato']
# Green capsicum finely chopped ['capsicum']
# Onion thinly sliced ['onion']
# Tomatoes thinly sliced ['tomato']
# Spinach Leaves chopped ['spinach']
# Rose Petals ['rose petals']
# Onions chopped ['onion']
# Lemon juice ['lemon']
# Spinach puree blanched ['spinach']
# Potatoes peeled and grated ['potato']
# Onions grated ['onion']
# Spinach cleaned ['spinach']
# Medium onion finely chopped ['onion']
# Medium tomatoes finely chopped ['tomato']
# Potatoes quartered ['potato']
# Onions chopped ['onion']
# Tomatoes chopped ['tomato']
# Pressed Rice ['rice']
# Onion ['onion']
# Tomato seeded and diced ['tomato']
# Lemon juice ['lemon']
# Roasted peanuts ['peanut']
# Rice flour ['rice']
# Rice flour ['rice']
# Onions finely chopped ['onion']
# White pumpkin peeled ['pumpkin']
# Split Bengal gram soaked ['oak']
# Rice soaked ['rice', 'oak']
# Potatoes peeled ['potato']
# Pineapple ['pineapple', 'apple']
# Cashewnuts ['cashew']
# Cashewnuts soaked ['cashew', 'oak']
# Almonds soaked ['oak', 'almond']
# Lemon juice ['lemon']
# Rice flour ['rice']
# Medium onions finely chopped ['onion']
# Rice Flour ['rice']
# Rice ['rice']
# Almonds chopped ['almond']
# Cabbage ['cabbage']
# Onions ['onion']
# Lemon juice ['lemon']
# Peanuts roasted ['peanut']
# Onion chopped ['onion']
# Tomatoes ['tomato']
# Dates seedless chopped ['date']
# Cashewnuts chopped ['cashew']
# Almonds chopped ['almond']
# Bengal gram soaked ['oak']
# Onion paste boiled ['onion']
# Onion ['onion']
# Rice flour ['rice']
# Yellow pumpkin grated ['pumpkin']
# Cashewnuts ['cashew']
# Whole wheat flour ['wheat']
# Rice Flour boiled ['rice']
# Banana leaves ['banana']
# Onion ['onion']
# Tomatoes finely chopped ['tomato']
# Onion chopped ['onion']
# Onions ['onion']
# Onion chopped ['onion']
# Peanuts ['peanut']
# Potatoes ['potato']
# Deep fried onions ['onion']
# Lemon juice ['lemon']
# Roasted Peanuts ['peanut']
# Potato boiled and peeled ['potato']
# Tomato ['tomato']
# Lemon juice ['lemon']
# Onions finely chopped ['onion']
# Potatoes boiled and mashed ['potato']
# ...
# Potatoes boiled and mashed ['potato']
# Chickpeas soaked and boiled ['chickpea', 'oak']
# Onions ['onion']
# Tomato ['tomato']
# Large onion finely chopped ['onion']
# Large tomato finely chopped ['tomato']
# Spring onion bulbs chopped ['onion']
# Spring onion greens chopped ['onion']
# Chickpeas soaked overnight and parboiled ['chickpea', 'oak']
# Lemon juice ['lemon']
# Tomatoes ['tomato']
# Onions ['onion']
# Tomatoes ['tomato']
# Rice ['rice']
# Red kidney beans soaked ['oak']
# Onions ['onion']
# Spring onion green ['onion']
# Tomato ['tomato']
# Onion ['onion']
# Onions chopped ['onion']
# Tomatoes chopped ['tomato']
# Split Bengal gram soaked ['oak']
# Rice flour ['rice']
# Cashewnuts ['cashew']
# Juice of 1 lemon ['lemon']
# Basmati rice parboiled ['rice']
# Potato boiled, peeled and cut into 1 inch cubes ['potato']
# Lemon juice ['lemon']
# Pumpkin cut into batons ['pumpkin']
# Rice ['rice']
# Potatoes cut into thick strips ['potato']
# Carrot cut into small cubes ['carrot']
# Potato cut into cubes ['potato']
# Tomato puree ['tomato']
# Onions finely chopped ['onion']
# Green capsicum chopped ['capsicum']
# Lemon juice ['lemon']
# Lemon juice ['lemon']
# Almonds,blanched and slivered ['almond']
# Medium onion 1 ['onion']
# Fresh Spinach leaves chopped ['spinach']
# Fresh spinach leaves chopped ['spinach']
# Onion chopped ['onion']
# Tomato ['tomato']
# Tomato wedges ['tomato']
# Red Pumpkin cut into ½ inch cubes ['pumpkin']
# Potato cut into ½ inch cubes ['potato']
# Onions chopped ['onion']
# Tomatoes chopped ['tomato']
# Onion sliced ['onion']
# Tomato puree ['tomato']
# Onions sliced ['onion']
# Tomatoes chopped ['tomato']
# Brown pressed rice ['rice']
# Onions ['onion']
# Onion chopped ['onion']
# Potato boiled and 1/2 inch cubes ['potato']
# Roasted peanuts ['peanut']
# Lemon juice ['lemon']
# Lemon juice ['lemon']
# Rice ['rice']
# Rice Flour ['rice']
# Green capsicum chopped ['capsicum']
# Red capsicum chopped ['capsicum']
# Tomato finely chopped ['tomato']
# Cabbage finely chopped ['cabbage']
# Juice of ½ lemon ['lemon']
# Basmati rice soaked ['rice', 'oak']
# Onions finely chopped ['onion']
# Tomatoes finely chopped ['tomato']
# Juice of 1 lemon ['lemon']
# Onion chopped ['onion']
# Onion chopped ['onion']
# Cashewnut paste ['cashew']
# Juice of ½ lemon ['lemon']
# Rice ['rice']
# Potatoes ['potato']
# Onions ['onion']
# Rice ['rice']
# Onion sliced ['onion']
# Button onions ['onion']
# Tomatoes quartered ['tomato']
# Cashewnuts ['cashew']
# Brown Basmati rice soaked in water for 3-4 hours ['rice', 'oak']
# Split green gram skinless soaked ['oak']
# Onions roughly chopped ['onion']
# Carrots ['carrot']
# Potatoes ['potato']
# Onions ['onion']
# Onion ['onion']
# Onions grated ['onion']
# Whole wheat flour dough ['wheat']
# Tomato Puree ['tomato']
# Onions chopped ['onion']
# Tomato puree ['tomato']
# Potatoes grated ['potato']
# Peanuts roasted and crushed ['peanut']
# Tomato cut into round slices ['tomato']
# Chickpeas soaked and boiled ['chickpea', 'oak']
# Onion finely chopped ['onion']
# Green capsicum finely chopped ['capsicum']
# Tomato finely chopped ['tomato']
# Potato boiled, peeled and cut into small pieces ['potato']
# Lemon juice ['lemon']
# Onions cut into roundels ['onion']
# Tomatoes cut into roundels ['tomato']
# Potatoes boiled, peeled and sliced ['potato']
# Basmati Rice ['rice']
# Onions ['onion']
# Puffed rice ['rice']
# Onion chopped ['onion']
# Tomato 1/2 inch pieces ['tomato']
# Roasted peanuts skinned ['peanut']
# Onion chopped ['onion']
# Lemon juice ['lemon']
# Medium potatoes boiled, peeled and mashed ['potato']
# Medium onion finely chopped ['onion']
# Cabbage chopped ['cabbage']
# Lemon juice ['lemon']
# Almond paste ['almond']
# Rice flour ['rice']
# Banana ['banana']
# Vanilla essence ['vanilla']
# Whole wheat flour ['wheat']
# Onion finely chopped ['onion']
# Cashewnut paste -almond-poppy seed paste ['cashew', 'almond']
# Cashewnuts fried ['cashew']
# Onions ['onion']
# Tomatoes ['tomato']
# Split Bengal gram soaked and unpolished ['oak']
# Split red lentils soaked and unpolished ['oak']
# Split green gram skinless soaked and unpolished ['oak']
# Red pumpkin cut into small cubes ['pumpkin']
# Potato cut into small cubes ['potato']
# Potatoes ['potato']
# Olive oil ['olive oil']
# Whole wheat flour ['wheat']
# Carrots ['carrot']
# Onion ['onion']
# Potatoes ['potato']
# Peanuts ['peanut']
# Green apples ['apple']
# Castor sugar ['castor']
# Bottle Gourd ['bottle gourd']
# Onions,grated ['onion']
# Fresh tomato puree ['tomato']
# Red Pumpkin grated ['pumpkin']
# Almonds sliced ['almond']
# Chopped onions ['onion']
# Fresh tomato puree ['tomato']
# Basmati rice parboiled ['rice']
# Red lentils split soaked and half cooked ['oak']
# Onion sliced ['onion']
# Green capsicum finely chopped ['capsicum']
# Carrot boiled ['carrot']
# Tomatoes pureed ['tomato']
# Onion sliced ['onion']
# Cashewnuts fried ['cashew']
# Potatoes boiled peeled and mashed ['potato']
# Green Capsicum chopped ['capsicum']
# Whole wheat flour ['wheat']
# Onion chopped ['onion']
# Broken wheat soaked for 2-3 hours ['wheat', 'oak']
# Split Bengal gram soaked ['oak']
# Split skinless black gram soaked ['oak']
# Fried onions ['onion']
# Lemon wedges ['lemon']
# Onion chopped ['onion']
# Tomatoes chopped ['tomato']
# Lemon juice ['lemon']
# Whole wheat flour ['wheat']
# Cashewnuts chopped ['cashew']
# Almonds chopped ['almond']
# Onion chopped ['onion']
# Basmati Rice ['rice']
# Cashewnut powder ['cashew']
# Split Bengal gram soaked in water for 3-4 hours ['oak']
# Onions finely chopped ['onion']
# Tomatoes finely chopped ['tomato']
# Potatoes separated into florets ['potato']
# Red pumpkin 1/2 inch pieces ['pumpkin']
# Sweet potato 1/2 inch pieces ['sweet potato', 'potato']
# Red pumpkin 1/2 inch pieces ['pumpkin']
# Spinach shredded ['spinach']
# Carrot cut into ¼ inch cubes and blanched ['carrot']
# Green capsicum ['capsicum']
# Onion ['onion']
# Extra virgin olive oil ['olive oil']
# Onion ['onion']
# Onion chopped ['onion']
# Tomato chopped ['tomato']
# Onion sliced ['onion']
# Onions ['onion']
# Potatoes ['potato']
# Onions ['onion']
# Tomatoes pureed ['tomato']
# Onion ['onion']
# Onion finely chopped ['onion']
# Potato Wafers ['potato']
# Onions ['onion']
# Tomato ['tomato']
# Peanuts ['peanut']
# Cashewnuts ['cashew']
# Tomatoes chopped ['tomato']
# Onion roughly chopped ['onion']
# Vanilla essence ['vanilla']
# Sago soaked ['oak']
# Cashewnuts ['cashew']
# Almonds ['almond']
# Onions ['onion']
# Soaked rice ['rice', 'oak']
# Lemon juice ['lemon']
# Peanuts ['peanut']
# Large onion sliced ['onion']
# Onion chopped ['onion']
# Lemon juice ['lemon']
# Potatoes cut into ¼ inch cubes ['potato']
# Baby Potatoes ['potato']
# Potatoes cubed ['potato']
# Rice,soaked ['rice', 'oak']
# Onion sliced ['onion']
# Split black gram soaked ['oak']
# Cashewnuts chopped ['cashew']
# Cooked Rice cooled ['rice']
# Peanuts deep fried ['peanut']
# Potatoes peeled ['potato']
# Onion seeds ['onion']
# Onion seeds ['onion']
# Green capsicums cut into 1/2 inch pieces ['capsicum']
# Peanuts ['peanut']
# Lemon juice ['lemon']
# Potatoes boiled peeled and mashed ['potato']
# Onions chopped ['onion']
# Cooked rice ['rice']
# A few thin strips of green capsicum ['capsicum']
# A few thin strips of red capsicum ['capsicum']
# Basmati Rice ['rice']
# Tomatoes ['tomato']
# Onions ['onion']
# Cashewnuts ['cashew']
# Onion finely chopped ['onion']
# Tomato puree ['tomato']
# Lemon juice ['lemon']
# Onion ['onion']
# Dates stoned ['date']
# Chenna ['henna']
# Brokenwheat ['wheat']
# Almonds ['almond']
# Whole wheat flour ['wheat']
# Red cabbage shredded ['cabbage']
# Cabbage shredded ['cabbage']
# Carrots grated ['carrot']
# White radish grated ['radish']
# Green capsicums chopped ['capsicum']
# Orange juice ['orange']
# Lemon juice ['lemon']
# Roasted peanuts coarsely crushed ['peanut']
# Elaichi Bananas ['banana']
# Dark chocolate grated ['cola']
# Almonds ['almond']
# Cashewnuts ['cashew']
# Potatoes peeled and cut into cubes ['potato']
# Onion chopped ['onion']
# Tomato chopped ['tomato']
# Potatoes boiled, peeled and cut into cubes ['potato']
# Onion finely chopped ['onion']
# Raw bananas ['banana']
# Baby potatoes,peeled ['potato']
# Whole wheat flour ['wheat']
# Onions chopped ['onion']
# Onions grated ['onion']
# Cashewnuts ['cashew']
# Green capsicum finely chopped ['capsicum']
# Bottle gourd peeled and grated ['bottle gourd']
# Almonds ['almond']
# Dates dried ['date']
# Apricots ['apricot']
# Cashewnuts ['cashew']
# Rose petals ['rose petals']
# Onions grated ['onion']
# Chickpeas soaked and boiled ['chickpea', 'oak']
# Spinach roughly chopped ['spinach']
# Onion diced ['onion']
# Juice of lemon ['lemon']
# Roasted Peanuts coarsely crushed ['peanut']
# Lemons cut into wedges ['lemon']
# Lemon juice ['lemon']
# Rice powder coarsely ground ['rice']
# Lemon wedges ['lemon']
# Onions ['onion']
# Onion chopped ['onion']
# Kodumpuli soaked ['oak']
# Potatoes grated peeled and soaked ['oak', 'potato']
# Roasted Peanuts ['peanut']
# Roasted peanuts de-skinned ['peanut']
# Cashewnuts roasted ['cashew']
# Lemon juice ['lemon']
# Rice flour ['rice']
# Potatoes boiled and mashed ['potato']
# Roasted peanuts coarsely ground ['peanut']
# Lemon juice ['lemon']
# Skinless Split Black Gram soaked ['oak']
# Skinless Split Green Gram soaked ['oak']
# Radish ['radish']
# Tomatoes quartered ['tomato']
# Medium carrot blanched and cut into 1/2 inch pieces ['carrot']
# Onions grated ['onion']
# Tomato puree ['tomato']
# Carrot ['carrot']
# Onions chopped ['onion']
# Potato 1/2 inch cubes ['potato']
# Carrot 1/2 inch cubes ['carrot']
# Tomatoes chopped ['tomato']
# Almond essence ['almond']
# Almonds ['almond']
# Wholewheat Flour ['wheat']
# Ripe banana ['banana']
# Lemon juice ['lemon']
# Onion rings ['onion']
# Lemon wedges ['lemon']
# Rice flour ['rice']
# Whole wheat flour ['wheat']
# Sabut masoor dal soaked ['oak']
# Basmati rice soaked ['rice', 'oak']
# Cashewnuts ['cashew']
# Onion sliced ['onion']
# Browned Onions ['onion']
# Onions ['onion']
# Cashewnuts ['cashew']
# Rice ['rice']
# Cashewnuts ['cashew']
# Rice ['rice']
# Peanuts ['peanut']
# Onion ['onion']
# Whole wheat flour ['wheat']
# Split green gram soaked ['oak']
# Onions ['onion']
# Onions finely chopped ['onion']
# Rice ['rice']
# Plums ['plum']
# Potatoes boiled, peeled and mashed ['potato']
# Onion chopped ['onion']
# Dried dates crushed ['date']
# Almonds sliced ['almond']
# Cashewnuts chopped ['cashew']
# Carrots grated ['carrot']
# Fresh spinach leaves shredded ['spinach']
# Potato boiled and mashed ['potato']
# Onion chopped ['onion']
# Potato peeled, cut into cubes and deep-fried ['potato']
# Medium onions finely chopped ['onion']
# Potatoes boiled peeled and mashed ['potato']
# Crushed peanuts ['peanut']
# Crushed cashewnuts ['cashew']
# Juice of ¼ lemon ['lemon']
# Thin strips of red capsicum ['capsicum']
# Thin strips of yellow capsicum ['capsicum']
# Thin strips of green capsicum ['capsicum']
# A lemon wedge ['lemon']
# Whole wheat flour 1½ cups ['wheat']
# Coffee powder ['coffee']
# Tomato ['tomato']
# Rose petals ['rose petals']
# Oats ['oats']
# Onions finely chopped ['onion']
# Pressed rice ['rice']
# Roasted peanuts ['peanut']
# Potatoes boiled peeled and cut into 1 inch cubes ['potato']
# Juice of ½ lemon ['lemon']
# Rice Flour ['rice']
# Ripe bananas ['banana']
# Onion chopped ['onion']
# Cooked Rice ['rice']
# Molaga Podi ['aga']
# Molagapodi ['aga']
# Onion finely chopped ['onion']
# Tomato finely chopped ['tomato']
# Tomato puree ['tomato']
# Rice flour ['rice']
# Tomatoes chopped ['tomato']
# Lemon ['lemon']
# Potatoes grated ['potato']
# Onions ['onion']
# Tomatoes chopped ['tomato']
# Black carrots ['carrot']
# Juice of 1 lemon ['lemon']
# Onion seeds ['onion']
# Basmati Rice soaked ['rice', 'oak']
# Onion sliced ['onion']
# Tomatoes, chopped ['tomato']
# Onions cut into rings and deep fried ['onion']
# Basmati Rice soaked ['rice', 'oak']
# Almonds ['almond']
# Cashewnuts ['cashew']
# Onion seeds ['onion']
# Wholewheat Flour ['wheat']
# Coarse Whole Wheat flour ['wheat']
# Pineapple peeled and cut into ½ inch cubes ['pineapple', 'apple']
# Whole wheat flour ['wheat']
# Potatoes boiled and chopped ['potato']
# Onion chopped ['onion']
# Split Bengal gram soaked and drained ['oak']
# Large onion finely chopped ['onion']
# Medium tomatoes finely chopped ['tomato']
# Bottle gourd peeled and cut into large pieces ['bottle gourd']
# Lemon juice ['lemon']
# Potatoes peeled and cut into strips ['potato']
# Onions sliced ['onion']
# Tomato finely chopped ['tomato']
# Raw Banana peeled 1 inch pieces ['banana']
# Almonds slivered ['almond']
# Basmati Rice ['rice']
# Milk soaked ['oak']
# Castor sugar ['castor']
# Potatoes boiled and peeled ['potato']
# Peanuts roasted and crushed ['peanut']
# Rice flour ['rice']
# Lemon juice ['lemon']
# Onion chopped ['onion']
# Roasted peanuts ['peanut']
# Basmati rice boiled ['rice']
# Green capsicum chopped ['capsicum']
# Spring onions chopped ['onion']
# Tomato seeded and diced ['tomato']
# Cashewnuts soaked ['cashew', 'oak']
# Onions sliced ['onion']
# Cherry tomatoes ['tomato']
# Ripe bananas ['banana']
# Whole wheat flour ['wheat']
# Castor sugar ['castor']
# split black gram with skin soaked overnight and drained ['oak']
# Onion seeds ['onion']
# Onions finely chopped ['onion']
# Tomatoes finely chopped ['tomato']
# Wheat Flour ['wheat']
# Almonds coarsely powdered ['almond']
# Cashewnuts coarsely powdered ['cashew']
# Peanuts ['peanut']
# Salted Peanuts ['peanut']
# Browned onions ['onion']
# Chenna ['henna']
# Rice flour ['rice']
# A few onion rings ['onion']
# A lemon slice ['lemon']
# Split Bengal gram soaked ['oak']
# Split green gram skinless soaked ['oak']
# Split black gram skinless soaked ['oak']
# Cashewnuts broken ['cashew']
# Melon seeds ['melon']
# Whole Wheat Flour ['wheat']
# Dried rose petals ['rose petals']
# Tomato Paste ['tomato']
# Onion sliced ['onion']
# Tomato paste ['tomato']
# Cashewnut paste ['cashew']
# Pearl Spot ['pear']
# Banana leaves ['banana']
# Lemon juice ['lemon']
# Basmati rice ['rice']
# Almonds ['almond']
# Rice ['rice']
# Lemon juice ['lemon']
# Almond sliced ['almond']
# Cashewnuts sliced ['cashew']
# Rice flour ['rice']
# Baby Potatoes ['potato']
# Lemon juice ['lemon']
# Lemon juice ['lemon']
# Coarse rice powder ['rice']
# Onion roundels, separated into rings ['onion']
# Rice soaked and drained ['rice', 'oak']
# split skinless green gram soaked and drained ['oak']
# Onion finely chopped ['onion']
# Potato peeled and cubed ['potato']
# Carrot peeled and cubed ['carrot']
# Tomatoes finely chopped ['tomato']
# Rice soaked for 4 hours and drained ['rice', 'oak']
# Split black gram skinless soaked for 4 hours and drained ['oak']
# Baby potatoes peeled ['potato']
# Onion ['onion']
# Lemon ['lemon']
# Extra virgin olive oil ['olive oil']
# Cherry tomatoes ['tomato']
# Onion rings ['onion']
# Lemon slices ['lemon']
# Red capsicum thin strips ['capsicum']
# Fried onion paste ['onion']
# Cashew nut-almond paste ['cashew', 'almond']
# Lemon juice ['lemon']
# Onions ['onion']
# White radish cut into roundels ['radish']
# Onion sliced ['onion']
# Tomato quartered ['tomato']
# Rice powder ['rice']
# Lemon juice ['lemon']
# Onion rings ['onion']
# Lemon slices ['lemon']
# Lemon juice ['lemon']
# Chickpeas ['chickpea']
# Basmati rice ['rice']
# Whole wheat flour ['wheat']
# Onion chopped ['onion']
# Tomato,chopped ['tomato']
# Onion chopped ['onion']
# Tomato chopped ['tomato']
# Onion chopped ['onion']
# Lemon ['lemon']
# White Radish ['radish']
# Peanuts ['peanut']
# Baby potatoes ['potato']
# Onion chopped ['onion']
# Cashewnut paste ['cashew']
# Tomato puree ['tomato']
# Peanuts roasted and peeled ['peanut']
# Basmati Rice soaked and drained ['rice', 'oak']
# Onions thinly sliced ['onion']
# Tomatoes chopped ['tomato']
# Onion ['onion']
# Rice flour ['rice']
# Tomatoes chopped ['tomato']
# Onions ['onion']
# Onions chopped ['onion']
# Tomatoes chopped ['tomato']
# Basmati rice soaked and drained ['rice', 'oak']
# Medium onion ['onion']
# Fried onions ['onion']
# Lemon Leaves ['lemon']
# Lemons ['lemon']
# Madras onions peeled ['onion']
# Red pumpkin peeled, cut into cubes and boiled ['pumpkin']
# Onion seeds ['onion']
# Lemon ['lemon']
# Potatoes boiled ['potato']
# Browned Onions ['onion']
# Tomatoes chopped ['tomato']
# Lemon juice ['lemon']
# Rice ['rice']
# Rice ['rice']
# Chickpeas ['chickpea']
# Spring onions ['onion']
# Cabbage ['cabbage']
# Tomatoes ['tomato']
# Split Bengal Gram soaked ['oak']
# Onion ['onion']
# Whole wheat ['wheat']
# Lemon juice ['lemon']
# Rice flour ['rice']
# Onions,chopped ['onion']
# Cashewnut paste ['cashew']
# Wheat flour rotis ['wheat']
# Soya granules soaked ['oak']
# Onion ['onion']
# Green capsicum ['capsicum']
# Orange ['orange']
# Sweet lime ['lime']
# Onions chopped ['onion']
# Tomatoes pureed ['tomato']
# Cashewnuts ['cashew']
# Onions chopped ['onion']
# Pressed rice thick ['rice']
# Raw peanuts ['peanut']
# Lemon ['lemon']

# %%
match_list_tarla= match_list

# %%
import pandas as pd
sp = []
for l in spice_dict.values():
    sp.extend(l)
print(len(list(set(sp))))

data = pd.read_csv('spices.csv')
print(len(data['Spices']))
# Out:
# 47
# 63

# %%
len(set(list(set(sp)) + list(data['Spices'])))
# Out:
# 109

# %%
set(sp) & set(data['Spices'])
# Out:
# {'chickpea'}

# %%
63+47
# Out:
# 110
